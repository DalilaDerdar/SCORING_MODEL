# %% [markdown]
# ## Création dataframe avec les features

# %%
##HOME CREDIT DEFAULT RISK COMPETITION
# La plupart des caractéristiques sont créées en appliquant les fonctions min, max, mean, sum et var aux tableaux groupés.
# Peu de sélection de caractéristiques est effectuée et le surajustement peut être un problème car de nombreuses caractéristiques
#sont liées.
# Les idées clés suivantes ont été utilisées :
    # - Diviser ou soustraire des caractéristiques importantes pour obtenir des taux (comme l'annuité et le revenu).
    # - Dans les données du Bureau : créer des caractéristiques spécifiques pour les crédits actifs et les crédits fermés.
    # - Dans les demandes antérieures : créer des caractéristiques spécifiques pour les demandes approuvées et refusées.
# Modularité : une fonction pour chaque table (sauf bureau_balance et application_test)
# - Encodage unique pour les caractéristiques catégorielles
# Toutes les tables sont jointes à l'application DF à l'aide de la clé SK_ID_CURR (sauf bureau_balance).
# Vous pouvez utiliser LightGBM avec KFold ou KFold stratifié.

import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
warnings.simplefilter(action='ignore', category=FutureWarning)
import lightgbm as lgb
print(lgb.__version__)

@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))
# Out:
# 3.3.5

# %%
# One-hot encoding for categorical columns with get_dummies
def one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

# %%
# Preprocess application_train.csv and application_test.csv
def application_train_test(num_rows = None, nan_as_category = False):
    # Read data and merge
    df = pd.read_csv('../data/application_train.csv', nrows= num_rows)
    test_df = pd.read_csv('../data/application_test.csv', nrows= num_rows)
    print("Train samples: {}, test samples: {}".format(len(df), len(test_df)))
    df = pd.concat([df, test_df]).reset_index()
    # Optional: Remove 4 applications with XNA CODE_GENDER (train set)
    df = df[df['CODE_GENDER'] != 'XNA']

    # Categorical features with Binary encode (0 or 1; two categories)
    for bin_feature in ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY']:
        df[bin_feature], uniques = pd.factorize(df[bin_feature])

    # Categorical features with One-Hot encode
    df, cat_cols = one_hot_encoder(df, nan_as_category)

    # NaN values for DAYS_EMPLOYED: 365.243 -> nan
    df['DAYS_EMPLOYED'].replace(365243, np.nan, inplace= True)
    
    # Some simple new features (percentages)
    df['DAYS_EMPLOYED_PERC'] = df['DAYS_EMPLOYED'] / df['DAYS_BIRTH']
    df['INCOME_CREDIT_PERC'] = df['AMT_INCOME_TOTAL'] / df['AMT_CREDIT']
    df['INCOME_PER_PERSON'] = df['AMT_INCOME_TOTAL'] / df['CNT_FAM_MEMBERS']
    df['ANNUITY_INCOME_PERC'] = df['AMT_ANNUITY'] / df['AMT_INCOME_TOTAL']
    df['PAYMENT_RATE'] = df['AMT_ANNUITY'] / df['AMT_CREDIT']
    del test_df
    gc.collect()
    return df

# %%
# Preprocess bureau.csv and bureau_balance.csv
def bureau_and_balance(num_rows = None, nan_as_category = True):
    bureau = pd.read_csv('../data/bureau.csv', nrows = num_rows)
    bb = pd.read_csv('../data/bureau_balance.csv', nrows = num_rows)
    bb, bb_cat = one_hot_encoder(bb, nan_as_category)
    bureau, bureau_cat = one_hot_encoder(bureau, nan_as_category)
    

    # Bureau balance: Perform aggregations and merge with bureau.csv
    bb_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size']}
    for col in bb_cat:
        bb_aggregations[col] = ['mean']
    bb_agg = bb.groupby('SK_ID_BUREAU').agg(bb_aggregations)
    bb_agg.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bb_agg.columns.tolist()])
    bureau = bureau.join(bb_agg, how='left', on='SK_ID_BUREAU')
    bureau.drop(['SK_ID_BUREAU'], axis=1, inplace= True)
    del bb, bb_agg
    gc.collect()

    # Bureau and bureau_balance numeric features
    num_aggregations = {
        'DAYS_CREDIT': ['min', 'max', 'mean', 'var'],
        'DAYS_CREDIT_ENDDATE': ['min', 'max', 'mean'],
        'DAYS_CREDIT_UPDATE': ['mean'],
        'CREDIT_DAY_OVERDUE': ['max', 'mean'],
        'AMT_CREDIT_MAX_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_DEBT': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM_LIMIT': ['mean', 'sum'],
        'AMT_ANNUITY': ['max', 'mean'],
        'CNT_CREDIT_PROLONG': ['sum'],
        'MONTHS_BALANCE_MIN': ['min'],
        'MONTHS_BALANCE_MAX': ['max'],
        'MONTHS_BALANCE_SIZE': ['mean', 'sum']
    }
    # Bureau and bureau_balance categorical features
    cat_aggregations = {}
    for cat in bureau_cat: cat_aggregations[cat] = ['mean']
    for cat in bb_cat: cat_aggregations[cat + "_MEAN"] = ['mean']

    bureau_agg = bureau.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    bureau_agg.columns = pd.Index(['BURO_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
    
    # Bureau: Active credits - using only numerical aggregations
    active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
    active_agg = active.groupby('SK_ID_CURR').agg(num_aggregations)
    active_agg.columns = pd.Index(['ACTIVE_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(active_agg, how='left', on='SK_ID_CURR')
    del active, active_agg
    gc.collect()

    # Bureau: Closed credits - using only numerical aggregations
    closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
    closed_agg = closed.groupby('SK_ID_CURR').agg(num_aggregations)
    closed_agg.columns = pd.Index(['CLOSED_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')
    del closed, closed_agg, bureau
    gc.collect()
    return bureau_agg

# %%
# Preprocess previous_applications.csv
def previous_applications(num_rows = None, nan_as_category = True):
    prev = pd.read_csv('../data/previous_application.csv', nrows = num_rows)
    prev, cat_cols = one_hot_encoder(prev, nan_as_category= True)

             
    # Days 365.243 values -> nan
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)

    # Add feature: value ask / value received percentage
    prev['APP_CREDIT_PERC'] = prev['AMT_APPLICATION'] / prev['AMT_CREDIT']

    # Previous applications numeric features
    num_aggregations = {
        'AMT_ANNUITY': ['min', 'max', 'mean'],
        'AMT_APPLICATION': ['min', 'max', 'mean'],
        'AMT_CREDIT': ['min', 'max', 'mean'],
        'APP_CREDIT_PERC': ['min', 'max', 'mean', 'var'],
        'AMT_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'AMT_GOODS_PRICE': ['min', 'max', 'mean'],
        'HOUR_APPR_PROCESS_START': ['min', 'max', 'mean'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
    }
    # Previous applications categorical features
    cat_aggregations = {}
    for cat in cat_cols:
        cat_aggregations[cat] = ['mean']

    prev_agg = prev.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])

    # Previous Applications: Approved Applications - only numerical features
    approved = prev[prev['NAME_CONTRACT_STATUS_Approved'] == 1]
    approved_agg = approved.groupby('SK_ID_CURR').agg(num_aggregations)
    approved_agg.columns = pd.Index(['APPROVED_' + e[0] + "_" + e[1].upper() for e in approved_agg.columns.tolist()])
    prev_agg = prev_agg.join(approved_agg, how='left', on='SK_ID_CURR')
    
    # Previous Applications: Refused Applications - only numerical features
    refused = prev[prev['NAME_CONTRACT_STATUS_Refused'] == 1]
    refused_agg = refused.groupby('SK_ID_CURR').agg(num_aggregations)
    refused_agg.columns = pd.Index(['REFUSED_' + e[0] + "_" + e[1].upper() for e in refused_agg.columns.tolist()])
    prev_agg = prev_agg.join(refused_agg, how='left', on='SK_ID_CURR')
    del refused, refused_agg, approved, approved_agg, prev
    gc.collect()
    return prev_agg

# %%
# Preprocess POS_CASH_balance.csv
def pos_cash(num_rows = None, nan_as_category = True):
    pos = pd.read_csv('../data/POS_CASH_balance.csv', nrows = num_rows)
    pos, cat_cols = one_hot_encoder(pos, nan_as_category= True)
    

    # Features
    aggregations = {
        'MONTHS_BALANCE': ['max', 'mean', 'size'],
        'SK_DPD': ['max', 'mean'],
        'SK_DPD_DEF': ['max', 'mean']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']

    pos_agg = pos.groupby('SK_ID_CURR').agg(aggregations)
    pos_agg.columns = pd.Index(['POS_' + e[0] + "_" + e[1].upper() for e in pos_agg.columns.tolist()])
    
    # Count pos cash accounts
    pos_agg['POS_COUNT'] = pos.groupby('SK_ID_CURR').size()
    del pos
    gc.collect()
    return pos_agg

# %%
# Preprocess installments_payments.csv
def installments_payments(num_rows = None, nan_as_category = True):
    ins = pd.read_csv('../data/installments_payments.csv', nrows = num_rows)
    ins, cat_cols = one_hot_encoder(ins, nan_as_category= True)
    

    # Percentage and difference paid in each installment (amount paid and installment value)
    ins['PAYMENT_PERC'] = ins['AMT_PAYMENT'] / ins['AMT_INSTALMENT']
    ins['PAYMENT_DIFF'] = ins['AMT_INSTALMENT'] - ins['AMT_PAYMENT']

    # Days past due and days before due (no negative values)
    ins['DPD'] = ins['DAYS_ENTRY_PAYMENT'] - ins['DAYS_INSTALMENT']
    ins['DBD'] = ins['DAYS_INSTALMENT'] - ins['DAYS_ENTRY_PAYMENT']
    ins['DPD'] = ins['DPD'].apply(lambda x: x if x > 0 else 0)
    ins['DBD'] = ins['DBD'].apply(lambda x: x if x > 0 else 0)

    # Features: Perform aggregations
    aggregations = {
        'NUM_INSTALMENT_VERSION': ['nunique'],
        'DPD': ['max', 'mean', 'sum'],
        'DBD': ['max', 'mean', 'sum'],
        'PAYMENT_PERC': ['max', 'mean', 'sum', 'var'],
        'PAYMENT_DIFF': ['max', 'mean', 'sum', 'var'],
        'AMT_INSTALMENT': ['max', 'mean', 'sum'],
        'AMT_PAYMENT': ['min', 'max', 'mean', 'sum'],
        'DAYS_ENTRY_PAYMENT': ['max', 'mean', 'sum']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    ins_agg = ins.groupby('SK_ID_CURR').agg(aggregations)
    ins_agg.columns = pd.Index(['INSTAL_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
    
    # Count installments accounts
    ins_agg['INSTAL_COUNT'] = ins.groupby('SK_ID_CURR').size()
    del ins
    gc.collect()
    return ins_agg

# %%
# Preprocess credit_card_balance.csv
def credit_card_balance(num_rows = None, nan_as_category = True):
    cc = pd.read_csv('../data/credit_card_balance.csv', nrows = num_rows)
    cc, cat_cols = one_hot_encoder(cc, nan_as_category= True)
    
    # General aggregations
    cc.drop(['SK_ID_PREV'], axis= 1, inplace = True)
    cc_agg = cc.groupby('SK_ID_CURR').agg(['min', 'max', 'mean', 'sum', 'var'])
    cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
    
    # Count credit card lines
    cc_agg['CC_COUNT'] = cc.groupby('SK_ID_CURR').size()
    del cc
    gc.collect()
    return cc_agg

# %%
def main(debug = False):
    num_rows = 3000 if debug else None
    df = application_train_test(num_rows)
    with timer("Process bureau and bureau_balance"):
        bureau = bureau_and_balance(num_rows)
        print("Bureau df shape:", bureau.shape)
        df = df.join(bureau, how='left', on='SK_ID_CURR')
        del bureau
        gc.collect()
    with timer("Process previous_applications"):
        prev = previous_applications(num_rows)
        print("Previous applications df shape:", prev.shape)
        df = df.join(prev, how='left', on='SK_ID_CURR')
        del prev
        gc.collect()
    with timer("Process POS-CASH balance"):
        pos = pos_cash(num_rows)
        print("Pos-cash balance df shape:", pos.shape)
        df = df.join(pos, how='left', on='SK_ID_CURR')
        del pos
        gc.collect()
    with timer("Process installments payments"):
        ins = installments_payments(num_rows)
        print("Installments payments df shape:", ins.shape)
        df = df.join(ins, how='left', on='SK_ID_CURR')
        del ins
        gc.collect()
    with timer("Process credit card balance"):
        cc = credit_card_balance(num_rows)
        print("Credit card balance df shape:", cc.shape)
        df = df.join(cc, how='left', on='SK_ID_CURR')
        del cc
        gc.collect()
    
    return df


if __name__ == "__main__":
    submission_file_name = "../notebook/submit.csv"
    with timer("Full model run"):
        final_df = main()
    # print("Final dataframe shape:", final_df.shape)
    # print(final_df)
# Out:
# Train samples: 307511, test samples: 48744
# Bureau df shape: (305811, 116)
# Process bureau and bureau_balance - done in 20s
# Previous applications df shape: (338857, 249)
# Process previous_applications - done in 27s
# Pos-cash balance df shape: (337252, 18)
# Process POS-CASH balance - done in 15s
# Installments payments df shape: (339587, 26)
# Process installments payments - done in 31s
# Credit card balance df shape: (103558, 141)
# Process credit card balance - done in 17s
# Full model run - done in 115s

# %%
final_df.head()
# Out:
#    index  SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0      0      100002     1.0            0             0                0
# 1      1      100003     0.0            1             0                1
# 2      2      100004     0.0            0             1                0
# 3      3      100006     0.0            1             0                0
# 4      4      100007     0.0            0             0                0
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  ...  \
# 0             0          202500.0    406597.5      24700.5  ...
# 1             0          270000.0   1293502.5      35698.5  ...
# 2             0           67500.0    135000.0       6750.0  ...
# 3             0          135000.0    312682.5      29686.5  ...
# 4             0          121500.0    513000.0      21865.5  ...
#
#    CC_NAME_CONTRACT_STATUS_Signed_MAX  CC_NAME_CONTRACT_STATUS_Signed_MEAN  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                               False                                  0.0
# 4                                 NaN                                  NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_SUM  CC_NAME_CONTRACT_STATUS_Signed_VAR  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 0.0                                 0.0
# 4                                 NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_MIN  CC_NAME_CONTRACT_STATUS_nan_MAX  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                            False                            False
# 4                              NaN                              NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_MEAN  CC_NAME_CONTRACT_STATUS_nan_SUM  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               0.0                              0.0
# 4                               NaN                              NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_VAR  CC_COUNT
# 0                              NaN       NaN
# 1                              NaN       NaN
# 2                              NaN       NaN
# 3                              0.0       6.0
# 4                              NaN       NaN
#
# [5 rows x 798 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 356251 entries, 0 to 356254
# Columns: 798 entries, index to CC_COUNT
# dtypes: bool(133), float64(606), int64(43), object(16)
# memory usage: 1.8+ GB

# %%
#export to csv 
final_df.to_csv("final_df", index=False)

# %% [markdown]
# ## Echantillon 5000lignes

# %%
#import final_df from csv
final_df = pd.read_csv("../data/final_df")

#stratified sampling on final_df dataframe  with 5000 samples
def stratified_sampling(df, n_samples): 
    sample = df.groupby(
        'TARGET', group_keys=False
                        ).apply(lambda x: x.sample(int(np.rint(n_samples*len(x)/len(df))))
                        ).sample(frac=1).reset_index(drop=True)
    return sample

sample_df = stratified_sampling(final_df, 5000)
sample_df.head()
# Out:
#     index  SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0  170578      297693     0.0            1             0                1
# 1  292129      438422     0.0            0             1                0
# 2  174599      302335     0.0            1             0                1
# 3  243687      382092     0.0            1             0                1
# 4  294991      441752     0.0            1             0                0
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  ...  \
# 0             0          134419.5    270000.0      15214.5  ...
# 1             1          180000.0    921330.0      35221.5  ...
# 2             0           90000.0    450000.0      27661.5  ...
# 3             1          180000.0    331632.0      32800.5  ...
# 4             0          112500.0    765000.0      38250.0  ...
#
#    CC_NAME_CONTRACT_STATUS_Signed_MAX  CC_NAME_CONTRACT_STATUS_Signed_MEAN  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_SUM  CC_NAME_CONTRACT_STATUS_Signed_VAR  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_MIN  CC_NAME_CONTRACT_STATUS_nan_MAX  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_MEAN  CC_NAME_CONTRACT_STATUS_nan_SUM  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_VAR  CC_COUNT
# 0                              NaN       NaN
# 1                              NaN       NaN
# 2                              NaN       NaN
# 3                              NaN       NaN
# 4                              NaN       NaN
#
# [5 rows x 798 columns]

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4315 entries, 0 to 4314
# Columns: 798 entries, index to CC_COUNT
# dtypes: bool(133), float64(606), int64(43), object(16)
# memory usage: 22.4+ MB

# %%
sample_df['TARGET'].value_counts()
# Out:
# TARGET
# 0.0    3967
# 1.0     348
# Name: count, dtype: int64

# %% [markdown]
# ## Exploration

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
for col in sample_df.columns:
    print(col)
# Out:
# index
# SK_ID_CURR
# TARGET
# CODE_GENDER
# FLAG_OWN_CAR
# FLAG_OWN_REALTY
# CNT_CHILDREN
# AMT_INCOME_TOTAL
# AMT_CREDIT
# AMT_ANNUITY
# AMT_GOODS_PRICE
# REGION_POPULATION_RELATIVE
# DAYS_BIRTH
# DAYS_EMPLOYED
# DAYS_REGISTRATION
# DAYS_ID_PUBLISH
# OWN_CAR_AGE
# FLAG_MOBIL
# FLAG_EMP_PHONE
# FLAG_WORK_PHONE
# FLAG_CONT_MOBILE
# FLAG_PHONE
# FLAG_EMAIL
# CNT_FAM_MEMBERS
# REGION_RATING_CLIENT
# REGION_RATING_CLIENT_W_CITY
# HOUR_APPR_PROCESS_START
# REG_REGION_NOT_LIVE_REGION
# REG_REGION_NOT_WORK_REGION
# LIVE_REGION_NOT_WORK_REGION
# REG_CITY_NOT_LIVE_CITY
# REG_CITY_NOT_WORK_CITY
# LIVE_CITY_NOT_WORK_CITY
# EXT_SOURCE_1
# EXT_SOURCE_2
# EXT_SOURCE_3
# APARTMENTS_AVG
# BASEMENTAREA_AVG
# YEARS_BEGINEXPLUATATION_AVG
# YEARS_BUILD_AVG
# COMMONAREA_AVG
# ELEVATORS_AVG
# ENTRANCES_AVG
# FLOORSMAX_AVG
# FLOORSMIN_AVG
# LANDAREA_AVG
# LIVINGAPARTMENTS_AVG
# LIVINGAREA_AVG
# NONLIVINGAPARTMENTS_AVG
# NONLIVINGAREA_AVG
# APARTMENTS_MODE
# BASEMENTAREA_MODE
# YEARS_BEGINEXPLUATATION_MODE
# YEARS_BUILD_MODE
# COMMONAREA_MODE
# ELEVATORS_MODE
# ENTRANCES_MODE
# FLOORSMAX_MODE
# FLOORSMIN_MODE
# LANDAREA_MODE
# LIVINGAPARTMENTS_MODE
# LIVINGAREA_MODE
# NONLIVINGAPARTMENTS_MODE
# NONLIVINGAREA_MODE
# APARTMENTS_MEDI
# BASEMENTAREA_MEDI
# YEARS_BEGINEXPLUATATION_MEDI
# YEARS_BUILD_MEDI
# COMMONAREA_MEDI
# ELEVATORS_MEDI
# ENTRANCES_MEDI
# FLOORSMAX_MEDI
# FLOORSMIN_MEDI
# LANDAREA_MEDI
# LIVINGAPARTMENTS_MEDI
# LIVINGAREA_MEDI
# NONLIVINGAPARTMENTS_MEDI
# NONLIVINGAREA_MEDI
# TOTALAREA_MODE
# OBS_30_CNT_SOCIAL_CIRCLE
# DEF_30_CNT_SOCIAL_CIRCLE
# OBS_60_CNT_SOCIAL_CIRCLE
# DEF_60_CNT_SOCIAL_CIRCLE
# DAYS_LAST_PHONE_CHANGE
# FLAG_DOCUMENT_2
# FLAG_DOCUMENT_3
# FLAG_DOCUMENT_4
# FLAG_DOCUMENT_5
# FLAG_DOCUMENT_6
# FLAG_DOCUMENT_7
# FLAG_DOCUMENT_8
# FLAG_DOCUMENT_9
# FLAG_DOCUMENT_10
# FLAG_DOCUMENT_11
# FLAG_DOCUMENT_12
# FLAG_DOCUMENT_13
# FLAG_DOCUMENT_14
# FLAG_DOCUMENT_15
# FLAG_DOCUMENT_16
# FLAG_DOCUMENT_17
# FLAG_DOCUMENT_18
# FLAG_DOCUMENT_19
# FLAG_DOCUMENT_20
# FLAG_DOCUMENT_21
# AMT_REQ_CREDIT_BUREAU_HOUR
# AMT_REQ_CREDIT_BUREAU_DAY
# AMT_REQ_CREDIT_BUREAU_WEEK
# AMT_REQ_CREDIT_BUREAU_MON
# AMT_REQ_CREDIT_BUREAU_QRT
# AMT_REQ_CREDIT_BUREAU_YEAR
# NAME_CONTRACT_TYPE_Cash loans
# NAME_CONTRACT_TYPE_Revolving loans
# NAME_TYPE_SUITE_Children
# NAME_TYPE_SUITE_Family
# NAME_TYPE_SUITE_Group of people
# NAME_TYPE_SUITE_Other_A
# NAME_TYPE_SUITE_Other_B
# NAME_TYPE_SUITE_Spouse, partner
# NAME_TYPE_SUITE_Unaccompanied
# NAME_INCOME_TYPE_Businessman
# NAME_INCOME_TYPE_Commercial associate
# NAME_INCOME_TYPE_Maternity leave
# NAME_INCOME_TYPE_Pensioner
# NAME_INCOME_TYPE_State servant
# NAME_INCOME_TYPE_Student
# NAME_INCOME_TYPE_Unemployed
# NAME_INCOME_TYPE_Working
# NAME_EDUCATION_TYPE_Academic degree
# NAME_EDUCATION_TYPE_Higher education
# NAME_EDUCATION_TYPE_Incomplete higher
# NAME_EDUCATION_TYPE_Lower secondary
# NAME_EDUCATION_TYPE_Secondary / secondary special
# NAME_FAMILY_STATUS_Civil marriage
# NAME_FAMILY_STATUS_Married
# NAME_FAMILY_STATUS_Separated
# NAME_FAMILY_STATUS_Single / not married
# NAME_FAMILY_STATUS_Unknown
# NAME_FAMILY_STATUS_Widow
# NAME_HOUSING_TYPE_Co-op apartment
# NAME_HOUSING_TYPE_House / apartment
# NAME_HOUSING_TYPE_Municipal apartment
# NAME_HOUSING_TYPE_Office apartment
# NAME_HOUSING_TYPE_Rented apartment
# NAME_HOUSING_TYPE_With parents
# OCCUPATION_TYPE_Accountants
# OCCUPATION_TYPE_Cleaning staff
# OCCUPATION_TYPE_Cooking staff
# OCCUPATION_TYPE_Core staff
# OCCUPATION_TYPE_Drivers
# OCCUPATION_TYPE_HR staff
# OCCUPATION_TYPE_High skill tech staff
# OCCUPATION_TYPE_IT staff
# OCCUPATION_TYPE_Laborers
# OCCUPATION_TYPE_Low-skill Laborers
# OCCUPATION_TYPE_Managers
# OCCUPATION_TYPE_Medicine staff
# OCCUPATION_TYPE_Private service staff
# OCCUPATION_TYPE_Realty agents
# OCCUPATION_TYPE_Sales staff
# OCCUPATION_TYPE_Secretaries
# OCCUPATION_TYPE_Security staff
# OCCUPATION_TYPE_Waiters/barmen staff
# WEEKDAY_APPR_PROCESS_START_FRIDAY
# WEEKDAY_APPR_PROCESS_START_MONDAY
# WEEKDAY_APPR_PROCESS_START_SATURDAY
# WEEKDAY_APPR_PROCESS_START_SUNDAY
# WEEKDAY_APPR_PROCESS_START_THURSDAY
# WEEKDAY_APPR_PROCESS_START_TUESDAY
# WEEKDAY_APPR_PROCESS_START_WEDNESDAY
# ORGANIZATION_TYPE_Advertising
# ORGANIZATION_TYPE_Agriculture
# ORGANIZATION_TYPE_Bank
# ORGANIZATION_TYPE_Business Entity Type 1
# ORGANIZATION_TYPE_Business Entity Type 2
# ORGANIZATION_TYPE_Business Entity Type 3
# ORGANIZATION_TYPE_Cleaning
# ORGANIZATION_TYPE_Construction
# ORGANIZATION_TYPE_Culture
# ORGANIZATION_TYPE_Electricity
# ORGANIZATION_TYPE_Emergency
# ORGANIZATION_TYPE_Government
# ORGANIZATION_TYPE_Hotel
# ORGANIZATION_TYPE_Housing
# ORGANIZATION_TYPE_Industry: type 1
# ORGANIZATION_TYPE_Industry: type 10
# ORGANIZATION_TYPE_Industry: type 11
# ORGANIZATION_TYPE_Industry: type 12
# ORGANIZATION_TYPE_Industry: type 13
# ORGANIZATION_TYPE_Industry: type 2
# ORGANIZATION_TYPE_Industry: type 3
# ORGANIZATION_TYPE_Industry: type 4
# ORGANIZATION_TYPE_Industry: type 5
# ORGANIZATION_TYPE_Industry: type 6
# ORGANIZATION_TYPE_Industry: type 7
# ORGANIZATION_TYPE_Industry: type 8
# ORGANIZATION_TYPE_Industry: type 9
# ORGANIZATION_TYPE_Insurance
# ORGANIZATION_TYPE_Kindergarten
# ORGANIZATION_TYPE_Legal Services
# ORGANIZATION_TYPE_Medicine
# ORGANIZATION_TYPE_Military
# ORGANIZATION_TYPE_Mobile
# ORGANIZATION_TYPE_Other
# ORGANIZATION_TYPE_Police
# ORGANIZATION_TYPE_Postal
# ORGANIZATION_TYPE_Realtor
# ORGANIZATION_TYPE_Religion
# ORGANIZATION_TYPE_Restaurant
# ORGANIZATION_TYPE_School
# ORGANIZATION_TYPE_Security
# ORGANIZATION_TYPE_Security Ministries
# ORGANIZATION_TYPE_Self-employed
# ORGANIZATION_TYPE_Services
# ORGANIZATION_TYPE_Telecom
# ORGANIZATION_TYPE_Trade: type 1
# ORGANIZATION_TYPE_Trade: type 2
# ORGANIZATION_TYPE_Trade: type 3
# ORGANIZATION_TYPE_Trade: type 4
# ORGANIZATION_TYPE_Trade: type 5
# ORGANIZATION_TYPE_Trade: type 6
# ORGANIZATION_TYPE_Trade: type 7
# ORGANIZATION_TYPE_Transport: type 1
# ORGANIZATION_TYPE_Transport: type 2
# ORGANIZATION_TYPE_Transport: type 3
# ORGANIZATION_TYPE_Transport: type 4
# ORGANIZATION_TYPE_University
# ORGANIZATION_TYPE_XNA
# FONDKAPREMONT_MODE_not specified
# FONDKAPREMONT_MODE_org spec account
# FONDKAPREMONT_MODE_reg oper account
# FONDKAPREMONT_MODE_reg oper spec account
# HOUSETYPE_MODE_block of flats
# HOUSETYPE_MODE_specific housing
# HOUSETYPE_MODE_terraced house
# WALLSMATERIAL_MODE_Block
# WALLSMATERIAL_MODE_Mixed
# WALLSMATERIAL_MODE_Monolithic
# WALLSMATERIAL_MODE_Others
# WALLSMATERIAL_MODE_Panel
# WALLSMATERIAL_MODE_Stone, brick
# WALLSMATERIAL_MODE_Wooden
# EMERGENCYSTATE_MODE_No
# EMERGENCYSTATE_MODE_Yes
# DAYS_EMPLOYED_PERC
# INCOME_CREDIT_PERC
# INCOME_PER_PERSON
# ANNUITY_INCOME_PERC
# PAYMENT_RATE
# BURO_DAYS_CREDIT_MIN
# BURO_DAYS_CREDIT_MAX
# BURO_DAYS_CREDIT_MEAN
# BURO_DAYS_CREDIT_VAR
# BURO_DAYS_CREDIT_ENDDATE_MIN
# BURO_DAYS_CREDIT_ENDDATE_MAX
# BURO_DAYS_CREDIT_ENDDATE_MEAN
# BURO_DAYS_CREDIT_UPDATE_MEAN
# BURO_CREDIT_DAY_OVERDUE_MAX
# BURO_CREDIT_DAY_OVERDUE_MEAN
# BURO_AMT_CREDIT_MAX_OVERDUE_MEAN
# BURO_AMT_CREDIT_SUM_MAX
# BURO_AMT_CREDIT_SUM_MEAN
# BURO_AMT_CREDIT_SUM_SUM
# BURO_AMT_CREDIT_SUM_DEBT_MAX
# BURO_AMT_CREDIT_SUM_DEBT_MEAN
# BURO_AMT_CREDIT_SUM_DEBT_SUM
# BURO_AMT_CREDIT_SUM_OVERDUE_MEAN
# BURO_AMT_CREDIT_SUM_LIMIT_MEAN
# BURO_AMT_CREDIT_SUM_LIMIT_SUM
# BURO_AMT_ANNUITY_MAX
# BURO_AMT_ANNUITY_MEAN
# BURO_CNT_CREDIT_PROLONG_SUM
# BURO_MONTHS_BALANCE_MIN_MIN
# BURO_MONTHS_BALANCE_MAX_MAX
# BURO_MONTHS_BALANCE_SIZE_MEAN
# BURO_MONTHS_BALANCE_SIZE_SUM
# BURO_CREDIT_ACTIVE_Active_MEAN
# BURO_CREDIT_ACTIVE_Bad debt_MEAN
# BURO_CREDIT_ACTIVE_Closed_MEAN
# BURO_CREDIT_ACTIVE_Sold_MEAN
# BURO_CREDIT_ACTIVE_nan_MEAN
# BURO_CREDIT_CURRENCY_currency 1_MEAN
# BURO_CREDIT_CURRENCY_currency 2_MEAN
# BURO_CREDIT_CURRENCY_currency 3_MEAN
# BURO_CREDIT_CURRENCY_currency 4_MEAN
# BURO_CREDIT_CURRENCY_nan_MEAN
# BURO_CREDIT_TYPE_Another type of loan_MEAN
# BURO_CREDIT_TYPE_Car loan_MEAN
# BURO_CREDIT_TYPE_Cash loan (non-earmarked)_MEAN
# BURO_CREDIT_TYPE_Consumer credit_MEAN
# BURO_CREDIT_TYPE_Credit card_MEAN
# BURO_CREDIT_TYPE_Interbank credit_MEAN
# BURO_CREDIT_TYPE_Loan for business development_MEAN
# BURO_CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN
# BURO_CREDIT_TYPE_Loan for the purchase of equipment_MEAN
# BURO_CREDIT_TYPE_Loan for working capital replenishment_MEAN
# BURO_CREDIT_TYPE_Microloan_MEAN
# BURO_CREDIT_TYPE_Mobile operator loan_MEAN
# BURO_CREDIT_TYPE_Mortgage_MEAN
# BURO_CREDIT_TYPE_Real estate loan_MEAN
# BURO_CREDIT_TYPE_Unknown type of loan_MEAN
# BURO_CREDIT_TYPE_nan_MEAN
# BURO_STATUS_0_MEAN_MEAN
# BURO_STATUS_1_MEAN_MEAN
# BURO_STATUS_2_MEAN_MEAN
# BURO_STATUS_3_MEAN_MEAN
# BURO_STATUS_4_MEAN_MEAN
# BURO_STATUS_5_MEAN_MEAN
# BURO_STATUS_C_MEAN_MEAN
# BURO_STATUS_X_MEAN_MEAN
# BURO_STATUS_nan_MEAN_MEAN
# ACTIVE_DAYS_CREDIT_MIN
# ACTIVE_DAYS_CREDIT_MAX
# ACTIVE_DAYS_CREDIT_MEAN
# ACTIVE_DAYS_CREDIT_VAR
# ACTIVE_DAYS_CREDIT_ENDDATE_MIN
# ACTIVE_DAYS_CREDIT_ENDDATE_MAX
# ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
# ACTIVE_DAYS_CREDIT_UPDATE_MEAN
# ACTIVE_CREDIT_DAY_OVERDUE_MAX
# ACTIVE_CREDIT_DAY_OVERDUE_MEAN
# ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN
# ACTIVE_AMT_CREDIT_SUM_MAX
# ACTIVE_AMT_CREDIT_SUM_MEAN
# ACTIVE_AMT_CREDIT_SUM_SUM
# ACTIVE_AMT_CREDIT_SUM_DEBT_MAX
# ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN
# ACTIVE_AMT_CREDIT_SUM_DEBT_SUM
# ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN
# ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN
# ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM
# ACTIVE_AMT_ANNUITY_MAX
# ACTIVE_AMT_ANNUITY_MEAN
# ACTIVE_CNT_CREDIT_PROLONG_SUM
# ACTIVE_MONTHS_BALANCE_MIN_MIN
# ACTIVE_MONTHS_BALANCE_MAX_MAX
# ACTIVE_MONTHS_BALANCE_SIZE_MEAN
# ACTIVE_MONTHS_BALANCE_SIZE_SUM
# CLOSED_DAYS_CREDIT_MIN
# CLOSED_DAYS_CREDIT_MAX
# CLOSED_DAYS_CREDIT_MEAN
# CLOSED_DAYS_CREDIT_VAR
# CLOSED_DAYS_CREDIT_ENDDATE_MIN
# CLOSED_DAYS_CREDIT_ENDDATE_MAX
# CLOSED_DAYS_CREDIT_ENDDATE_MEAN
# CLOSED_DAYS_CREDIT_UPDATE_MEAN
# CLOSED_CREDIT_DAY_OVERDUE_MAX
# CLOSED_CREDIT_DAY_OVERDUE_MEAN
# CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN
# CLOSED_AMT_CREDIT_SUM_MAX
# CLOSED_AMT_CREDIT_SUM_MEAN
# CLOSED_AMT_CREDIT_SUM_SUM
# CLOSED_AMT_CREDIT_SUM_DEBT_MAX
# CLOSED_AMT_CREDIT_SUM_DEBT_MEAN
# CLOSED_AMT_CREDIT_SUM_DEBT_SUM
# CLOSED_AMT_CREDIT_SUM_OVERDUE_MEAN
# CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN
# CLOSED_AMT_CREDIT_SUM_LIMIT_SUM
# CLOSED_AMT_ANNUITY_MAX
# CLOSED_AMT_ANNUITY_MEAN
# CLOSED_CNT_CREDIT_PROLONG_SUM
# CLOSED_MONTHS_BALANCE_MIN_MIN
# CLOSED_MONTHS_BALANCE_MAX_MAX
# CLOSED_MONTHS_BALANCE_SIZE_MEAN
# CLOSED_MONTHS_BALANCE_SIZE_SUM
# PREV_AMT_ANNUITY_MIN
# PREV_AMT_ANNUITY_MAX
# PREV_AMT_ANNUITY_MEAN
# PREV_AMT_APPLICATION_MIN
# PREV_AMT_APPLICATION_MAX
# PREV_AMT_APPLICATION_MEAN
# PREV_AMT_CREDIT_MIN
# PREV_AMT_CREDIT_MAX
# PREV_AMT_CREDIT_MEAN
# PREV_APP_CREDIT_PERC_MIN
# PREV_APP_CREDIT_PERC_MAX
# PREV_APP_CREDIT_PERC_MEAN
# PREV_APP_CREDIT_PERC_VAR
# PREV_AMT_DOWN_PAYMENT_MIN
# PREV_AMT_DOWN_PAYMENT_MAX
# PREV_AMT_DOWN_PAYMENT_MEAN
# PREV_AMT_GOODS_PRICE_MIN
# PREV_AMT_GOODS_PRICE_MAX
# PREV_AMT_GOODS_PRICE_MEAN
# PREV_HOUR_APPR_PROCESS_START_MIN
# PREV_HOUR_APPR_PROCESS_START_MAX
# PREV_HOUR_APPR_PROCESS_START_MEAN
# PREV_RATE_DOWN_PAYMENT_MIN
# PREV_RATE_DOWN_PAYMENT_MAX
# PREV_RATE_DOWN_PAYMENT_MEAN
# PREV_DAYS_DECISION_MIN
# PREV_DAYS_DECISION_MAX
# PREV_DAYS_DECISION_MEAN
# PREV_CNT_PAYMENT_MEAN
# PREV_CNT_PAYMENT_SUM
# PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN
# PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN
# PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN
# PREV_NAME_CONTRACT_TYPE_XNA_MEAN
# PREV_NAME_CONTRACT_TYPE_nan_MEAN
# PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN
# PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN
# PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN
# PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN
# PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN
# PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN
# PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN
# PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN
# PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN
# PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN
# PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN
# PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN
# PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# PREV_NAME_CONTRACT_STATUS_Canceled_MEAN
# PREV_NAME_CONTRACT_STATUS_Refused_MEAN
# PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN
# PREV_NAME_CONTRACT_STATUS_nan_MEAN
# PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN
# PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN
# PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN
# PREV_NAME_PAYMENT_TYPE_XNA_MEAN
# PREV_NAME_PAYMENT_TYPE_nan_MEAN
# PREV_CODE_REJECT_REASON_CLIENT_MEAN
# PREV_CODE_REJECT_REASON_HC_MEAN
# PREV_CODE_REJECT_REASON_LIMIT_MEAN
# PREV_CODE_REJECT_REASON_SCO_MEAN
# PREV_CODE_REJECT_REASON_SCOFR_MEAN
# PREV_CODE_REJECT_REASON_SYSTEM_MEAN
# PREV_CODE_REJECT_REASON_VERIF_MEAN
# PREV_CODE_REJECT_REASON_XAP_MEAN
# PREV_CODE_REJECT_REASON_XNA_MEAN
# PREV_CODE_REJECT_REASON_nan_MEAN
# PREV_NAME_TYPE_SUITE_Children_MEAN
# PREV_NAME_TYPE_SUITE_Family_MEAN
# PREV_NAME_TYPE_SUITE_Group of people_MEAN
# PREV_NAME_TYPE_SUITE_Other_A_MEAN
# PREV_NAME_TYPE_SUITE_Other_B_MEAN
# PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN
# PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN
# PREV_NAME_TYPE_SUITE_nan_MEAN
# PREV_NAME_CLIENT_TYPE_New_MEAN
# PREV_NAME_CLIENT_TYPE_Refreshed_MEAN
# PREV_NAME_CLIENT_TYPE_Repeater_MEAN
# PREV_NAME_CLIENT_TYPE_XNA_MEAN
# PREV_NAME_CLIENT_TYPE_nan_MEAN
# PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN
# PREV_NAME_GOODS_CATEGORY_Animals_MEAN
# PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN
# PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN
# PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN
# PREV_NAME_GOODS_CATEGORY_Computers_MEAN
# PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN
# PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN
# PREV_NAME_GOODS_CATEGORY_Direct Sales_MEAN
# PREV_NAME_GOODS_CATEGORY_Education_MEAN
# PREV_NAME_GOODS_CATEGORY_Fitness_MEAN
# PREV_NAME_GOODS_CATEGORY_Furniture_MEAN
# PREV_NAME_GOODS_CATEGORY_Gardening_MEAN
# PREV_NAME_GOODS_CATEGORY_Homewares_MEAN
# PREV_NAME_GOODS_CATEGORY_House Construction_MEAN
# PREV_NAME_GOODS_CATEGORY_Insurance_MEAN
# PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN
# PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN
# PREV_NAME_GOODS_CATEGORY_Medicine_MEAN
# PREV_NAME_GOODS_CATEGORY_Mobile_MEAN
# PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN
# PREV_NAME_GOODS_CATEGORY_Other_MEAN
# PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN
# PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN
# PREV_NAME_GOODS_CATEGORY_Tourism_MEAN
# PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN
# PREV_NAME_GOODS_CATEGORY_Weapon_MEAN
# PREV_NAME_GOODS_CATEGORY_XNA_MEAN
# PREV_NAME_GOODS_CATEGORY_nan_MEAN
# PREV_NAME_PORTFOLIO_Cards_MEAN
# PREV_NAME_PORTFOLIO_Cars_MEAN
# PREV_NAME_PORTFOLIO_Cash_MEAN
# PREV_NAME_PORTFOLIO_POS_MEAN
# PREV_NAME_PORTFOLIO_XNA_MEAN
# PREV_NAME_PORTFOLIO_nan_MEAN
# PREV_NAME_PRODUCT_TYPE_XNA_MEAN
# PREV_NAME_PRODUCT_TYPE_walk-in_MEAN
# PREV_NAME_PRODUCT_TYPE_x-sell_MEAN
# PREV_NAME_PRODUCT_TYPE_nan_MEAN
# PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN
# PREV_CHANNEL_TYPE_Car dealer_MEAN
# PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN
# PREV_CHANNEL_TYPE_Contact center_MEAN
# PREV_CHANNEL_TYPE_Country-wide_MEAN
# PREV_CHANNEL_TYPE_Credit and cash offices_MEAN
# PREV_CHANNEL_TYPE_Regional / Local_MEAN
# PREV_CHANNEL_TYPE_Stone_MEAN
# PREV_CHANNEL_TYPE_nan_MEAN
# PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN
# PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN
# PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN
# PREV_NAME_SELLER_INDUSTRY_Construction_MEAN
# PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN
# PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN
# PREV_NAME_SELLER_INDUSTRY_Industry_MEAN
# PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN
# PREV_NAME_SELLER_INDUSTRY_MLM partners_MEAN
# PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN
# PREV_NAME_SELLER_INDUSTRY_XNA_MEAN
# PREV_NAME_SELLER_INDUSTRY_nan_MEAN
# PREV_NAME_YIELD_GROUP_XNA_MEAN
# PREV_NAME_YIELD_GROUP_high_MEAN
# PREV_NAME_YIELD_GROUP_low_action_MEAN
# PREV_NAME_YIELD_GROUP_low_normal_MEAN
# PREV_NAME_YIELD_GROUP_middle_MEAN
# PREV_NAME_YIELD_GROUP_nan_MEAN
# PREV_PRODUCT_COMBINATION_Card Street_MEAN
# PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN
# PREV_PRODUCT_COMBINATION_Cash_MEAN
# PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN
# PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN
# PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN
# PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN
# PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN
# PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN
# PREV_PRODUCT_COMBINATION_POS household with interest_MEAN
# PREV_PRODUCT_COMBINATION_POS household without interest_MEAN
# PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN
# PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN
# PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN
# PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN
# PREV_PRODUCT_COMBINATION_POS other with interest_MEAN
# PREV_PRODUCT_COMBINATION_POS others without interest_MEAN
# PREV_PRODUCT_COMBINATION_nan_MEAN
# APPROVED_AMT_ANNUITY_MIN
# APPROVED_AMT_ANNUITY_MAX
# APPROVED_AMT_ANNUITY_MEAN
# APPROVED_AMT_APPLICATION_MIN
# APPROVED_AMT_APPLICATION_MAX
# APPROVED_AMT_APPLICATION_MEAN
# APPROVED_AMT_CREDIT_MIN
# APPROVED_AMT_CREDIT_MAX
# APPROVED_AMT_CREDIT_MEAN
# APPROVED_APP_CREDIT_PERC_MIN
# APPROVED_APP_CREDIT_PERC_MAX
# APPROVED_APP_CREDIT_PERC_MEAN
# APPROVED_APP_CREDIT_PERC_VAR
# APPROVED_AMT_DOWN_PAYMENT_MIN
# APPROVED_AMT_DOWN_PAYMENT_MAX
# APPROVED_AMT_DOWN_PAYMENT_MEAN
# APPROVED_AMT_GOODS_PRICE_MIN
# APPROVED_AMT_GOODS_PRICE_MAX
# APPROVED_AMT_GOODS_PRICE_MEAN
# APPROVED_HOUR_APPR_PROCESS_START_MIN
# APPROVED_HOUR_APPR_PROCESS_START_MAX
# APPROVED_HOUR_APPR_PROCESS_START_MEAN
# APPROVED_RATE_DOWN_PAYMENT_MIN
# APPROVED_RATE_DOWN_PAYMENT_MAX
# APPROVED_RATE_DOWN_PAYMENT_MEAN
# APPROVED_DAYS_DECISION_MIN
# APPROVED_DAYS_DECISION_MAX
# APPROVED_DAYS_DECISION_MEAN
# APPROVED_CNT_PAYMENT_MEAN
# APPROVED_CNT_PAYMENT_SUM
# REFUSED_AMT_ANNUITY_MIN
# REFUSED_AMT_ANNUITY_MAX
# REFUSED_AMT_ANNUITY_MEAN
# REFUSED_AMT_APPLICATION_MIN
# REFUSED_AMT_APPLICATION_MAX
# REFUSED_AMT_APPLICATION_MEAN
# REFUSED_AMT_CREDIT_MIN
# REFUSED_AMT_CREDIT_MAX
# REFUSED_AMT_CREDIT_MEAN
# REFUSED_APP_CREDIT_PERC_MIN
# REFUSED_APP_CREDIT_PERC_MAX
# REFUSED_APP_CREDIT_PERC_MEAN
# REFUSED_APP_CREDIT_PERC_VAR
# REFUSED_AMT_DOWN_PAYMENT_MIN
# REFUSED_AMT_DOWN_PAYMENT_MAX
# REFUSED_AMT_DOWN_PAYMENT_MEAN
# REFUSED_AMT_GOODS_PRICE_MIN
# REFUSED_AMT_GOODS_PRICE_MAX
# REFUSED_AMT_GOODS_PRICE_MEAN
# REFUSED_HOUR_APPR_PROCESS_START_MIN
# REFUSED_HOUR_APPR_PROCESS_START_MAX
# REFUSED_HOUR_APPR_PROCESS_START_MEAN
# REFUSED_RATE_DOWN_PAYMENT_MIN
# REFUSED_RATE_DOWN_PAYMENT_MAX
# REFUSED_RATE_DOWN_PAYMENT_MEAN
# REFUSED_DAYS_DECISION_MIN
# REFUSED_DAYS_DECISION_MAX
# REFUSED_DAYS_DECISION_MEAN
# REFUSED_CNT_PAYMENT_MEAN
# REFUSED_CNT_PAYMENT_SUM
# POS_MONTHS_BALANCE_MAX
# POS_MONTHS_BALANCE_MEAN
# POS_MONTHS_BALANCE_SIZE
# POS_SK_DPD_MAX
# POS_SK_DPD_MEAN
# POS_SK_DPD_DEF_MAX
# POS_SK_DPD_DEF_MEAN
# POS_NAME_CONTRACT_STATUS_Active_MEAN
# POS_NAME_CONTRACT_STATUS_Amortized debt_MEAN
# POS_NAME_CONTRACT_STATUS_Approved_MEAN
# POS_NAME_CONTRACT_STATUS_Canceled_MEAN
# POS_NAME_CONTRACT_STATUS_Completed_MEAN
# POS_NAME_CONTRACT_STATUS_Demand_MEAN
# POS_NAME_CONTRACT_STATUS_Returned to the store_MEAN
# POS_NAME_CONTRACT_STATUS_Signed_MEAN
# POS_NAME_CONTRACT_STATUS_XNA_MEAN
# POS_NAME_CONTRACT_STATUS_nan_MEAN
# POS_COUNT
# INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE
# INSTAL_DPD_MAX
# INSTAL_DPD_MEAN
# INSTAL_DPD_SUM
# INSTAL_DBD_MAX
# INSTAL_DBD_MEAN
# INSTAL_DBD_SUM
# INSTAL_PAYMENT_PERC_MAX
# INSTAL_PAYMENT_PERC_MEAN
# INSTAL_PAYMENT_PERC_SUM
# INSTAL_PAYMENT_PERC_VAR
# INSTAL_PAYMENT_DIFF_MAX
# INSTAL_PAYMENT_DIFF_MEAN
# INSTAL_PAYMENT_DIFF_SUM
# INSTAL_PAYMENT_DIFF_VAR
# INSTAL_AMT_INSTALMENT_MAX
# INSTAL_AMT_INSTALMENT_MEAN
# INSTAL_AMT_INSTALMENT_SUM
# INSTAL_AMT_PAYMENT_MIN
# INSTAL_AMT_PAYMENT_MAX
# INSTAL_AMT_PAYMENT_MEAN
# INSTAL_AMT_PAYMENT_SUM
# INSTAL_DAYS_ENTRY_PAYMENT_MAX
# INSTAL_DAYS_ENTRY_PAYMENT_MEAN
# INSTAL_DAYS_ENTRY_PAYMENT_SUM
# INSTAL_COUNT
# CC_MONTHS_BALANCE_MIN
# CC_MONTHS_BALANCE_MAX
# CC_MONTHS_BALANCE_MEAN
# CC_MONTHS_BALANCE_SUM
# CC_MONTHS_BALANCE_VAR
# CC_AMT_BALANCE_MIN
# CC_AMT_BALANCE_MAX
# CC_AMT_BALANCE_MEAN
# CC_AMT_BALANCE_SUM
# CC_AMT_BALANCE_VAR
# CC_AMT_CREDIT_LIMIT_ACTUAL_MIN
# CC_AMT_CREDIT_LIMIT_ACTUAL_MAX
# CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN
# CC_AMT_CREDIT_LIMIT_ACTUAL_SUM
# CC_AMT_CREDIT_LIMIT_ACTUAL_VAR
# CC_AMT_DRAWINGS_ATM_CURRENT_MIN
# CC_AMT_DRAWINGS_ATM_CURRENT_MAX
# CC_AMT_DRAWINGS_ATM_CURRENT_MEAN
# CC_AMT_DRAWINGS_ATM_CURRENT_SUM
# CC_AMT_DRAWINGS_ATM_CURRENT_VAR
# CC_AMT_DRAWINGS_CURRENT_MIN
# CC_AMT_DRAWINGS_CURRENT_MAX
# CC_AMT_DRAWINGS_CURRENT_MEAN
# CC_AMT_DRAWINGS_CURRENT_SUM
# CC_AMT_DRAWINGS_CURRENT_VAR
# CC_AMT_DRAWINGS_OTHER_CURRENT_MIN
# CC_AMT_DRAWINGS_OTHER_CURRENT_MAX
# CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN
# CC_AMT_DRAWINGS_OTHER_CURRENT_SUM
# CC_AMT_DRAWINGS_OTHER_CURRENT_VAR
# CC_AMT_DRAWINGS_POS_CURRENT_MIN
# CC_AMT_DRAWINGS_POS_CURRENT_MAX
# CC_AMT_DRAWINGS_POS_CURRENT_MEAN
# CC_AMT_DRAWINGS_POS_CURRENT_SUM
# CC_AMT_DRAWINGS_POS_CURRENT_VAR
# CC_AMT_INST_MIN_REGULARITY_MIN
# CC_AMT_INST_MIN_REGULARITY_MAX
# CC_AMT_INST_MIN_REGULARITY_MEAN
# CC_AMT_INST_MIN_REGULARITY_SUM
# CC_AMT_INST_MIN_REGULARITY_VAR
# CC_AMT_PAYMENT_CURRENT_MIN
# CC_AMT_PAYMENT_CURRENT_MAX
# CC_AMT_PAYMENT_CURRENT_MEAN
# CC_AMT_PAYMENT_CURRENT_SUM
# CC_AMT_PAYMENT_CURRENT_VAR
# CC_AMT_PAYMENT_TOTAL_CURRENT_MIN
# CC_AMT_PAYMENT_TOTAL_CURRENT_MAX
# CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN
# CC_AMT_PAYMENT_TOTAL_CURRENT_SUM
# CC_AMT_PAYMENT_TOTAL_CURRENT_VAR
# CC_AMT_RECEIVABLE_PRINCIPAL_MIN
# CC_AMT_RECEIVABLE_PRINCIPAL_MAX
# CC_AMT_RECEIVABLE_PRINCIPAL_MEAN
# CC_AMT_RECEIVABLE_PRINCIPAL_SUM
# CC_AMT_RECEIVABLE_PRINCIPAL_VAR
# CC_AMT_RECIVABLE_MIN
# CC_AMT_RECIVABLE_MAX
# CC_AMT_RECIVABLE_MEAN
# CC_AMT_RECIVABLE_SUM
# CC_AMT_RECIVABLE_VAR
# CC_AMT_TOTAL_RECEIVABLE_MIN
# CC_AMT_TOTAL_RECEIVABLE_MAX
# CC_AMT_TOTAL_RECEIVABLE_MEAN
# CC_AMT_TOTAL_RECEIVABLE_SUM
# CC_AMT_TOTAL_RECEIVABLE_VAR
# CC_CNT_DRAWINGS_ATM_CURRENT_MIN
# CC_CNT_DRAWINGS_ATM_CURRENT_MAX
# CC_CNT_DRAWINGS_ATM_CURRENT_MEAN
# CC_CNT_DRAWINGS_ATM_CURRENT_SUM
# CC_CNT_DRAWINGS_ATM_CURRENT_VAR
# CC_CNT_DRAWINGS_CURRENT_MIN
# CC_CNT_DRAWINGS_CURRENT_MAX
# CC_CNT_DRAWINGS_CURRENT_MEAN
# CC_CNT_DRAWINGS_CURRENT_SUM
# CC_CNT_DRAWINGS_CURRENT_VAR
# CC_CNT_DRAWINGS_OTHER_CURRENT_MIN
# CC_CNT_DRAWINGS_OTHER_CURRENT_MAX
# CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN
# CC_CNT_DRAWINGS_OTHER_CURRENT_SUM
# CC_CNT_DRAWINGS_OTHER_CURRENT_VAR
# CC_CNT_DRAWINGS_POS_CURRENT_MIN
# CC_CNT_DRAWINGS_POS_CURRENT_MAX
# CC_CNT_DRAWINGS_POS_CURRENT_MEAN
# CC_CNT_DRAWINGS_POS_CURRENT_SUM
# CC_CNT_DRAWINGS_POS_CURRENT_VAR
# CC_CNT_INSTALMENT_MATURE_CUM_MIN
# CC_CNT_INSTALMENT_MATURE_CUM_MAX
# CC_CNT_INSTALMENT_MATURE_CUM_MEAN
# CC_CNT_INSTALMENT_MATURE_CUM_SUM
# CC_CNT_INSTALMENT_MATURE_CUM_VAR
# CC_SK_DPD_MIN
# CC_SK_DPD_MAX
# CC_SK_DPD_MEAN
# CC_SK_DPD_SUM
# CC_SK_DPD_VAR
# CC_SK_DPD_DEF_MIN
# CC_SK_DPD_DEF_MAX
# CC_SK_DPD_DEF_MEAN
# CC_SK_DPD_DEF_SUM
# CC_SK_DPD_DEF_VAR
# CC_NAME_CONTRACT_STATUS_Active_MIN
# CC_NAME_CONTRACT_STATUS_Active_MAX
# CC_NAME_CONTRACT_STATUS_Active_MEAN
# CC_NAME_CONTRACT_STATUS_Active_SUM
# CC_NAME_CONTRACT_STATUS_Active_VAR
# CC_NAME_CONTRACT_STATUS_Approved_MIN
# CC_NAME_CONTRACT_STATUS_Approved_MAX
# CC_NAME_CONTRACT_STATUS_Approved_MEAN
# CC_NAME_CONTRACT_STATUS_Approved_SUM
# CC_NAME_CONTRACT_STATUS_Approved_VAR
# CC_NAME_CONTRACT_STATUS_Completed_MIN
# CC_NAME_CONTRACT_STATUS_Completed_MAX
# CC_NAME_CONTRACT_STATUS_Completed_MEAN
# CC_NAME_CONTRACT_STATUS_Completed_SUM
# CC_NAME_CONTRACT_STATUS_Completed_VAR
# CC_NAME_CONTRACT_STATUS_Demand_MIN
# CC_NAME_CONTRACT_STATUS_Demand_MAX
# CC_NAME_CONTRACT_STATUS_Demand_MEAN
# CC_NAME_CONTRACT_STATUS_Demand_SUM
# CC_NAME_CONTRACT_STATUS_Demand_VAR
# CC_NAME_CONTRACT_STATUS_Refused_MIN
# CC_NAME_CONTRACT_STATUS_Refused_MAX
# CC_NAME_CONTRACT_STATUS_Refused_MEAN
# CC_NAME_CONTRACT_STATUS_Refused_SUM
# CC_NAME_CONTRACT_STATUS_Refused_VAR
# CC_NAME_CONTRACT_STATUS_Sent proposal_MIN
# CC_NAME_CONTRACT_STATUS_Sent proposal_MAX
# CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN
# CC_NAME_CONTRACT_STATUS_Sent proposal_SUM
# CC_NAME_CONTRACT_STATUS_Sent proposal_VAR
# CC_NAME_CONTRACT_STATUS_Signed_MIN
# CC_NAME_CONTRACT_STATUS_Signed_MAX
# CC_NAME_CONTRACT_STATUS_Signed_MEAN
# CC_NAME_CONTRACT_STATUS_Signed_SUM
# CC_NAME_CONTRACT_STATUS_Signed_VAR
# CC_NAME_CONTRACT_STATUS_nan_MIN
# CC_NAME_CONTRACT_STATUS_nan_MAX
# CC_NAME_CONTRACT_STATUS_nan_MEAN
# CC_NAME_CONTRACT_STATUS_nan_SUM
# CC_NAME_CONTRACT_STATUS_nan_VAR
# CC_COUNT

# %%
sample_df['TARGET'].value_counts()
# Out:
# TARGET
# 0.0    3967
# 1.0     348
# Name: count, dtype: int64

# %%
print(sample_df.isna().sum())
# Out:
# index                                                                       0
# SK_ID_CURR                                                                  0
# TARGET                                                                      0
# CODE_GENDER                                                                 0
# FLAG_OWN_CAR                                                                0
# FLAG_OWN_REALTY                                                             0
# CNT_CHILDREN                                                                0
# AMT_INCOME_TOTAL                                                            0
# AMT_CREDIT                                                                  0
# AMT_ANNUITY                                                                 0
# AMT_GOODS_PRICE                                                             1
# REGION_POPULATION_RELATIVE                                                  0
# DAYS_BIRTH                                                                  0
# DAYS_EMPLOYED                                                             811
# DAYS_REGISTRATION                                                           0
# DAYS_ID_PUBLISH                                                             0
# OWN_CAR_AGE                                                              2814
# FLAG_MOBIL                                                                  0
# FLAG_EMP_PHONE                                                              0
# FLAG_WORK_PHONE                                                             0
# FLAG_CONT_MOBILE                                                            0
# FLAG_PHONE                                                                  0
# FLAG_EMAIL                                                                  0
# CNT_FAM_MEMBERS                                                             0
# REGION_RATING_CLIENT                                                        0
# REGION_RATING_CLIENT_W_CITY                                                 0
# HOUR_APPR_PROCESS_START                                                     0
# REG_REGION_NOT_LIVE_REGION                                                  0
# REG_REGION_NOT_WORK_REGION                                                  0
# LIVE_REGION_NOT_WORK_REGION                                                 0
# REG_CITY_NOT_LIVE_CITY                                                      0
# REG_CITY_NOT_WORK_CITY                                                      0
# LIVE_CITY_NOT_WORK_CITY                                                     0
# EXT_SOURCE_1                                                             2446
# EXT_SOURCE_2                                                               10
# EXT_SOURCE_3                                                              856
# APARTMENTS_AVG                                                           2209
# BASEMENTAREA_AVG                                                         2532
# YEARS_BEGINEXPLUATATION_AVG                                              2128
# YEARS_BUILD_AVG                                                          2898
# COMMONAREA_AVG                                                           3054
# ELEVATORS_AVG                                                            2324
# ENTRANCES_AVG                                                            2203
# FLOORSMAX_AVG                                                            2171
# FLOORSMIN_AVG                                                            2964
# LANDAREA_AVG                                                             2567
# LIVINGAPARTMENTS_AVG                                                     2973
# LIVINGAREA_AVG                                                           2181
# NONLIVINGAPARTMENTS_AVG                                                  3023
# NONLIVINGAREA_AVG                                                        2401
# APARTMENTS_MODE                                                          2209
# BASEMENTAREA_MODE                                                        2532
# YEARS_BEGINEXPLUATATION_MODE                                             2128
# YEARS_BUILD_MODE                                                         2898
# COMMONAREA_MODE                                                          3054
# ELEVATORS_MODE                                                           2324
# ENTRANCES_MODE                                                           2203
# FLOORSMAX_MODE                                                           2171
# FLOORSMIN_MODE                                                           2964
# LANDAREA_MODE                                                            2567
# LIVINGAPARTMENTS_MODE                                                    2973
# LIVINGAREA_MODE                                                          2181
# NONLIVINGAPARTMENTS_MODE                                                 3023
# NONLIVINGAREA_MODE                                                       2401
# APARTMENTS_MEDI                                                          2209
# BASEMENTAREA_MEDI                                                        2532
# YEARS_BEGINEXPLUATATION_MEDI                                             2128
# YEARS_BUILD_MEDI                                                         2898
# COMMONAREA_MEDI                                                          3054
# ELEVATORS_MEDI                                                           2324
# ENTRANCES_MEDI                                                           2203
# FLOORSMAX_MEDI                                                           2171
# FLOORSMIN_MEDI                                                           2964
# LANDAREA_MEDI                                                            2567
# LIVINGAPARTMENTS_MEDI                                                    2973
# LIVINGAREA_MEDI                                                          2181
# NONLIVINGAPARTMENTS_MEDI                                                 3023
# NONLIVINGAREA_MEDI                                                       2401
# TOTALAREA_MODE                                                           2104
# OBS_30_CNT_SOCIAL_CIRCLE                                                   13
# DEF_30_CNT_SOCIAL_CIRCLE                                                   13
# OBS_60_CNT_SOCIAL_CIRCLE                                                   13
# DEF_60_CNT_SOCIAL_CIRCLE                                                   13
# DAYS_LAST_PHONE_CHANGE                                                      0
# FLAG_DOCUMENT_2                                                             0
# FLAG_DOCUMENT_3                                                             0
# FLAG_DOCUMENT_4                                                             0
# FLAG_DOCUMENT_5                                                             0
# FLAG_DOCUMENT_6                                                             0
# FLAG_DOCUMENT_7                                                             0
# FLAG_DOCUMENT_8                                                             0
# FLAG_DOCUMENT_9                                                             0
# FLAG_DOCUMENT_10                                                            0
# FLAG_DOCUMENT_11                                                            0
# FLAG_DOCUMENT_12                                                            0
# FLAG_DOCUMENT_13                                                            0
# FLAG_DOCUMENT_14                                                            0
# FLAG_DOCUMENT_15                                                            0
# FLAG_DOCUMENT_16                                                            0
# FLAG_DOCUMENT_17                                                            0
# FLAG_DOCUMENT_18                                                            0
# FLAG_DOCUMENT_19                                                            0
# FLAG_DOCUMENT_20                                                            0
# FLAG_DOCUMENT_21                                                            0
# AMT_REQ_CREDIT_BUREAU_HOUR                                                594
# AMT_REQ_CREDIT_BUREAU_DAY                                                 594
# AMT_REQ_CREDIT_BUREAU_WEEK                                                594
# AMT_REQ_CREDIT_BUREAU_MON                                                 594
# AMT_REQ_CREDIT_BUREAU_QRT                                                 594
# AMT_REQ_CREDIT_BUREAU_YEAR                                                594
# NAME_CONTRACT_TYPE_Cash loans                                               0
# NAME_CONTRACT_TYPE_Revolving loans                                          0
# NAME_TYPE_SUITE_Children                                                    0
# NAME_TYPE_SUITE_Family                                                      0
# NAME_TYPE_SUITE_Group of people                                             0
# NAME_TYPE_SUITE_Other_A                                                     0
# NAME_TYPE_SUITE_Other_B                                                     0
# NAME_TYPE_SUITE_Spouse, partner                                             0
# NAME_TYPE_SUITE_Unaccompanied                                               0
# NAME_INCOME_TYPE_Businessman                                                0
# NAME_INCOME_TYPE_Commercial associate                                       0
# NAME_INCOME_TYPE_Maternity leave                                            0
# NAME_INCOME_TYPE_Pensioner                                                  0
# NAME_INCOME_TYPE_State servant                                              0
# NAME_INCOME_TYPE_Student                                                    0
# NAME_INCOME_TYPE_Unemployed                                                 0
# NAME_INCOME_TYPE_Working                                                    0
# NAME_EDUCATION_TYPE_Academic degree                                         0
# NAME_EDUCATION_TYPE_Higher education                                        0
# NAME_EDUCATION_TYPE_Incomplete higher                                       0
# NAME_EDUCATION_TYPE_Lower secondary                                         0
# NAME_EDUCATION_TYPE_Secondary / secondary special                           0
# NAME_FAMILY_STATUS_Civil marriage                                           0
# NAME_FAMILY_STATUS_Married                                                  0
# NAME_FAMILY_STATUS_Separated                                                0
# NAME_FAMILY_STATUS_Single / not married                                     0
# NAME_FAMILY_STATUS_Unknown                                                  0
# NAME_FAMILY_STATUS_Widow                                                    0
# NAME_HOUSING_TYPE_Co-op apartment                                           0
# NAME_HOUSING_TYPE_House / apartment                                         0
# NAME_HOUSING_TYPE_Municipal apartment                                       0
# NAME_HOUSING_TYPE_Office apartment                                          0
# NAME_HOUSING_TYPE_Rented apartment                                          0
# NAME_HOUSING_TYPE_With parents                                              0
# OCCUPATION_TYPE_Accountants                                                 0
# OCCUPATION_TYPE_Cleaning staff                                              0
# OCCUPATION_TYPE_Cooking staff                                               0
# OCCUPATION_TYPE_Core staff                                                  0
# OCCUPATION_TYPE_Drivers                                                     0
# OCCUPATION_TYPE_HR staff                                                    0
# OCCUPATION_TYPE_High skill tech staff                                       0
# OCCUPATION_TYPE_IT staff                                                    0
# OCCUPATION_TYPE_Laborers                                                    0
# OCCUPATION_TYPE_Low-skill Laborers                                          0
# OCCUPATION_TYPE_Managers                                                    0
# OCCUPATION_TYPE_Medicine staff                                              0
# OCCUPATION_TYPE_Private service staff                                       0
# OCCUPATION_TYPE_Realty agents                                               0
# OCCUPATION_TYPE_Sales staff                                                 0
# OCCUPATION_TYPE_Secretaries                                                 0
# OCCUPATION_TYPE_Security staff                                              0
# OCCUPATION_TYPE_Waiters/barmen staff                                        0
# WEEKDAY_APPR_PROCESS_START_FRIDAY                                           0
# WEEKDAY_APPR_PROCESS_START_MONDAY                                           0
# WEEKDAY_APPR_PROCESS_START_SATURDAY                                         0
# WEEKDAY_APPR_PROCESS_START_SUNDAY                                           0
# WEEKDAY_APPR_PROCESS_START_THURSDAY                                         0
# WEEKDAY_APPR_PROCESS_START_TUESDAY                                          0
# WEEKDAY_APPR_PROCESS_START_WEDNESDAY                                        0
# ORGANIZATION_TYPE_Advertising                                               0
# ORGANIZATION_TYPE_Agriculture                                               0
# ORGANIZATION_TYPE_Bank                                                      0
# ORGANIZATION_TYPE_Business Entity Type 1                                    0
# ORGANIZATION_TYPE_Business Entity Type 2                                    0
# ORGANIZATION_TYPE_Business Entity Type 3                                    0
# ORGANIZATION_TYPE_Cleaning                                                  0
# ORGANIZATION_TYPE_Construction                                              0
# ORGANIZATION_TYPE_Culture                                                   0
# ORGANIZATION_TYPE_Electricity                                               0
# ORGANIZATION_TYPE_Emergency                                                 0
# ORGANIZATION_TYPE_Government                                                0
# ORGANIZATION_TYPE_Hotel                                                     0
# ORGANIZATION_TYPE_Housing                                                   0
# ORGANIZATION_TYPE_Industry: type 1                                          0
# ORGANIZATION_TYPE_Industry: type 10                                         0
# ORGANIZATION_TYPE_Industry: type 11                                         0
# ORGANIZATION_TYPE_Industry: type 12                                         0
# ORGANIZATION_TYPE_Industry: type 13                                         0
# ORGANIZATION_TYPE_Industry: type 2                                          0
# ORGANIZATION_TYPE_Industry: type 3                                          0
# ORGANIZATION_TYPE_Industry: type 4                                          0
# ORGANIZATION_TYPE_Industry: type 5                                          0
# ORGANIZATION_TYPE_Industry: type 6                                          0
# ORGANIZATION_TYPE_Industry: type 7                                          0
# ORGANIZATION_TYPE_Industry: type 8                                          0
# ORGANIZATION_TYPE_Industry: type 9                                          0
# ORGANIZATION_TYPE_Insurance                                                 0
# ORGANIZATION_TYPE_Kindergarten                                              0
# ORGANIZATION_TYPE_Legal Services                                            0
# ORGANIZATION_TYPE_Medicine                                                  0
# ORGANIZATION_TYPE_Military                                                  0
# ORGANIZATION_TYPE_Mobile                                                    0
# ORGANIZATION_TYPE_Other                                                     0
# ORGANIZATION_TYPE_Police                                                    0
# ORGANIZATION_TYPE_Postal                                                    0
# ORGANIZATION_TYPE_Realtor                                                   0
# ORGANIZATION_TYPE_Religion                                                  0
# ORGANIZATION_TYPE_Restaurant                                                0
# ORGANIZATION_TYPE_School                                                    0
# ORGANIZATION_TYPE_Security                                                  0
# ORGANIZATION_TYPE_Security Ministries                                       0
# ORGANIZATION_TYPE_Self-employed                                             0
# ORGANIZATION_TYPE_Services                                                  0
# ORGANIZATION_TYPE_Telecom                                                   0
# ORGANIZATION_TYPE_Trade: type 1                                             0
# ORGANIZATION_TYPE_Trade: type 2                                             0
# ORGANIZATION_TYPE_Trade: type 3                                             0
# ORGANIZATION_TYPE_Trade: type 4                                             0
# ORGANIZATION_TYPE_Trade: type 5                                             0
# ORGANIZATION_TYPE_Trade: type 6                                             0
# ORGANIZATION_TYPE_Trade: type 7                                             0
# ORGANIZATION_TYPE_Transport: type 1                                         0
# ORGANIZATION_TYPE_Transport: type 2                                         0
# ORGANIZATION_TYPE_Transport: type 3                                         0
# ORGANIZATION_TYPE_Transport: type 4                                         0
# ORGANIZATION_TYPE_University                                                0
# ORGANIZATION_TYPE_XNA                                                       0
# FONDKAPREMONT_MODE_not specified                                            0
# FONDKAPREMONT_MODE_org spec account                                         0
# FONDKAPREMONT_MODE_reg oper account                                         0
# FONDKAPREMONT_MODE_reg oper spec account                                    0
# HOUSETYPE_MODE_block of flats                                               0
# HOUSETYPE_MODE_specific housing                                             0
# HOUSETYPE_MODE_terraced house                                               0
# WALLSMATERIAL_MODE_Block                                                    0
# WALLSMATERIAL_MODE_Mixed                                                    0
# WALLSMATERIAL_MODE_Monolithic                                               0
# WALLSMATERIAL_MODE_Others                                                   0
# WALLSMATERIAL_MODE_Panel                                                    0
# WALLSMATERIAL_MODE_Stone, brick                                             0
# WALLSMATERIAL_MODE_Wooden                                                   0
# EMERGENCYSTATE_MODE_No                                                      0
# EMERGENCYSTATE_MODE_Yes                                                     0
# DAYS_EMPLOYED_PERC                                                        811
# INCOME_CREDIT_PERC                                                          0
# INCOME_PER_PERSON                                                           0
# ANNUITY_INCOME_PERC                                                         0
# PAYMENT_RATE                                                                0
# BURO_DAYS_CREDIT_MIN                                                      626
# BURO_DAYS_CREDIT_MAX                                                      626
# BURO_DAYS_CREDIT_MEAN                                                     626
# BURO_DAYS_CREDIT_VAR                                                     1086
# BURO_DAYS_CREDIT_ENDDATE_MIN                                              652
# BURO_DAYS_CREDIT_ENDDATE_MAX                                              652
# BURO_DAYS_CREDIT_ENDDATE_MEAN                                             652
# BURO_DAYS_CREDIT_UPDATE_MEAN                                              626
# BURO_CREDIT_DAY_OVERDUE_MAX                                               626
# BURO_CREDIT_DAY_OVERDUE_MEAN                                              626
# BURO_AMT_CREDIT_MAX_OVERDUE_MEAN                                         1722
# BURO_AMT_CREDIT_SUM_MAX                                                   626
# BURO_AMT_CREDIT_SUM_MEAN                                                  626
# BURO_AMT_CREDIT_SUM_SUM                                                   626
# BURO_AMT_CREDIT_SUM_DEBT_MAX                                              726
# BURO_AMT_CREDIT_SUM_DEBT_MEAN                                             726
# BURO_AMT_CREDIT_SUM_DEBT_SUM                                              626
# BURO_AMT_CREDIT_SUM_OVERDUE_MEAN                                          626
# BURO_AMT_CREDIT_SUM_LIMIT_MEAN                                            927
# BURO_AMT_CREDIT_SUM_LIMIT_SUM                                             626
# BURO_AMT_ANNUITY_MAX                                                     3226
# BURO_AMT_ANNUITY_MEAN                                                    3226
# BURO_CNT_CREDIT_PROLONG_SUM                                               626
# BURO_MONTHS_BALANCE_MIN_MIN                                              3053
# BURO_MONTHS_BALANCE_MAX_MAX                                              3053
# BURO_MONTHS_BALANCE_SIZE_MEAN                                            3053
# BURO_MONTHS_BALANCE_SIZE_SUM                                              626
# BURO_CREDIT_ACTIVE_Active_MEAN                                            626
# BURO_CREDIT_ACTIVE_Bad debt_MEAN                                          626
# BURO_CREDIT_ACTIVE_Closed_MEAN                                            626
# BURO_CREDIT_ACTIVE_Sold_MEAN                                              626
# BURO_CREDIT_ACTIVE_nan_MEAN                                               626
# BURO_CREDIT_CURRENCY_currency 1_MEAN                                      626
# BURO_CREDIT_CURRENCY_currency 2_MEAN                                      626
# BURO_CREDIT_CURRENCY_currency 3_MEAN                                      626
# BURO_CREDIT_CURRENCY_currency 4_MEAN                                      626
# BURO_CREDIT_CURRENCY_nan_MEAN                                             626
# BURO_CREDIT_TYPE_Another type of loan_MEAN                                626
# BURO_CREDIT_TYPE_Car loan_MEAN                                            626
# BURO_CREDIT_TYPE_Cash loan (non-earmarked)_MEAN                           626
# BURO_CREDIT_TYPE_Consumer credit_MEAN                                     626
# BURO_CREDIT_TYPE_Credit card_MEAN                                         626
# BURO_CREDIT_TYPE_Interbank credit_MEAN                                    626
# BURO_CREDIT_TYPE_Loan for business development_MEAN                       626
# BURO_CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN        626
# BURO_CREDIT_TYPE_Loan for the purchase of equipment_MEAN                  626
# BURO_CREDIT_TYPE_Loan for working capital replenishment_MEAN              626
# BURO_CREDIT_TYPE_Microloan_MEAN                                           626
# BURO_CREDIT_TYPE_Mobile operator loan_MEAN                                626
# BURO_CREDIT_TYPE_Mortgage_MEAN                                            626
# BURO_CREDIT_TYPE_Real estate loan_MEAN                                    626
# BURO_CREDIT_TYPE_Unknown type of loan_MEAN                                626
# BURO_CREDIT_TYPE_nan_MEAN                                                 626
# BURO_STATUS_0_MEAN_MEAN                                                  3053
# BURO_STATUS_1_MEAN_MEAN                                                  3053
# BURO_STATUS_2_MEAN_MEAN                                                  3053
# BURO_STATUS_3_MEAN_MEAN                                                  3053
# BURO_STATUS_4_MEAN_MEAN                                                  3053
# BURO_STATUS_5_MEAN_MEAN                                                  3053
# BURO_STATUS_C_MEAN_MEAN                                                  3053
# BURO_STATUS_X_MEAN_MEAN                                                  3053
# BURO_STATUS_nan_MEAN_MEAN                                                3053
# ACTIVE_DAYS_CREDIT_MIN                                                   1262
# ACTIVE_DAYS_CREDIT_MAX                                                   1262
# ACTIVE_DAYS_CREDIT_MEAN                                                  1262
# ACTIVE_DAYS_CREDIT_VAR                                                   2243
# ACTIVE_DAYS_CREDIT_ENDDATE_MIN                                           1384
# ACTIVE_DAYS_CREDIT_ENDDATE_MAX                                           1384
# ACTIVE_DAYS_CREDIT_ENDDATE_MEAN                                          1384
# ACTIVE_DAYS_CREDIT_UPDATE_MEAN                                           1262
# ACTIVE_CREDIT_DAY_OVERDUE_MAX                                            1262
# ACTIVE_CREDIT_DAY_OVERDUE_MEAN                                           1262
# ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN                                       2662
# ACTIVE_AMT_CREDIT_SUM_MAX                                                1262
# ACTIVE_AMT_CREDIT_SUM_MEAN                                               1262
# ACTIVE_AMT_CREDIT_SUM_SUM                                                1262
# ACTIVE_AMT_CREDIT_SUM_DEBT_MAX                                           1394
# ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN                                          1394
# ACTIVE_AMT_CREDIT_SUM_DEBT_SUM                                           1262
# ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN                                       1262
# ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN                                         1638
# ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM                                          1262
# ACTIVE_AMT_ANNUITY_MAX                                                   3491
# ACTIVE_AMT_ANNUITY_MEAN                                                  3491
# ACTIVE_CNT_CREDIT_PROLONG_SUM                                            1262
# ACTIVE_MONTHS_BALANCE_MIN_MIN                                            3263
# ACTIVE_MONTHS_BALANCE_MAX_MAX                                            3263
# ACTIVE_MONTHS_BALANCE_SIZE_MEAN                                          3263
# ACTIVE_MONTHS_BALANCE_SIZE_SUM                                           1262
# CLOSED_DAYS_CREDIT_MIN                                                   1101
# CLOSED_DAYS_CREDIT_MAX                                                   1101
# CLOSED_DAYS_CREDIT_MEAN                                                  1101
# CLOSED_DAYS_CREDIT_VAR                                                   1793
# CLOSED_DAYS_CREDIT_ENDDATE_MIN                                           1116
# CLOSED_DAYS_CREDIT_ENDDATE_MAX                                           1116
# CLOSED_DAYS_CREDIT_ENDDATE_MEAN                                          1116
# CLOSED_DAYS_CREDIT_UPDATE_MEAN                                           1101
# CLOSED_CREDIT_DAY_OVERDUE_MAX                                            1101
# CLOSED_CREDIT_DAY_OVERDUE_MEAN                                           1101
# CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN                                       2260
# CLOSED_AMT_CREDIT_SUM_MAX                                                1101
# CLOSED_AMT_CREDIT_SUM_MEAN                                               1101
# CLOSED_AMT_CREDIT_SUM_SUM                                                1101
# CLOSED_AMT_CREDIT_SUM_DEBT_MAX                                           1266
# CLOSED_AMT_CREDIT_SUM_DEBT_MEAN                                          1266
# CLOSED_AMT_CREDIT_SUM_DEBT_SUM                                           1101
# CLOSED_AMT_CREDIT_SUM_OVERDUE_MEAN                                       1101
# CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN                                         1537
# CLOSED_AMT_CREDIT_SUM_LIMIT_SUM                                          1101
# CLOSED_AMT_ANNUITY_MAX                                                   3417
# CLOSED_AMT_ANNUITY_MEAN                                                  3417
# CLOSED_CNT_CREDIT_PROLONG_SUM                                            1101
# CLOSED_MONTHS_BALANCE_MIN_MIN                                            3215
# CLOSED_MONTHS_BALANCE_MAX_MAX                                            3215
# CLOSED_MONTHS_BALANCE_SIZE_MEAN                                          3215
# CLOSED_MONTHS_BALANCE_SIZE_SUM                                           1101
# PREV_AMT_ANNUITY_MIN                                                      260
# PREV_AMT_ANNUITY_MAX                                                      260
# PREV_AMT_ANNUITY_MEAN                                                     260
# PREV_AMT_APPLICATION_MIN                                                  254
# PREV_AMT_APPLICATION_MAX                                                  254
# PREV_AMT_APPLICATION_MEAN                                                 254
# PREV_AMT_CREDIT_MIN                                                       254
# PREV_AMT_CREDIT_MAX                                                       254
# PREV_AMT_CREDIT_MEAN                                                      254
# PREV_APP_CREDIT_PERC_MIN                                                  259
# PREV_APP_CREDIT_PERC_MAX                                                  259
# PREV_APP_CREDIT_PERC_MEAN                                                 259
# PREV_APP_CREDIT_PERC_VAR                                                 1124
# PREV_AMT_DOWN_PAYMENT_MIN                                                 467
# PREV_AMT_DOWN_PAYMENT_MAX                                                 467
# PREV_AMT_DOWN_PAYMENT_MEAN                                                467
# PREV_AMT_GOODS_PRICE_MIN                                                  271
# PREV_AMT_GOODS_PRICE_MAX                                                  271
# PREV_AMT_GOODS_PRICE_MEAN                                                 271
# PREV_HOUR_APPR_PROCESS_START_MIN                                          254
# PREV_HOUR_APPR_PROCESS_START_MAX                                          254
# PREV_HOUR_APPR_PROCESS_START_MEAN                                         254
# PREV_RATE_DOWN_PAYMENT_MIN                                                467
# PREV_RATE_DOWN_PAYMENT_MAX                                                467
# PREV_RATE_DOWN_PAYMENT_MEAN                                               467
# PREV_DAYS_DECISION_MIN                                                    254
# PREV_DAYS_DECISION_MAX                                                    254
# PREV_DAYS_DECISION_MEAN                                                   254
# PREV_CNT_PAYMENT_MEAN                                                     260
# PREV_CNT_PAYMENT_SUM                                                      254
# PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN                                   254
# PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN                               254
# PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN                              254
# PREV_NAME_CONTRACT_TYPE_XNA_MEAN                                          254
# PREV_NAME_CONTRACT_TYPE_nan_MEAN                                          254
# PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN                               254
# PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN                               254
# PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN                             254
# PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN                               254
# PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN                             254
# PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN                              254
# PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN                            254
# PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN                                  254
# PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN                                   254
# PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN                                   254
# PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN                                 254
# PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN             254
# PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN                     254
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN                          254
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN             254
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN                            254
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN                         254
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN                        254
# PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN                              254
# PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN                                254
# PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN                        254
# PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN                                254
# PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN              254
# PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN                                    254
# PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN                                  254
# PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN                                 254
# PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN                 254
# PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN                                    254
# PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN                  254
# PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN         254
# PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN                 254
# PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN                                  254
# PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN                             254
# PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN                 254
# PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN                                      254
# PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN                                      254
# PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN                                      254
# PREV_NAME_CONTRACT_STATUS_Approved_MEAN                                   254
# PREV_NAME_CONTRACT_STATUS_Canceled_MEAN                                   254
# PREV_NAME_CONTRACT_STATUS_Refused_MEAN                                    254
# PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN                               254
# PREV_NAME_CONTRACT_STATUS_nan_MEAN                                        254
# PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN                         254
# PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN     254
# PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN                    254
# PREV_NAME_PAYMENT_TYPE_XNA_MEAN                                           254
# PREV_NAME_PAYMENT_TYPE_nan_MEAN                                           254
# PREV_CODE_REJECT_REASON_CLIENT_MEAN                                       254
# PREV_CODE_REJECT_REASON_HC_MEAN                                           254
# PREV_CODE_REJECT_REASON_LIMIT_MEAN                                        254
# PREV_CODE_REJECT_REASON_SCO_MEAN                                          254
# PREV_CODE_REJECT_REASON_SCOFR_MEAN                                        254
# PREV_CODE_REJECT_REASON_SYSTEM_MEAN                                       254
# PREV_CODE_REJECT_REASON_VERIF_MEAN                                        254
# PREV_CODE_REJECT_REASON_XAP_MEAN                                          254
# PREV_CODE_REJECT_REASON_XNA_MEAN                                          254
# PREV_CODE_REJECT_REASON_nan_MEAN                                          254
# PREV_NAME_TYPE_SUITE_Children_MEAN                                        254
# PREV_NAME_TYPE_SUITE_Family_MEAN                                          254
# PREV_NAME_TYPE_SUITE_Group of people_MEAN                                 254
# PREV_NAME_TYPE_SUITE_Other_A_MEAN                                         254
# PREV_NAME_TYPE_SUITE_Other_B_MEAN                                         254
# PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN                                 254
# PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN                                   254
# PREV_NAME_TYPE_SUITE_nan_MEAN                                             254
# PREV_NAME_CLIENT_TYPE_New_MEAN                                            254
# PREV_NAME_CLIENT_TYPE_Refreshed_MEAN                                      254
# PREV_NAME_CLIENT_TYPE_Repeater_MEAN                                       254
# PREV_NAME_CLIENT_TYPE_XNA_MEAN                                            254
# PREV_NAME_CLIENT_TYPE_nan_MEAN                                            254
# PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN                          254
# PREV_NAME_GOODS_CATEGORY_Animals_MEAN                                     254
# PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN                                 254
# PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN                            254
# PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN                    254
# PREV_NAME_GOODS_CATEGORY_Computers_MEAN                                   254
# PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN                      254
# PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN                        254
# PREV_NAME_GOODS_CATEGORY_Direct Sales_MEAN                                254
# PREV_NAME_GOODS_CATEGORY_Education_MEAN                                   254
# PREV_NAME_GOODS_CATEGORY_Fitness_MEAN                                     254
# PREV_NAME_GOODS_CATEGORY_Furniture_MEAN                                   254
# PREV_NAME_GOODS_CATEGORY_Gardening_MEAN                                   254
# PREV_NAME_GOODS_CATEGORY_Homewares_MEAN                                   254
# PREV_NAME_GOODS_CATEGORY_House Construction_MEAN                          254
# PREV_NAME_GOODS_CATEGORY_Insurance_MEAN                                   254
# PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN                                     254
# PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN                            254
# PREV_NAME_GOODS_CATEGORY_Medicine_MEAN                                    254
# PREV_NAME_GOODS_CATEGORY_Mobile_MEAN                                      254
# PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN                           254
# PREV_NAME_GOODS_CATEGORY_Other_MEAN                                       254
# PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN                    254
# PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN                           254
# PREV_NAME_GOODS_CATEGORY_Tourism_MEAN                                     254
# PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN                                    254
# PREV_NAME_GOODS_CATEGORY_Weapon_MEAN                                      254
# PREV_NAME_GOODS_CATEGORY_XNA_MEAN                                         254
# PREV_NAME_GOODS_CATEGORY_nan_MEAN                                         254
# PREV_NAME_PORTFOLIO_Cards_MEAN                                            254
# PREV_NAME_PORTFOLIO_Cars_MEAN                                             254
# PREV_NAME_PORTFOLIO_Cash_MEAN                                             254
# PREV_NAME_PORTFOLIO_POS_MEAN                                              254
# PREV_NAME_PORTFOLIO_XNA_MEAN                                              254
# PREV_NAME_PORTFOLIO_nan_MEAN                                              254
# PREV_NAME_PRODUCT_TYPE_XNA_MEAN                                           254
# PREV_NAME_PRODUCT_TYPE_walk-in_MEAN                                       254
# PREV_NAME_PRODUCT_TYPE_x-sell_MEAN                                        254
# PREV_NAME_PRODUCT_TYPE_nan_MEAN                                           254
# PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN                                    254
# PREV_CHANNEL_TYPE_Car dealer_MEAN                                         254
# PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN                         254
# PREV_CHANNEL_TYPE_Contact center_MEAN                                     254
# PREV_CHANNEL_TYPE_Country-wide_MEAN                                       254
# PREV_CHANNEL_TYPE_Credit and cash offices_MEAN                            254
# PREV_CHANNEL_TYPE_Regional / Local_MEAN                                   254
# PREV_CHANNEL_TYPE_Stone_MEAN                                              254
# PREV_CHANNEL_TYPE_nan_MEAN                                                254
# PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN                            254
# PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN                                   254
# PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN                               254
# PREV_NAME_SELLER_INDUSTRY_Construction_MEAN                               254
# PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN                       254
# PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN                                  254
# PREV_NAME_SELLER_INDUSTRY_Industry_MEAN                                   254
# PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN                                    254
# PREV_NAME_SELLER_INDUSTRY_MLM partners_MEAN                               254
# PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN                                    254
# PREV_NAME_SELLER_INDUSTRY_XNA_MEAN                                        254
# PREV_NAME_SELLER_INDUSTRY_nan_MEAN                                        254
# PREV_NAME_YIELD_GROUP_XNA_MEAN                                            254
# PREV_NAME_YIELD_GROUP_high_MEAN                                           254
# PREV_NAME_YIELD_GROUP_low_action_MEAN                                     254
# PREV_NAME_YIELD_GROUP_low_normal_MEAN                                     254
# PREV_NAME_YIELD_GROUP_middle_MEAN                                         254
# PREV_NAME_YIELD_GROUP_nan_MEAN                                            254
# PREV_PRODUCT_COMBINATION_Card Street_MEAN                                 254
# PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN                                 254
# PREV_PRODUCT_COMBINATION_Cash_MEAN                                        254
# PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN                           254
# PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN                            254
# PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN                         254
# PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN                           254
# PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN                            254
# PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN                         254
# PREV_PRODUCT_COMBINATION_POS household with interest_MEAN                 254
# PREV_PRODUCT_COMBINATION_POS household without interest_MEAN              254
# PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN                  254
# PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN               254
# PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN                    254
# PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN                 254
# PREV_PRODUCT_COMBINATION_POS other with interest_MEAN                     254
# PREV_PRODUCT_COMBINATION_POS others without interest_MEAN                 254
# PREV_PRODUCT_COMBINATION_nan_MEAN                                         254
# APPROVED_AMT_ANNUITY_MIN                                                  271
# APPROVED_AMT_ANNUITY_MAX                                                  271
# APPROVED_AMT_ANNUITY_MEAN                                                 271
# APPROVED_AMT_APPLICATION_MIN                                              271
# APPROVED_AMT_APPLICATION_MAX                                              271
# APPROVED_AMT_APPLICATION_MEAN                                             271
# APPROVED_AMT_CREDIT_MIN                                                   271
# APPROVED_AMT_CREDIT_MAX                                                   271
# APPROVED_AMT_CREDIT_MEAN                                                  271
# APPROVED_APP_CREDIT_PERC_MIN                                              271
# APPROVED_APP_CREDIT_PERC_MAX                                              271
# APPROVED_APP_CREDIT_PERC_MEAN                                             271
# APPROVED_APP_CREDIT_PERC_VAR                                             1344
# APPROVED_AMT_DOWN_PAYMENT_MIN                                             494
# APPROVED_AMT_DOWN_PAYMENT_MAX                                             494
# APPROVED_AMT_DOWN_PAYMENT_MEAN                                            494
# APPROVED_AMT_GOODS_PRICE_MIN                                              285
# APPROVED_AMT_GOODS_PRICE_MAX                                              285
# APPROVED_AMT_GOODS_PRICE_MEAN                                             285
# APPROVED_HOUR_APPR_PROCESS_START_MIN                                      271
# APPROVED_HOUR_APPR_PROCESS_START_MAX                                      271
# APPROVED_HOUR_APPR_PROCESS_START_MEAN                                     271
# APPROVED_RATE_DOWN_PAYMENT_MIN                                            494
# APPROVED_RATE_DOWN_PAYMENT_MAX                                            494
# APPROVED_RATE_DOWN_PAYMENT_MEAN                                           494
# APPROVED_DAYS_DECISION_MIN                                                271
# APPROVED_DAYS_DECISION_MAX                                                271
# APPROVED_DAYS_DECISION_MEAN                                               271
# APPROVED_CNT_PAYMENT_MEAN                                                 271
# APPROVED_CNT_PAYMENT_SUM                                                  271
# REFUSED_AMT_ANNUITY_MIN                                                  3007
# REFUSED_AMT_ANNUITY_MAX                                                  3007
# REFUSED_AMT_ANNUITY_MEAN                                                 3007
# REFUSED_AMT_APPLICATION_MIN                                              2887
# REFUSED_AMT_APPLICATION_MAX                                              2887
# REFUSED_AMT_APPLICATION_MEAN                                             2887
# REFUSED_AMT_CREDIT_MIN                                                   2887
# REFUSED_AMT_CREDIT_MAX                                                   2887
# REFUSED_AMT_CREDIT_MEAN                                                  2887
# REFUSED_APP_CREDIT_PERC_MIN                                              2963
# REFUSED_APP_CREDIT_PERC_MAX                                              2963
# REFUSED_APP_CREDIT_PERC_MEAN                                             2963
# REFUSED_APP_CREDIT_PERC_VAR                                              3607
# REFUSED_AMT_DOWN_PAYMENT_MIN                                             3647
# REFUSED_AMT_DOWN_PAYMENT_MAX                                             3647
# REFUSED_AMT_DOWN_PAYMENT_MEAN                                            3647
# REFUSED_AMT_GOODS_PRICE_MIN                                              2997
# REFUSED_AMT_GOODS_PRICE_MAX                                              2997
# REFUSED_AMT_GOODS_PRICE_MEAN                                             2997
# REFUSED_HOUR_APPR_PROCESS_START_MIN                                      2887
# REFUSED_HOUR_APPR_PROCESS_START_MAX                                      2887
# REFUSED_HOUR_APPR_PROCESS_START_MEAN                                     2887
# REFUSED_RATE_DOWN_PAYMENT_MIN                                            3647
# REFUSED_RATE_DOWN_PAYMENT_MAX                                            3647
# REFUSED_RATE_DOWN_PAYMENT_MEAN                                           3647
# REFUSED_DAYS_DECISION_MIN                                                2887
# REFUSED_DAYS_DECISION_MAX                                                2887
# REFUSED_DAYS_DECISION_MEAN                                               2887
# REFUSED_CNT_PAYMENT_MEAN                                                 3007
# REFUSED_CNT_PAYMENT_SUM                                                  2887
# POS_MONTHS_BALANCE_MAX                                                    264
# POS_MONTHS_BALANCE_MEAN                                                   264
# POS_MONTHS_BALANCE_SIZE                                                   264
# POS_SK_DPD_MAX                                                            264
# POS_SK_DPD_MEAN                                                           264
# POS_SK_DPD_DEF_MAX                                                        264
# POS_SK_DPD_DEF_MEAN                                                       264
# POS_NAME_CONTRACT_STATUS_Active_MEAN                                      264
# POS_NAME_CONTRACT_STATUS_Amortized debt_MEAN                              264
# POS_NAME_CONTRACT_STATUS_Approved_MEAN                                    264
# POS_NAME_CONTRACT_STATUS_Canceled_MEAN                                    264
# POS_NAME_CONTRACT_STATUS_Completed_MEAN                                   264
# POS_NAME_CONTRACT_STATUS_Demand_MEAN                                      264
# POS_NAME_CONTRACT_STATUS_Returned to the store_MEAN                       264
# POS_NAME_CONTRACT_STATUS_Signed_MEAN                                      264
# POS_NAME_CONTRACT_STATUS_XNA_MEAN                                         264
# POS_NAME_CONTRACT_STATUS_nan_MEAN                                         264
# POS_COUNT                                                                 264
# INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE                                     234
# INSTAL_DPD_MAX                                                            234
# INSTAL_DPD_MEAN                                                           234
# INSTAL_DPD_SUM                                                            234
# INSTAL_DBD_MAX                                                            234
# INSTAL_DBD_MEAN                                                           234
# INSTAL_DBD_SUM                                                            234
# INSTAL_PAYMENT_PERC_MAX                                                   234
# INSTAL_PAYMENT_PERC_MEAN                                                  234
# INSTAL_PAYMENT_PERC_SUM                                                   234
# INSTAL_PAYMENT_PERC_VAR                                                   244
# INSTAL_PAYMENT_DIFF_MAX                                                   234
# INSTAL_PAYMENT_DIFF_MEAN                                                  234
# INSTAL_PAYMENT_DIFF_SUM                                                   234
# INSTAL_PAYMENT_DIFF_VAR                                                   244
# INSTAL_AMT_INSTALMENT_MAX                                                 234
# INSTAL_AMT_INSTALMENT_MEAN                                                234
# INSTAL_AMT_INSTALMENT_SUM                                                 234
# INSTAL_AMT_PAYMENT_MIN                                                    234
# INSTAL_AMT_PAYMENT_MAX                                                    234
# INSTAL_AMT_PAYMENT_MEAN                                                   234
# INSTAL_AMT_PAYMENT_SUM                                                    234
# INSTAL_DAYS_ENTRY_PAYMENT_MAX                                             234
# INSTAL_DAYS_ENTRY_PAYMENT_MEAN                                            234
# INSTAL_DAYS_ENTRY_PAYMENT_SUM                                             234
# INSTAL_COUNT                                                              234
# CC_MONTHS_BALANCE_MIN                                                    3093
# CC_MONTHS_BALANCE_MAX                                                    3093
# CC_MONTHS_BALANCE_MEAN                                                   3093
# CC_MONTHS_BALANCE_SUM                                                    3093
# CC_MONTHS_BALANCE_VAR                                                    3099
# CC_AMT_BALANCE_MIN                                                       3093
# CC_AMT_BALANCE_MAX                                                       3093
# CC_AMT_BALANCE_MEAN                                                      3093
# CC_AMT_BALANCE_SUM                                                       3093
# CC_AMT_BALANCE_VAR                                                       3099
# CC_AMT_CREDIT_LIMIT_ACTUAL_MIN                                           3093
# CC_AMT_CREDIT_LIMIT_ACTUAL_MAX                                           3093
# CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN                                          3093
# CC_AMT_CREDIT_LIMIT_ACTUAL_SUM                                           3093
# CC_AMT_CREDIT_LIMIT_ACTUAL_VAR                                           3099
# CC_AMT_DRAWINGS_ATM_CURRENT_MIN                                          3467
# CC_AMT_DRAWINGS_ATM_CURRENT_MAX                                          3467
# CC_AMT_DRAWINGS_ATM_CURRENT_MEAN                                         3467
# CC_AMT_DRAWINGS_ATM_CURRENT_SUM                                          3093
# CC_AMT_DRAWINGS_ATM_CURRENT_VAR                                          3475
# CC_AMT_DRAWINGS_CURRENT_MIN                                              3093
# CC_AMT_DRAWINGS_CURRENT_MAX                                              3093
# CC_AMT_DRAWINGS_CURRENT_MEAN                                             3093
# CC_AMT_DRAWINGS_CURRENT_SUM                                              3093
# CC_AMT_DRAWINGS_CURRENT_VAR                                              3099
# CC_AMT_DRAWINGS_OTHER_CURRENT_MIN                                        3467
# CC_AMT_DRAWINGS_OTHER_CURRENT_MAX                                        3467
# CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN                                       3467
# CC_AMT_DRAWINGS_OTHER_CURRENT_SUM                                        3093
# CC_AMT_DRAWINGS_OTHER_CURRENT_VAR                                        3475
# CC_AMT_DRAWINGS_POS_CURRENT_MIN                                          3467
# CC_AMT_DRAWINGS_POS_CURRENT_MAX                                          3467
# CC_AMT_DRAWINGS_POS_CURRENT_MEAN                                         3467
# CC_AMT_DRAWINGS_POS_CURRENT_SUM                                          3093
# CC_AMT_DRAWINGS_POS_CURRENT_VAR                                          3475
# CC_AMT_INST_MIN_REGULARITY_MIN                                           3093
# CC_AMT_INST_MIN_REGULARITY_MAX                                           3093
# CC_AMT_INST_MIN_REGULARITY_MEAN                                          3093
# CC_AMT_INST_MIN_REGULARITY_SUM                                           3093
# CC_AMT_INST_MIN_REGULARITY_VAR                                           3099
# CC_AMT_PAYMENT_CURRENT_MIN                                               3470
# CC_AMT_PAYMENT_CURRENT_MAX                                               3470
# CC_AMT_PAYMENT_CURRENT_MEAN                                              3470
# CC_AMT_PAYMENT_CURRENT_SUM                                               3093
# CC_AMT_PAYMENT_CURRENT_VAR                                               3482
# CC_AMT_PAYMENT_TOTAL_CURRENT_MIN                                         3093
# CC_AMT_PAYMENT_TOTAL_CURRENT_MAX                                         3093
# CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN                                        3093
# CC_AMT_PAYMENT_TOTAL_CURRENT_SUM                                         3093
# CC_AMT_PAYMENT_TOTAL_CURRENT_VAR                                         3099
# CC_AMT_RECEIVABLE_PRINCIPAL_MIN                                          3093
# CC_AMT_RECEIVABLE_PRINCIPAL_MAX                                          3093
# CC_AMT_RECEIVABLE_PRINCIPAL_MEAN                                         3093
# CC_AMT_RECEIVABLE_PRINCIPAL_SUM                                          3093
# CC_AMT_RECEIVABLE_PRINCIPAL_VAR                                          3099
# CC_AMT_RECIVABLE_MIN                                                     3093
# CC_AMT_RECIVABLE_MAX                                                     3093
# CC_AMT_RECIVABLE_MEAN                                                    3093
# CC_AMT_RECIVABLE_SUM                                                     3093
# CC_AMT_RECIVABLE_VAR                                                     3099
# CC_AMT_TOTAL_RECEIVABLE_MIN                                              3093
# CC_AMT_TOTAL_RECEIVABLE_MAX                                              3093
# CC_AMT_TOTAL_RECEIVABLE_MEAN                                             3093
# CC_AMT_TOTAL_RECEIVABLE_SUM                                              3093
# CC_AMT_TOTAL_RECEIVABLE_VAR                                              3099
# CC_CNT_DRAWINGS_ATM_CURRENT_MIN                                          3467
# CC_CNT_DRAWINGS_ATM_CURRENT_MAX                                          3467
# CC_CNT_DRAWINGS_ATM_CURRENT_MEAN                                         3467
# CC_CNT_DRAWINGS_ATM_CURRENT_SUM                                          3093
# CC_CNT_DRAWINGS_ATM_CURRENT_VAR                                          3475
# CC_CNT_DRAWINGS_CURRENT_MIN                                              3093
# CC_CNT_DRAWINGS_CURRENT_MAX                                              3093
# CC_CNT_DRAWINGS_CURRENT_MEAN                                             3093
# CC_CNT_DRAWINGS_CURRENT_SUM                                              3093
# CC_CNT_DRAWINGS_CURRENT_VAR                                              3099
# CC_CNT_DRAWINGS_OTHER_CURRENT_MIN                                        3467
# CC_CNT_DRAWINGS_OTHER_CURRENT_MAX                                        3467
# CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN                                       3467
# CC_CNT_DRAWINGS_OTHER_CURRENT_SUM                                        3093
# CC_CNT_DRAWINGS_OTHER_CURRENT_VAR                                        3475
# CC_CNT_DRAWINGS_POS_CURRENT_MIN                                          3467
# CC_CNT_DRAWINGS_POS_CURRENT_MAX                                          3467
# CC_CNT_DRAWINGS_POS_CURRENT_MEAN                                         3467
# CC_CNT_DRAWINGS_POS_CURRENT_SUM                                          3093
# CC_CNT_DRAWINGS_POS_CURRENT_VAR                                          3475
# CC_CNT_INSTALMENT_MATURE_CUM_MIN                                         3093
# CC_CNT_INSTALMENT_MATURE_CUM_MAX                                         3093
# CC_CNT_INSTALMENT_MATURE_CUM_MEAN                                        3093
# CC_CNT_INSTALMENT_MATURE_CUM_SUM                                         3093
# CC_CNT_INSTALMENT_MATURE_CUM_VAR                                         3099
# CC_SK_DPD_MIN                                                            3093
# CC_SK_DPD_MAX                                                            3093
# CC_SK_DPD_MEAN                                                           3093
# CC_SK_DPD_SUM                                                            3093
# CC_SK_DPD_VAR                                                            3099
# CC_SK_DPD_DEF_MIN                                                        3093
# CC_SK_DPD_DEF_MAX                                                        3093
# CC_SK_DPD_DEF_MEAN                                                       3093
# CC_SK_DPD_DEF_SUM                                                        3093
# CC_SK_DPD_DEF_VAR                                                        3099
# CC_NAME_CONTRACT_STATUS_Active_MIN                                       3093
# CC_NAME_CONTRACT_STATUS_Active_MAX                                       3093
# CC_NAME_CONTRACT_STATUS_Active_MEAN                                      3093
# CC_NAME_CONTRACT_STATUS_Active_SUM                                       3093
# CC_NAME_CONTRACT_STATUS_Active_VAR                                       3099
# CC_NAME_CONTRACT_STATUS_Approved_MIN                                     3093
# CC_NAME_CONTRACT_STATUS_Approved_MAX                                     3093
# CC_NAME_CONTRACT_STATUS_Approved_MEAN                                    3093
# CC_NAME_CONTRACT_STATUS_Approved_SUM                                     3093
# CC_NAME_CONTRACT_STATUS_Approved_VAR                                     3099
# CC_NAME_CONTRACT_STATUS_Completed_MIN                                    3093
# CC_NAME_CONTRACT_STATUS_Completed_MAX                                    3093
# CC_NAME_CONTRACT_STATUS_Completed_MEAN                                   3093
# CC_NAME_CONTRACT_STATUS_Completed_SUM                                    3093
# CC_NAME_CONTRACT_STATUS_Completed_VAR                                    3099
# CC_NAME_CONTRACT_STATUS_Demand_MIN                                       3093
# CC_NAME_CONTRACT_STATUS_Demand_MAX                                       3093
# CC_NAME_CONTRACT_STATUS_Demand_MEAN                                      3093
# CC_NAME_CONTRACT_STATUS_Demand_SUM                                       3093
# CC_NAME_CONTRACT_STATUS_Demand_VAR                                       3099
# CC_NAME_CONTRACT_STATUS_Refused_MIN                                      3093
# CC_NAME_CONTRACT_STATUS_Refused_MAX                                      3093
# CC_NAME_CONTRACT_STATUS_Refused_MEAN                                     3093
# CC_NAME_CONTRACT_STATUS_Refused_SUM                                      3093
# CC_NAME_CONTRACT_STATUS_Refused_VAR                                      3099
# CC_NAME_CONTRACT_STATUS_Sent proposal_MIN                                3093
# CC_NAME_CONTRACT_STATUS_Sent proposal_MAX                                3093
# CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN                               3093
# CC_NAME_CONTRACT_STATUS_Sent proposal_SUM                                3093
# CC_NAME_CONTRACT_STATUS_Sent proposal_VAR                                3099
# CC_NAME_CONTRACT_STATUS_Signed_MIN                                       3093
# CC_NAME_CONTRACT_STATUS_Signed_MAX                                       3093
# CC_NAME_CONTRACT_STATUS_Signed_MEAN                                      3093
# CC_NAME_CONTRACT_STATUS_Signed_SUM                                       3093
# CC_NAME_CONTRACT_STATUS_Signed_VAR                                       3099
# CC_NAME_CONTRACT_STATUS_nan_MIN                                          3093
# CC_NAME_CONTRACT_STATUS_nan_MAX                                          3093
# CC_NAME_CONTRACT_STATUS_nan_MEAN                                         3093
# CC_NAME_CONTRACT_STATUS_nan_SUM                                          3093
# CC_NAME_CONTRACT_STATUS_nan_VAR                                          3099
# CC_COUNT                                                                 3093
# dtype: int64

# %%
sample_df['NB_NAN']=sample_df.isna().sum(axis=1)

# %%
sample_df['NB_NAN'].value_counts()
# Out:
# NB_NAN
# 242    77
# 241    72
# 244    72
# 199    65
# 219    57
# 243    53
# 197    53
# 240    52
# 200    50
# 218    50
# 215    47
# 196    46
# 217    46
# 198    46
# 245    45
# 239    44
# 216    43
# 220    42
# 341    42
# 221    41
# 339    39
# 340    38
# 214    38
# 223    36
# 225    36
# 195    35
# 212    33
# 213    32
# 222    31
# 173    31
# 201    30
# 211    28
# 99     28
# 266    28
# 246    27
# 190    27
# 224    27
# 206    26
# 264    26
# 226    26
# 210    26
# 265    26
# 338    25
# 191    25
# 204    24
# 295    24
# 178    23
# 202    23
# 205    23
# 174    22
# 175    22
# 238    21
# 263    21
# 101    21
# 105    20
# 262    20
# 77     20
# 73     19
# 298    19
# 177    19
# 209    19
# 247    19
# 78     19
# 176    18
# 193    18
# 188    18
# 236    18
# 230    18
# 186    17
# 192    17
# 98     17
# 232    17
# 55     17
# 207    17
# 167    17
# 203    17
# 267    17
# 102    16
# 261    16
# 208    16
# 82     16
# 172    16
# 234    15
# 76     15
# 231    15
# 250    15
# 194    15
# 104    15
# 83     15
# 70     15
# 227    15
# 127    15
# 168    15
# 80     14
# 310    14
# 79     14
# 268    14
# 81     14
# 183    14
# 57     14
# 61     14
# 184    14
# 74     14
# 59     13
# 187    13
# 66     13
# 56     13
# 103    13
# 75     13
# 185    13
# 248    12
# 235    12
# 315    12
# 58     12
# 40     12
# 68     12
# 296    12
# 179    12
# 88     11
# 153    11
# 229    11
# 233    11
# 32     11
# 166    11
# 84     11
# 169    11
# 151    11
# 126    11
# 189    11
# 171    11
# 100    11
# 503    10
# 251    10
# 237    10
# 181    10
# 72     10
# 313    10
# 253    10
# 228    10
# 269    10
# 31     10
# 297    10
# 53     10
# 180     9
# 125     9
# 146     9
# 132     9
# 316     9
# 26      9
# 148     9
# 69      9
# 108     9
# 106     9
# 34      9
# 128     9
# 37      9
# 49      9
# 92      9
# 312     9
# 182     8
# 147     8
# 60      8
# 459     8
# 149     8
# 260     8
# 309     8
# 300     8
# 50      8
# 308     8
# 270     8
# 107     8
# 97      8
# 45      8
# 87      8
# 129     8
# 38      8
# 482     8
# 64      8
# 150     8
# 36      8
# 62      8
# 131     7
# 334     7
# 67      7
# 486     7
# 484     7
# 155     7
# 27      7
# 314     7
# 46      7
# 601     7
# 48      7
# 85      7
# 86      7
# 71      7
# 343     7
# 52      7
# 28      7
# 54      7
# 110     7
# 159     7
# 96      7
# 65      7
# 120     6
# 112     6
# 337     6
# 89      6
# 63      6
# 122     6
# 480     6
# 271     6
# 113     6
# 121     6
# 154     6
# 481     6
# 249     6
# 464     6
# 273     6
# 311     6
# 8       6
# 463     5
# 133     5
# 252     5
# 33      5
# 123     5
# 460     5
# 94      5
# 275     5
# 483     5
# 505     5
# 43      5
# 255     5
# 291     5
# 93      5
# 502     5
# 301     5
# 47      5
# 114     5
# 485     5
# 165     4
# 292     4
# 109     4
# 119     4
# 506     4
# 437     4
# 318     4
# 25      4
# 95      4
# 272     4
# 508     4
# 504     4
# 29      4
# 44      4
# 164     4
# 130     4
# 124     4
# 307     4
# 162     4
# 479     4
# 465     4
# 331     4
# 163     4
# 111     4
# 317     4
# 51      4
# 115     4
# 141     4
# 160     4
# 320     4
# 18      4
# 438     4
# 488     4
# 170     4
# 30      4
# 462     3
# 304     3
# 507     3
# 10      3
# 319     3
# 477     3
# 474     3
# 143     3
# 152     3
# 91      3
# 436     3
# 525     3
# 90      3
# 254     3
# 35      3
# 467     3
# 278     3
# 158     3
# 9       3
# 478     3
# 529     3
# 493     3
# 342     3
# 156     3
# 524     3
# 7       3
# 321     3
# 290     3
# 145     3
# 327     3
# 468     2
# 461     2
# 2       2
# 487     2
# 528     2
# 118     2
# 299     2
# 490     2
# 513     2
# 527     2
# 138     2
# 573     2
# 135     2
# 516     2
# 499     2
# 13      2
# 602     2
# 257     2
# 496     2
# 451     2
# 326     2
# 144     2
# 294     2
# 4       2
# 600     2
# 140     2
# 492     2
# 139     2
# 161     2
# 470     2
# 22      2
# 509     2
# 434     2
# 333     2
# 305     2
# 561     2
# 456     2
# 23      2
# 603     2
# 41      2
# 287     2
# 323     2
# 285     2
# 466     2
# 277     2
# 11      2
# 514     2
# 42      1
# 445     1
# 440     1
# 476     1
# 1       1
# 518     1
# 552     1
# 435     1
# 563     1
# 494     1
# 374     1
# 580     1
# 526     1
# 293     1
# 574     1
# 604     1
# 136     1
# 157     1
# 256     1
# 553     1
# 531     1
# 286     1
# 559     1
# 289     1
# 391     1
# 281     1
# 0       1
# 557     1
# 322     1
# 353     1
# 12      1
# 510     1
# 19      1
# 16      1
# 142     1
# 324     1
# 471     1
# 5       1
# 259     1
# 397     1
# 473     1
# 443     1
# 137     1
# 14      1
# 532     1
# 21      1
# 550     1
# 355     1
# 39      1
# 351     1
# 412     1
# 3       1
# 576     1
# 469     1
# 24      1
# 571     1
# 350     1
# 495     1
# 453     1
# 584     1
# 409     1
# 306     1
# 6       1
# 276     1
# 302     1
# 491     1
# 565     1
# 325     1
# 134     1
# 344     1
# 329     1
# 537     1
# 288     1
# 274     1
# 441     1
# 567     1
# 450     1
# Name: count, dtype: int64

# %%
sample_df=sample_df.drop_duplicates()

# %%
filling_rate = sample_df.notna().mean()
filling_rate_sortvalue= round(filling_rate*100).sort_values(ascending=False)
filling_rate_sortvalue
# Out:
# index                                                                    100.0
# ORGANIZATION_TYPE_Bank                                                   100.0
# OCCUPATION_TYPE_Sales staff                                              100.0
# OCCUPATION_TYPE_Secretaries                                              100.0
# OCCUPATION_TYPE_Security staff                                           100.0
# OCCUPATION_TYPE_Waiters/barmen staff                                     100.0
# WEEKDAY_APPR_PROCESS_START_FRIDAY                                        100.0
# WEEKDAY_APPR_PROCESS_START_MONDAY                                        100.0
# WEEKDAY_APPR_PROCESS_START_SATURDAY                                      100.0
# WEEKDAY_APPR_PROCESS_START_SUNDAY                                        100.0
# WEEKDAY_APPR_PROCESS_START_THURSDAY                                      100.0
# WEEKDAY_APPR_PROCESS_START_TUESDAY                                       100.0
# WEEKDAY_APPR_PROCESS_START_WEDNESDAY                                     100.0
# ORGANIZATION_TYPE_Advertising                                            100.0
# ORGANIZATION_TYPE_Agriculture                                            100.0
# ORGANIZATION_TYPE_Business Entity Type 1                                 100.0
# NAME_INCOME_TYPE_Unemployed                                              100.0
# ORGANIZATION_TYPE_Business Entity Type 2                                 100.0
# ORGANIZATION_TYPE_Business Entity Type 3                                 100.0
# ORGANIZATION_TYPE_Cleaning                                               100.0
# ORGANIZATION_TYPE_Construction                                           100.0
# ORGANIZATION_TYPE_Culture                                                100.0
# ORGANIZATION_TYPE_Electricity                                            100.0
# ORGANIZATION_TYPE_Emergency                                              100.0
# ORGANIZATION_TYPE_Government                                             100.0
# ORGANIZATION_TYPE_Hotel                                                  100.0
# ORGANIZATION_TYPE_Housing                                                100.0
# ORGANIZATION_TYPE_Industry: type 1                                       100.0
# ORGANIZATION_TYPE_Industry: type 10                                      100.0
# ORGANIZATION_TYPE_Industry: type 11                                      100.0
# OCCUPATION_TYPE_Realty agents                                            100.0
# OCCUPATION_TYPE_Private service staff                                    100.0
# OCCUPATION_TYPE_Medicine staff                                           100.0
# OCCUPATION_TYPE_Managers                                                 100.0
# NAME_EDUCATION_TYPE_Academic degree                                      100.0
# NAME_EDUCATION_TYPE_Higher education                                     100.0
# NAME_EDUCATION_TYPE_Incomplete higher                                    100.0
# NAME_EDUCATION_TYPE_Lower secondary                                      100.0
# NAME_EDUCATION_TYPE_Secondary / secondary special                        100.0
# NAME_FAMILY_STATUS_Civil marriage                                        100.0
# NAME_FAMILY_STATUS_Married                                               100.0
# NAME_FAMILY_STATUS_Separated                                             100.0
# NAME_FAMILY_STATUS_Single / not married                                  100.0
# NAME_FAMILY_STATUS_Unknown                                               100.0
# NAME_FAMILY_STATUS_Widow                                                 100.0
# NAME_HOUSING_TYPE_Co-op apartment                                        100.0
# NAME_HOUSING_TYPE_House / apartment                                      100.0
# NAME_HOUSING_TYPE_Municipal apartment                                    100.0
# NAME_HOUSING_TYPE_Office apartment                                       100.0
# NAME_HOUSING_TYPE_Rented apartment                                       100.0
# NAME_HOUSING_TYPE_With parents                                           100.0
# OCCUPATION_TYPE_Accountants                                              100.0
# OCCUPATION_TYPE_Cleaning staff                                           100.0
# OCCUPATION_TYPE_Cooking staff                                            100.0
# OCCUPATION_TYPE_Core staff                                               100.0
# OCCUPATION_TYPE_Drivers                                                  100.0
# OCCUPATION_TYPE_HR staff                                                 100.0
# OCCUPATION_TYPE_High skill tech staff                                    100.0
# OCCUPATION_TYPE_IT staff                                                 100.0
# OCCUPATION_TYPE_Laborers                                                 100.0
# OCCUPATION_TYPE_Low-skill Laborers                                       100.0
# ORGANIZATION_TYPE_Industry: type 12                                      100.0
# ORGANIZATION_TYPE_Industry: type 13                                      100.0
# ORGANIZATION_TYPE_Industry: type 2                                       100.0
# ORGANIZATION_TYPE_Trade: type 6                                          100.0
# ORGANIZATION_TYPE_Transport: type 1                                      100.0
# ORGANIZATION_TYPE_Transport: type 2                                      100.0
# ORGANIZATION_TYPE_Transport: type 3                                      100.0
# ORGANIZATION_TYPE_Transport: type 4                                      100.0
# ORGANIZATION_TYPE_University                                             100.0
# ORGANIZATION_TYPE_XNA                                                    100.0
# FONDKAPREMONT_MODE_not specified                                         100.0
# FONDKAPREMONT_MODE_org spec account                                      100.0
# FONDKAPREMONT_MODE_reg oper account                                      100.0
# FONDKAPREMONT_MODE_reg oper spec account                                 100.0
# HOUSETYPE_MODE_block of flats                                            100.0
# HOUSETYPE_MODE_specific housing                                          100.0
# HOUSETYPE_MODE_terraced house                                            100.0
# WALLSMATERIAL_MODE_Block                                                 100.0
# WALLSMATERIAL_MODE_Mixed                                                 100.0
# WALLSMATERIAL_MODE_Monolithic                                            100.0
# WALLSMATERIAL_MODE_Others                                                100.0
# WALLSMATERIAL_MODE_Panel                                                 100.0
# WALLSMATERIAL_MODE_Stone, brick                                          100.0
# WALLSMATERIAL_MODE_Wooden                                                100.0
# EMERGENCYSTATE_MODE_No                                                   100.0
# EMERGENCYSTATE_MODE_Yes                                                  100.0
# INCOME_CREDIT_PERC                                                       100.0
# INCOME_PER_PERSON                                                        100.0
# ANNUITY_INCOME_PERC                                                      100.0
# PAYMENT_RATE                                                             100.0
# SK_ID_CURR                                                               100.0
# ORGANIZATION_TYPE_Trade: type 7                                          100.0
# ORGANIZATION_TYPE_Trade: type 5                                          100.0
# ORGANIZATION_TYPE_Industry: type 3                                       100.0
# ORGANIZATION_TYPE_Trade: type 4                                          100.0
# ORGANIZATION_TYPE_Industry: type 4                                       100.0
# ORGANIZATION_TYPE_Industry: type 5                                       100.0
# ORGANIZATION_TYPE_Industry: type 6                                       100.0
# ORGANIZATION_TYPE_Industry: type 7                                       100.0
# ORGANIZATION_TYPE_Industry: type 8                                       100.0
# ORGANIZATION_TYPE_Industry: type 9                                       100.0
# ORGANIZATION_TYPE_Insurance                                              100.0
# ORGANIZATION_TYPE_Kindergarten                                           100.0
# ORGANIZATION_TYPE_Legal Services                                         100.0
# ORGANIZATION_TYPE_Medicine                                               100.0
# ORGANIZATION_TYPE_Military                                               100.0
# ORGANIZATION_TYPE_Mobile                                                 100.0
# ORGANIZATION_TYPE_Other                                                  100.0
# ORGANIZATION_TYPE_Police                                                 100.0
# ORGANIZATION_TYPE_Postal                                                 100.0
# ORGANIZATION_TYPE_Realtor                                                100.0
# ORGANIZATION_TYPE_Religion                                               100.0
# ORGANIZATION_TYPE_Restaurant                                             100.0
# ORGANIZATION_TYPE_School                                                 100.0
# ORGANIZATION_TYPE_Security                                               100.0
# ORGANIZATION_TYPE_Security Ministries                                    100.0
# ORGANIZATION_TYPE_Self-employed                                          100.0
# ORGANIZATION_TYPE_Services                                               100.0
# ORGANIZATION_TYPE_Telecom                                                100.0
# ORGANIZATION_TYPE_Trade: type 1                                          100.0
# ORGANIZATION_TYPE_Trade: type 2                                          100.0
# ORGANIZATION_TYPE_Trade: type 3                                          100.0
# NAME_INCOME_TYPE_Working                                                 100.0
# NB_NAN                                                                   100.0
# NAME_INCOME_TYPE_Student                                                 100.0
# REG_CITY_NOT_LIVE_CITY                                                   100.0
# CNT_FAM_MEMBERS                                                          100.0
# REGION_RATING_CLIENT                                                     100.0
# REGION_RATING_CLIENT_W_CITY                                              100.0
# HOUR_APPR_PROCESS_START                                                  100.0
# REG_REGION_NOT_LIVE_REGION                                               100.0
# REG_REGION_NOT_WORK_REGION                                               100.0
# LIVE_REGION_NOT_WORK_REGION                                              100.0
# REG_CITY_NOT_WORK_CITY                                                   100.0
# FLAG_DOCUMENT_3                                                          100.0
# EXT_SOURCE_2                                                             100.0
# TARGET                                                                   100.0
# OBS_30_CNT_SOCIAL_CIRCLE                                                 100.0
# DEF_30_CNT_SOCIAL_CIRCLE                                                 100.0
# OBS_60_CNT_SOCIAL_CIRCLE                                                 100.0
# DEF_60_CNT_SOCIAL_CIRCLE                                                 100.0
# DAYS_LAST_PHONE_CHANGE                                                   100.0
# FLAG_EMAIL                                                               100.0
# FLAG_PHONE                                                               100.0
# FLAG_CONT_MOBILE                                                         100.0
# FLAG_WORK_PHONE                                                          100.0
# NAME_INCOME_TYPE_State servant                                           100.0
# CODE_GENDER                                                              100.0
# FLAG_OWN_CAR                                                             100.0
# FLAG_OWN_REALTY                                                          100.0
# CNT_CHILDREN                                                             100.0
# AMT_INCOME_TOTAL                                                         100.0
# AMT_CREDIT                                                               100.0
# AMT_ANNUITY                                                              100.0
# AMT_GOODS_PRICE                                                          100.0
# REGION_POPULATION_RELATIVE                                               100.0
# DAYS_BIRTH                                                               100.0
# DAYS_REGISTRATION                                                        100.0
# DAYS_ID_PUBLISH                                                          100.0
# FLAG_MOBIL                                                               100.0
# FLAG_EMP_PHONE                                                           100.0
# FLAG_DOCUMENT_2                                                          100.0
# LIVE_CITY_NOT_WORK_CITY                                                  100.0
# FLAG_DOCUMENT_4                                                          100.0
# NAME_CONTRACT_TYPE_Revolving loans                                       100.0
# FLAG_DOCUMENT_13                                                         100.0
# FLAG_DOCUMENT_14                                                         100.0
# FLAG_DOCUMENT_15                                                         100.0
# FLAG_DOCUMENT_16                                                         100.0
# FLAG_DOCUMENT_17                                                         100.0
# FLAG_DOCUMENT_18                                                         100.0
# FLAG_DOCUMENT_19                                                         100.0
# FLAG_DOCUMENT_20                                                         100.0
# FLAG_DOCUMENT_21                                                         100.0
# NAME_CONTRACT_TYPE_Cash loans                                            100.0
# FLAG_DOCUMENT_5                                                          100.0
# FLAG_DOCUMENT_11                                                         100.0
# NAME_TYPE_SUITE_Family                                                   100.0
# NAME_TYPE_SUITE_Group of people                                          100.0
# NAME_TYPE_SUITE_Other_A                                                  100.0
# NAME_TYPE_SUITE_Other_B                                                  100.0
# NAME_TYPE_SUITE_Spouse, partner                                          100.0
# NAME_TYPE_SUITE_Unaccompanied                                            100.0
# NAME_INCOME_TYPE_Businessman                                             100.0
# NAME_INCOME_TYPE_Commercial associate                                    100.0
# NAME_INCOME_TYPE_Maternity leave                                         100.0
# NAME_INCOME_TYPE_Pensioner                                               100.0
# FLAG_DOCUMENT_12                                                         100.0
# NAME_TYPE_SUITE_Children                                                 100.0
# FLAG_DOCUMENT_6                                                          100.0
# FLAG_DOCUMENT_7                                                          100.0
# FLAG_DOCUMENT_8                                                          100.0
# FLAG_DOCUMENT_9                                                          100.0
# FLAG_DOCUMENT_10                                                         100.0
# INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE                                     95.0
# INSTAL_DAYS_ENTRY_PAYMENT_MEAN                                            95.0
# INSTAL_DBD_MEAN                                                           95.0
# INSTAL_DBD_SUM                                                            95.0
# INSTAL_PAYMENT_PERC_MAX                                                   95.0
# INSTAL_PAYMENT_PERC_MEAN                                                  95.0
# INSTAL_PAYMENT_PERC_SUM                                                   95.0
# INSTAL_AMT_PAYMENT_MEAN                                                   95.0
# INSTAL_AMT_PAYMENT_SUM                                                    95.0
# INSTAL_DAYS_ENTRY_PAYMENT_MAX                                             95.0
# INSTAL_PAYMENT_DIFF_MEAN                                                  95.0
# INSTAL_DAYS_ENTRY_PAYMENT_SUM                                             95.0
# INSTAL_COUNT                                                              95.0
# INSTAL_DPD_SUM                                                            95.0
# INSTAL_PAYMENT_DIFF_SUM                                                   95.0
# INSTAL_AMT_INSTALMENT_MAX                                                 95.0
# INSTAL_AMT_INSTALMENT_MEAN                                                95.0
# INSTAL_AMT_INSTALMENT_SUM                                                 95.0
# INSTAL_AMT_PAYMENT_MIN                                                    95.0
# INSTAL_AMT_PAYMENT_MAX                                                    95.0
# INSTAL_DBD_MAX                                                            95.0
# INSTAL_PAYMENT_DIFF_MAX                                                   95.0
# INSTAL_DPD_MEAN                                                           95.0
# INSTAL_DPD_MAX                                                            95.0
# PREV_NAME_GOODS_CATEGORY_Computers_MEAN                                   94.0
# PREV_NAME_CLIENT_TYPE_New_MEAN                                            94.0
# PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN                          94.0
# PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN                                    94.0
# PREV_NAME_GOODS_CATEGORY_Weapon_MEAN                                      94.0
# PREV_NAME_GOODS_CATEGORY_XNA_MEAN                                         94.0
# PREV_NAME_CLIENT_TYPE_nan_MEAN                                            94.0
# PREV_NAME_CLIENT_TYPE_XNA_MEAN                                            94.0
# PREV_NAME_CLIENT_TYPE_Repeater_MEAN                                       94.0
# PREV_NAME_CLIENT_TYPE_Refreshed_MEAN                                      94.0
# PREV_NAME_TYPE_SUITE_nan_MEAN                                             94.0
# PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN                           94.0
# PREV_NAME_GOODS_CATEGORY_nan_MEAN                                         94.0
# PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN                                 94.0
# PREV_NAME_TYPE_SUITE_Other_B_MEAN                                         94.0
# PREV_NAME_TYPE_SUITE_Other_A_MEAN                                         94.0
# PREV_NAME_TYPE_SUITE_Group of people_MEAN                                 94.0
# PREV_NAME_TYPE_SUITE_Family_MEAN                                          94.0
# PREV_NAME_TYPE_SUITE_Children_MEAN                                        94.0
# PREV_CODE_REJECT_REASON_nan_MEAN                                          94.0
# PREV_NAME_GOODS_CATEGORY_Tourism_MEAN                                     94.0
# PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN                    94.0
# PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN                      94.0
# PREV_NAME_GOODS_CATEGORY_Other_MEAN                                       94.0
# PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN                        94.0
# PREV_NAME_GOODS_CATEGORY_Direct Sales_MEAN                                94.0
# PREV_NAME_GOODS_CATEGORY_Education_MEAN                                   94.0
# PREV_NAME_GOODS_CATEGORY_Fitness_MEAN                                     94.0
# PREV_NAME_GOODS_CATEGORY_Furniture_MEAN                                   94.0
# PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN                    94.0
# PREV_CODE_REJECT_REASON_XAP_MEAN                                          94.0
# PREV_NAME_GOODS_CATEGORY_Gardening_MEAN                                   94.0
# PREV_NAME_GOODS_CATEGORY_Homewares_MEAN                                   94.0
# PREV_NAME_GOODS_CATEGORY_House Construction_MEAN                          94.0
# PREV_NAME_GOODS_CATEGORY_Insurance_MEAN                                   94.0
# PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN                                     94.0
# PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN                            94.0
# PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN                            94.0
# PREV_NAME_GOODS_CATEGORY_Medicine_MEAN                                    94.0
# PREV_NAME_GOODS_CATEGORY_Mobile_MEAN                                      94.0
# PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN                                 94.0
# PREV_NAME_GOODS_CATEGORY_Animals_MEAN                                     94.0
# PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN                           94.0
# PREV_CODE_REJECT_REASON_XNA_MEAN                                          94.0
# PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN                               94.0
# PREV_CODE_REJECT_REASON_VERIF_MEAN                                        94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN              94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN                                  94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN                 94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN         94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN                  94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN                                    94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN                 94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN                                 94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN                                  94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN                                    94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN                                94.0
# PREV_CODE_REJECT_REASON_SYSTEM_MEAN                                       94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN                        94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN                                94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN                              94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN                        94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN                         94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN                            94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN             94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN                          94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN                     94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN                             94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN                 94.0
# PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN                                      94.0
# PREV_NAME_PORTFOLIO_Cars_MEAN                                             94.0
# PREV_CODE_REJECT_REASON_SCOFR_MEAN                                        94.0
# PREV_CODE_REJECT_REASON_SCO_MEAN                                          94.0
# PREV_CODE_REJECT_REASON_LIMIT_MEAN                                        94.0
# PREV_CODE_REJECT_REASON_HC_MEAN                                           94.0
# PREV_CODE_REJECT_REASON_CLIENT_MEAN                                       94.0
# PREV_NAME_PAYMENT_TYPE_nan_MEAN                                           94.0
# PREV_NAME_PAYMENT_TYPE_XNA_MEAN                                           94.0
# PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN                    94.0
# PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN     94.0
# PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN                         94.0
# PREV_NAME_CONTRACT_STATUS_nan_MEAN                                        94.0
# PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN             94.0
# PREV_NAME_CONTRACT_STATUS_Refused_MEAN                                    94.0
# PREV_NAME_CONTRACT_STATUS_Canceled_MEAN                                   94.0
# PREV_NAME_CONTRACT_STATUS_Approved_MEAN                                   94.0
# PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN                                   94.0
# PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN                                      94.0
# PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN                                      94.0
# PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN                                 94.0
# PREV_NAME_PORTFOLIO_Cards_MEAN                                            94.0
# PREV_PRODUCT_COMBINATION_POS household without interest_MEAN              94.0
# PREV_NAME_PORTFOLIO_Cash_MEAN                                             94.0
# APPROVED_AMT_CREDIT_MIN                                                   94.0
# APPROVED_DAYS_DECISION_MIN                                                94.0
# APPROVED_HOUR_APPR_PROCESS_START_MEAN                                     94.0
# APPROVED_HOUR_APPR_PROCESS_START_MAX                                      94.0
# APPROVED_HOUR_APPR_PROCESS_START_MIN                                      94.0
# APPROVED_APP_CREDIT_PERC_MEAN                                             94.0
# APPROVED_APP_CREDIT_PERC_MAX                                              94.0
# APPROVED_APP_CREDIT_PERC_MIN                                              94.0
# APPROVED_AMT_CREDIT_MEAN                                                  94.0
# APPROVED_AMT_CREDIT_MAX                                                   94.0
# APPROVED_AMT_APPLICATION_MEAN                                             94.0
# APPROVED_DAYS_DECISION_MEAN                                               94.0
# APPROVED_AMT_APPLICATION_MAX                                              94.0
# APPROVED_AMT_APPLICATION_MIN                                              94.0
# APPROVED_AMT_ANNUITY_MEAN                                                 94.0
# APPROVED_AMT_ANNUITY_MAX                                                  94.0
# APPROVED_AMT_ANNUITY_MIN                                                  94.0
# PREV_PRODUCT_COMBINATION_nan_MEAN                                         94.0
# PREV_PRODUCT_COMBINATION_POS others without interest_MEAN                 94.0
# PREV_PRODUCT_COMBINATION_POS other with interest_MEAN                     94.0
# PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN                 94.0
# APPROVED_DAYS_DECISION_MAX                                                94.0
# APPROVED_CNT_PAYMENT_MEAN                                                 94.0
# PREV_NAME_PORTFOLIO_POS_MEAN                                              94.0
# POS_NAME_CONTRACT_STATUS_Canceled_MEAN                                    94.0
# INSTAL_PAYMENT_DIFF_VAR                                                   94.0
# INSTAL_PAYMENT_PERC_VAR                                                   94.0
# POS_COUNT                                                                 94.0
# POS_NAME_CONTRACT_STATUS_nan_MEAN                                         94.0
# POS_NAME_CONTRACT_STATUS_XNA_MEAN                                         94.0
# POS_NAME_CONTRACT_STATUS_Signed_MEAN                                      94.0
# POS_NAME_CONTRACT_STATUS_Returned to the store_MEAN                       94.0
# POS_NAME_CONTRACT_STATUS_Demand_MEAN                                      94.0
# POS_NAME_CONTRACT_STATUS_Completed_MEAN                                   94.0
# POS_NAME_CONTRACT_STATUS_Approved_MEAN                                    94.0
# APPROVED_CNT_PAYMENT_SUM                                                  94.0
# POS_NAME_CONTRACT_STATUS_Amortized debt_MEAN                              94.0
# POS_NAME_CONTRACT_STATUS_Active_MEAN                                      94.0
# POS_SK_DPD_DEF_MEAN                                                       94.0
# POS_SK_DPD_DEF_MAX                                                        94.0
# POS_SK_DPD_MEAN                                                           94.0
# POS_SK_DPD_MAX                                                            94.0
# POS_MONTHS_BALANCE_SIZE                                                   94.0
# POS_MONTHS_BALANCE_MEAN                                                   94.0
# POS_MONTHS_BALANCE_MAX                                                    94.0
# PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN                    94.0
# PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN               94.0
# PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN                  94.0
# PREV_CHANNEL_TYPE_Country-wide_MEAN                                       94.0
# PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN                       94.0
# PREV_NAME_SELLER_INDUSTRY_Construction_MEAN                               94.0
# PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN                               94.0
# PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN                                   94.0
# PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN                            94.0
# PREV_CHANNEL_TYPE_nan_MEAN                                                94.0
# PREV_CHANNEL_TYPE_Stone_MEAN                                              94.0
# PREV_CHANNEL_TYPE_Regional / Local_MEAN                                   94.0
# PREV_CHANNEL_TYPE_Credit and cash offices_MEAN                            94.0
# PREV_CHANNEL_TYPE_Contact center_MEAN                                     94.0
# PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN                                  94.0
# PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN                         94.0
# PREV_CHANNEL_TYPE_Car dealer_MEAN                                         94.0
# PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN                                    94.0
# PREV_NAME_PRODUCT_TYPE_nan_MEAN                                           94.0
# PREV_NAME_PRODUCT_TYPE_x-sell_MEAN                                        94.0
# PREV_NAME_PRODUCT_TYPE_walk-in_MEAN                                       94.0
# PREV_NAME_PRODUCT_TYPE_XNA_MEAN                                           94.0
# PREV_NAME_PORTFOLIO_nan_MEAN                                              94.0
# PREV_NAME_PORTFOLIO_XNA_MEAN                                              94.0
# PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN                                  94.0
# PREV_NAME_SELLER_INDUSTRY_Industry_MEAN                                   94.0
# PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN                                    94.0
# PREV_NAME_SELLER_INDUSTRY_MLM partners_MEAN                               94.0
# PREV_PRODUCT_COMBINATION_POS household with interest_MEAN                 94.0
# PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN                         94.0
# PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN                            94.0
# PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN                           94.0
# PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN                         94.0
# PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN                            94.0
# PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN                           94.0
# PREV_PRODUCT_COMBINATION_Cash_MEAN                                        94.0
# PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN                                 94.0
# PREV_PRODUCT_COMBINATION_Card Street_MEAN                                 94.0
# PREV_NAME_YIELD_GROUP_nan_MEAN                                            94.0
# PREV_NAME_YIELD_GROUP_middle_MEAN                                         94.0
# PREV_NAME_YIELD_GROUP_low_normal_MEAN                                     94.0
# PREV_NAME_YIELD_GROUP_low_action_MEAN                                     94.0
# PREV_NAME_YIELD_GROUP_high_MEAN                                           94.0
# PREV_NAME_YIELD_GROUP_XNA_MEAN                                            94.0
# PREV_NAME_SELLER_INDUSTRY_nan_MEAN                                        94.0
# PREV_NAME_SELLER_INDUSTRY_XNA_MEAN                                        94.0
# PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN                                    94.0
# PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN                                   94.0
# PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN                                   94.0
# PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN                            94.0
# PREV_AMT_CREDIT_MAX                                                       94.0
# PREV_AMT_GOODS_PRICE_MEAN                                                 94.0
# PREV_AMT_GOODS_PRICE_MAX                                                  94.0
# PREV_AMT_GOODS_PRICE_MIN                                                  94.0
# PREV_APP_CREDIT_PERC_MEAN                                                 94.0
# PREV_APP_CREDIT_PERC_MAX                                                  94.0
# PREV_APP_CREDIT_PERC_MIN                                                  94.0
# PREV_AMT_CREDIT_MEAN                                                      94.0
# PREV_AMT_CREDIT_MIN                                                       94.0
# PREV_HOUR_APPR_PROCESS_START_MAX                                          94.0
# PREV_AMT_APPLICATION_MEAN                                                 94.0
# PREV_AMT_APPLICATION_MAX                                                  94.0
# PREV_AMT_APPLICATION_MIN                                                  94.0
# PREV_AMT_ANNUITY_MEAN                                                     94.0
# PREV_AMT_ANNUITY_MAX                                                      94.0
# PREV_AMT_ANNUITY_MIN                                                      94.0
# PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN                              94.0
# PREV_HOUR_APPR_PROCESS_START_MIN                                          94.0
# PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN                               94.0
# PREV_HOUR_APPR_PROCESS_START_MEAN                                         94.0
# PREV_CNT_PAYMENT_MEAN                                                     94.0
# PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN                               94.0
# PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN                             94.0
# PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN                               94.0
# PREV_NAME_CONTRACT_TYPE_nan_MEAN                                          94.0
# PREV_NAME_CONTRACT_TYPE_XNA_MEAN                                          94.0
# PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN                              94.0
# PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN                               94.0
# PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN                                   94.0
# PREV_CNT_PAYMENT_SUM                                                      94.0
# PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN                             94.0
# PREV_DAYS_DECISION_MEAN                                                   94.0
# PREV_DAYS_DECISION_MAX                                                    94.0
# PREV_DAYS_DECISION_MIN                                                    94.0
# APPROVED_AMT_GOODS_PRICE_MIN                                              93.0
# APPROVED_AMT_GOODS_PRICE_MAX                                              93.0
# APPROVED_AMT_GOODS_PRICE_MEAN                                             93.0
# APPROVED_RATE_DOWN_PAYMENT_MAX                                            89.0
# APPROVED_AMT_DOWN_PAYMENT_MAX                                             89.0
# APPROVED_AMT_DOWN_PAYMENT_MEAN                                            89.0
# APPROVED_RATE_DOWN_PAYMENT_MIN                                            89.0
# APPROVED_AMT_DOWN_PAYMENT_MIN                                             89.0
# PREV_AMT_DOWN_PAYMENT_MIN                                                 89.0
# PREV_AMT_DOWN_PAYMENT_MAX                                                 89.0
# PREV_RATE_DOWN_PAYMENT_MIN                                                89.0
# APPROVED_RATE_DOWN_PAYMENT_MEAN                                           89.0
# PREV_RATE_DOWN_PAYMENT_MAX                                                89.0
# PREV_RATE_DOWN_PAYMENT_MEAN                                               89.0
# PREV_AMT_DOWN_PAYMENT_MEAN                                                89.0
# AMT_REQ_CREDIT_BUREAU_HOUR                                                86.0
# AMT_REQ_CREDIT_BUREAU_MON                                                 86.0
# AMT_REQ_CREDIT_BUREAU_QRT                                                 86.0
# AMT_REQ_CREDIT_BUREAU_DAY                                                 86.0
# AMT_REQ_CREDIT_BUREAU_WEEK                                                86.0
# AMT_REQ_CREDIT_BUREAU_YEAR                                                86.0
# BURO_CREDIT_CURRENCY_currency 2_MEAN                                      85.0
# BURO_CREDIT_CURRENCY_currency 3_MEAN                                      85.0
# BURO_CREDIT_CURRENCY_currency 4_MEAN                                      85.0
# BURO_CREDIT_CURRENCY_nan_MEAN                                             85.0
# BURO_CREDIT_TYPE_Another type of loan_MEAN                                85.0
# BURO_CREDIT_TYPE_Car loan_MEAN                                            85.0
# BURO_CREDIT_TYPE_Cash loan (non-earmarked)_MEAN                           85.0
# BURO_CREDIT_TYPE_Consumer credit_MEAN                                     85.0
# BURO_CREDIT_TYPE_Loan for working capital replenishment_MEAN              85.0
# BURO_CREDIT_TYPE_Credit card_MEAN                                         85.0
# BURO_CREDIT_TYPE_Interbank credit_MEAN                                    85.0
# BURO_CREDIT_TYPE_Loan for business development_MEAN                       85.0
# BURO_CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN        85.0
# BURO_CREDIT_TYPE_Loan for the purchase of equipment_MEAN                  85.0
# BURO_CREDIT_TYPE_Microloan_MEAN                                           85.0
# BURO_CREDIT_TYPE_Mobile operator loan_MEAN                                85.0
# BURO_CREDIT_TYPE_Mortgage_MEAN                                            85.0
# BURO_CREDIT_TYPE_Real estate loan_MEAN                                    85.0
# BURO_CREDIT_ACTIVE_nan_MEAN                                               85.0
# BURO_CREDIT_CURRENCY_currency 1_MEAN                                      85.0
# BURO_AMT_CREDIT_SUM_MEAN                                                  85.0
# BURO_CREDIT_ACTIVE_Sold_MEAN                                              85.0
# BURO_CREDIT_DAY_OVERDUE_MEAN                                              85.0
# BURO_DAYS_CREDIT_MIN                                                      85.0
# BURO_DAYS_CREDIT_MAX                                                      85.0
# BURO_DAYS_CREDIT_MEAN                                                     85.0
# BURO_DAYS_CREDIT_ENDDATE_MIN                                              85.0
# BURO_CREDIT_TYPE_nan_MEAN                                                 85.0
# BURO_DAYS_CREDIT_ENDDATE_MEAN                                             85.0
# BURO_DAYS_CREDIT_UPDATE_MEAN                                              85.0
# BURO_CREDIT_DAY_OVERDUE_MAX                                               85.0
# BURO_AMT_CREDIT_SUM_MAX                                                   85.0
# BURO_CREDIT_ACTIVE_Closed_MEAN                                            85.0
# BURO_AMT_CREDIT_SUM_SUM                                                   85.0
# BURO_AMT_CREDIT_SUM_DEBT_SUM                                              85.0
# BURO_AMT_CREDIT_SUM_OVERDUE_MEAN                                          85.0
# BURO_AMT_CREDIT_SUM_LIMIT_SUM                                             85.0
# BURO_CNT_CREDIT_PROLONG_SUM                                               85.0
# BURO_MONTHS_BALANCE_SIZE_SUM                                              85.0
# BURO_CREDIT_ACTIVE_Active_MEAN                                            85.0
# BURO_CREDIT_ACTIVE_Bad debt_MEAN                                          85.0
# BURO_DAYS_CREDIT_ENDDATE_MAX                                              85.0
# BURO_CREDIT_TYPE_Unknown type of loan_MEAN                                85.0
# BURO_AMT_CREDIT_SUM_DEBT_MAX                                              83.0
# BURO_AMT_CREDIT_SUM_DEBT_MEAN                                             83.0
# DAYS_EMPLOYED                                                             81.0
# DAYS_EMPLOYED_PERC                                                        81.0
# EXT_SOURCE_3                                                              80.0
# BURO_AMT_CREDIT_SUM_LIMIT_MEAN                                            79.0
# BURO_DAYS_CREDIT_VAR                                                      75.0
# CLOSED_DAYS_CREDIT_MIN                                                    74.0
# CLOSED_AMT_CREDIT_SUM_SUM                                                 74.0
# CLOSED_AMT_CREDIT_SUM_MEAN                                                74.0
# CLOSED_AMT_CREDIT_SUM_MAX                                                 74.0
# CLOSED_DAYS_CREDIT_MEAN                                                   74.0
# CLOSED_CREDIT_DAY_OVERDUE_MEAN                                            74.0
# CLOSED_DAYS_CREDIT_MAX                                                    74.0
# CLOSED_DAYS_CREDIT_ENDDATE_MIN                                            74.0
# CLOSED_DAYS_CREDIT_ENDDATE_MAX                                            74.0
# CLOSED_DAYS_CREDIT_ENDDATE_MEAN                                           74.0
# CLOSED_DAYS_CREDIT_UPDATE_MEAN                                            74.0
# CLOSED_AMT_CREDIT_SUM_DEBT_SUM                                            74.0
# CLOSED_CREDIT_DAY_OVERDUE_MAX                                             74.0
# PREV_APP_CREDIT_PERC_VAR                                                  74.0
# CLOSED_MONTHS_BALANCE_SIZE_SUM                                            74.0
# CLOSED_CNT_CREDIT_PROLONG_SUM                                             74.0
# CLOSED_AMT_CREDIT_SUM_LIMIT_SUM                                           74.0
# CLOSED_AMT_CREDIT_SUM_OVERDUE_MEAN                                        74.0
# ACTIVE_AMT_CREDIT_SUM_MAX                                                 71.0
# ACTIVE_CREDIT_DAY_OVERDUE_MAX                                             71.0
# ACTIVE_DAYS_CREDIT_MIN                                                    71.0
# ACTIVE_DAYS_CREDIT_MAX                                                    71.0
# ACTIVE_DAYS_CREDIT_MEAN                                                   71.0
# ACTIVE_MONTHS_BALANCE_SIZE_SUM                                            71.0
# ACTIVE_AMT_CREDIT_SUM_MEAN                                                71.0
# ACTIVE_DAYS_CREDIT_UPDATE_MEAN                                            71.0
# ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN                                        71.0
# ACTIVE_AMT_CREDIT_SUM_DEBT_SUM                                            71.0
# ACTIVE_CNT_CREDIT_PROLONG_SUM                                             71.0
# ACTIVE_AMT_CREDIT_SUM_SUM                                                 71.0
# CLOSED_AMT_CREDIT_SUM_DEBT_MEAN                                           71.0
# ACTIVE_CREDIT_DAY_OVERDUE_MEAN                                            71.0
# ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM                                           71.0
# CLOSED_AMT_CREDIT_SUM_DEBT_MAX                                            71.0
# APPROVED_APP_CREDIT_PERC_VAR                                              69.0
# ACTIVE_AMT_CREDIT_SUM_DEBT_MAX                                            68.0
# ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN                                           68.0
# ACTIVE_DAYS_CREDIT_ENDDATE_MEAN                                           68.0
# ACTIVE_DAYS_CREDIT_ENDDATE_MIN                                            68.0
# ACTIVE_DAYS_CREDIT_ENDDATE_MAX                                            68.0
# CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN                                          64.0
# ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN                                          62.0
# BURO_AMT_CREDIT_MAX_OVERDUE_MEAN                                          60.0
# CLOSED_DAYS_CREDIT_VAR                                                    58.0
# YEARS_BEGINEXPLUATATION_AVG                                               51.0
# YEARS_BEGINEXPLUATATION_MODE                                              51.0
# YEARS_BEGINEXPLUATATION_MEDI                                              51.0
# TOTALAREA_MODE                                                            51.0
# FLOORSMAX_AVG                                                             50.0
# FLOORSMAX_MEDI                                                            50.0
# FLOORSMAX_MODE                                                            50.0
# ENTRANCES_AVG                                                             49.0
# LIVINGAREA_MODE                                                           49.0
# APARTMENTS_AVG                                                            49.0
# LIVINGAREA_AVG                                                            49.0
# APARTMENTS_MODE                                                           49.0
# ENTRANCES_MEDI                                                            49.0
# LIVINGAREA_MEDI                                                           49.0
# ENTRANCES_MODE                                                            49.0
# APARTMENTS_MEDI                                                           49.0
# ACTIVE_DAYS_CREDIT_VAR                                                    48.0
# CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN                                        48.0
# ELEVATORS_AVG                                                             46.0
# ELEVATORS_MEDI                                                            46.0
# ELEVATORS_MODE                                                            46.0
# NONLIVINGAREA_MEDI                                                        44.0
# NONLIVINGAREA_AVG                                                         44.0
# NONLIVINGAREA_MODE                                                        44.0
# EXT_SOURCE_1                                                              43.0
# LANDAREA_AVG                                                              41.0
# BASEMENTAREA_MEDI                                                         41.0
# BASEMENTAREA_MODE                                                         41.0
# BASEMENTAREA_AVG                                                          41.0
# LANDAREA_MEDI                                                             41.0
# LANDAREA_MODE                                                             41.0
# ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN                                        38.0
# OWN_CAR_AGE                                                               35.0
# REFUSED_DAYS_DECISION_MAX                                                 33.0
# REFUSED_HOUR_APPR_PROCESS_START_MEAN                                      33.0
# REFUSED_DAYS_DECISION_MIN                                                 33.0
# YEARS_BUILD_MEDI                                                          33.0
# REFUSED_DAYS_DECISION_MEAN                                                33.0
# YEARS_BUILD_MODE                                                          33.0
# REFUSED_HOUR_APPR_PROCESS_START_MAX                                       33.0
# REFUSED_CNT_PAYMENT_SUM                                                   33.0
# REFUSED_HOUR_APPR_PROCESS_START_MIN                                       33.0
# REFUSED_AMT_APPLICATION_MIN                                               33.0
# REFUSED_AMT_APPLICATION_MAX                                               33.0
# REFUSED_AMT_APPLICATION_MEAN                                              33.0
# REFUSED_AMT_CREDIT_MIN                                                    33.0
# REFUSED_AMT_CREDIT_MAX                                                    33.0
# YEARS_BUILD_AVG                                                           33.0
# REFUSED_AMT_CREDIT_MEAN                                                   33.0
# REFUSED_APP_CREDIT_PERC_MIN                                               31.0
# LIVINGAPARTMENTS_AVG                                                      31.0
# FLOORSMIN_AVG                                                             31.0
# REFUSED_APP_CREDIT_PERC_MAX                                               31.0
# FLOORSMIN_MODE                                                            31.0
# LIVINGAPARTMENTS_MODE                                                     31.0
# REFUSED_APP_CREDIT_PERC_MEAN                                              31.0
# FLOORSMIN_MEDI                                                            31.0
# LIVINGAPARTMENTS_MEDI                                                     31.0
# REFUSED_AMT_GOODS_PRICE_MEAN                                              31.0
# REFUSED_AMT_GOODS_PRICE_MAX                                               31.0
# REFUSED_AMT_GOODS_PRICE_MIN                                               31.0
# REFUSED_AMT_ANNUITY_MAX                                                   30.0
# NONLIVINGAPARTMENTS_MODE                                                  30.0
# REFUSED_AMT_ANNUITY_MIN                                                   30.0
# NONLIVINGAPARTMENTS_MEDI                                                  30.0
# NONLIVINGAPARTMENTS_AVG                                                   30.0
# REFUSED_AMT_ANNUITY_MEAN                                                  30.0
# REFUSED_CNT_PAYMENT_MEAN                                                  30.0
# BURO_STATUS_0_MEAN_MEAN                                                   29.0
# BURO_STATUS_nan_MEAN_MEAN                                                 29.0
# BURO_STATUS_X_MEAN_MEAN                                                   29.0
# BURO_STATUS_C_MEAN_MEAN                                                   29.0
# COMMONAREA_MEDI                                                           29.0
# BURO_STATUS_5_MEAN_MEAN                                                   29.0
# BURO_STATUS_4_MEAN_MEAN                                                   29.0
# BURO_STATUS_2_MEAN_MEAN                                                   29.0
# BURO_STATUS_1_MEAN_MEAN                                                   29.0
# BURO_STATUS_3_MEAN_MEAN                                                   29.0
# COMMONAREA_AVG                                                            29.0
# BURO_MONTHS_BALANCE_SIZE_MEAN                                             29.0
# BURO_MONTHS_BALANCE_MAX_MAX                                               29.0
# BURO_MONTHS_BALANCE_MIN_MIN                                               29.0
# COMMONAREA_MODE                                                           29.0
# CC_CNT_DRAWINGS_ATM_CURRENT_SUM                                           28.0
# CC_AMT_TOTAL_RECEIVABLE_MAX                                               28.0
# CC_AMT_TOTAL_RECEIVABLE_MEAN                                              28.0
# CC_AMT_TOTAL_RECEIVABLE_SUM                                               28.0
# CC_AMT_TOTAL_RECEIVABLE_VAR                                               28.0
# CC_NAME_CONTRACT_STATUS_Demand_MEAN                                       28.0
# CC_CNT_DRAWINGS_CURRENT_MEAN                                              28.0
# CC_NAME_CONTRACT_STATUS_Demand_MAX                                        28.0
# CC_NAME_CONTRACT_STATUS_Demand_MIN                                        28.0
# CC_NAME_CONTRACT_STATUS_Completed_VAR                                     28.0
# CC_CNT_DRAWINGS_CURRENT_MAX                                               28.0
# CC_CNT_DRAWINGS_CURRENT_MIN                                               28.0
# CC_AMT_RECIVABLE_VAR                                                      28.0
# CC_AMT_TOTAL_RECEIVABLE_MIN                                               28.0
# CC_AMT_RECEIVABLE_PRINCIPAL_MAX                                           28.0
# CC_AMT_RECIVABLE_SUM                                                      28.0
# CC_AMT_RECIVABLE_MEAN                                                     28.0
# CC_AMT_RECIVABLE_MAX                                                      28.0
# CC_AMT_RECIVABLE_MIN                                                      28.0
# CC_AMT_RECEIVABLE_PRINCIPAL_VAR                                           28.0
# CC_AMT_RECEIVABLE_PRINCIPAL_SUM                                           28.0
# CC_AMT_RECEIVABLE_PRINCIPAL_MEAN                                          28.0
# CC_CNT_DRAWINGS_CURRENT_VAR                                               28.0
# CC_AMT_RECEIVABLE_PRINCIPAL_MIN                                           28.0
# CC_AMT_PAYMENT_TOTAL_CURRENT_VAR                                          28.0
# CC_AMT_PAYMENT_TOTAL_CURRENT_SUM                                          28.0
# CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN                                         28.0
# CC_AMT_PAYMENT_TOTAL_CURRENT_MAX                                          28.0
# CC_AMT_PAYMENT_TOTAL_CURRENT_MIN                                          28.0
# CC_CNT_DRAWINGS_CURRENT_SUM                                               28.0
# CC_CNT_DRAWINGS_POS_CURRENT_SUM                                           28.0
# CC_NAME_CONTRACT_STATUS_Completed_SUM                                     28.0
# CC_NAME_CONTRACT_STATUS_Completed_MEAN                                    28.0
# CC_SK_DPD_DEF_SUM                                                         28.0
# CC_SK_DPD_DEF_MEAN                                                        28.0
# CC_SK_DPD_DEF_VAR                                                         28.0
# CC_NAME_CONTRACT_STATUS_Active_MIN                                        28.0
# CC_NAME_CONTRACT_STATUS_Active_MAX                                        28.0
# CC_NAME_CONTRACT_STATUS_Active_MEAN                                       28.0
# CC_SK_DPD_DEF_MAX                                                         28.0
# CC_NAME_CONTRACT_STATUS_Active_SUM                                        28.0
# CC_SK_DPD_DEF_MIN                                                         28.0
# CC_AMT_PAYMENT_CURRENT_SUM                                                28.0
# CC_SK_DPD_VAR                                                             28.0
# CC_SK_DPD_SUM                                                             28.0
# CC_SK_DPD_MEAN                                                            28.0
# CC_SK_DPD_MAX                                                             28.0
# CC_SK_DPD_MIN                                                             28.0
# CC_CNT_INSTALMENT_MATURE_CUM_VAR                                          28.0
# CC_CNT_INSTALMENT_MATURE_CUM_SUM                                          28.0
# CC_CNT_INSTALMENT_MATURE_CUM_MEAN                                         28.0
# CC_CNT_INSTALMENT_MATURE_CUM_MAX                                          28.0
# CC_CNT_INSTALMENT_MATURE_CUM_MIN                                          28.0
# CC_NAME_CONTRACT_STATUS_Approved_MAX                                      28.0
# CC_NAME_CONTRACT_STATUS_Approved_MEAN                                     28.0
# CC_NAME_CONTRACT_STATUS_Approved_SUM                                      28.0
# CC_NAME_CONTRACT_STATUS_Approved_VAR                                      28.0
# CC_NAME_CONTRACT_STATUS_Completed_MIN                                     28.0
# CC_CNT_DRAWINGS_OTHER_CURRENT_SUM                                         28.0
# CC_NAME_CONTRACT_STATUS_Completed_MAX                                     28.0
# CC_NAME_CONTRACT_STATUS_Demand_SUM                                        28.0
# CC_AMT_DRAWINGS_CURRENT_MEAN                                              28.0
# CC_NAME_CONTRACT_STATUS_Demand_VAR                                        28.0
# CC_MONTHS_BALANCE_VAR                                                     28.0
# CC_AMT_CREDIT_LIMIT_ACTUAL_VAR                                            28.0
# CC_AMT_CREDIT_LIMIT_ACTUAL_SUM                                            28.0
# CC_NAME_CONTRACT_STATUS_Refused_MIN                                       28.0
# CC_AMT_CREDIT_LIMIT_ACTUAL_MAX                                            28.0
# CC_AMT_CREDIT_LIMIT_ACTUAL_MIN                                            28.0
# CC_AMT_BALANCE_VAR                                                        28.0
# CC_AMT_BALANCE_SUM                                                        28.0
# CC_AMT_BALANCE_MEAN                                                       28.0
# CC_AMT_BALANCE_MAX                                                        28.0
# CC_AMT_BALANCE_MIN                                                        28.0
# CC_MONTHS_BALANCE_SUM                                                     28.0
# CC_NAME_CONTRACT_STATUS_Signed_MEAN                                       28.0
# CC_MONTHS_BALANCE_MEAN                                                    28.0
# CC_MONTHS_BALANCE_MAX                                                     28.0
# CC_MONTHS_BALANCE_MIN                                                     28.0
# CC_NAME_CONTRACT_STATUS_Signed_VAR                                        28.0
# CC_NAME_CONTRACT_STATUS_nan_MIN                                           28.0
# CC_NAME_CONTRACT_STATUS_nan_MAX                                           28.0
# CC_NAME_CONTRACT_STATUS_nan_MEAN                                          28.0
# CC_NAME_CONTRACT_STATUS_nan_SUM                                           28.0
# CC_NAME_CONTRACT_STATUS_nan_VAR                                           28.0
# CC_COUNT                                                                  28.0
# CC_NAME_CONTRACT_STATUS_Signed_SUM                                        28.0
# CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN                                           28.0
# CC_NAME_CONTRACT_STATUS_Signed_MAX                                        28.0
# CC_NAME_CONTRACT_STATUS_Sent proposal_MIN                                 28.0
# CC_NAME_CONTRACT_STATUS_Refused_MAX                                       28.0
# CC_AMT_INST_MIN_REGULARITY_VAR                                            28.0
# CC_AMT_INST_MIN_REGULARITY_SUM                                            28.0
# CC_AMT_INST_MIN_REGULARITY_MEAN                                           28.0
# CC_AMT_INST_MIN_REGULARITY_MAX                                            28.0
# CC_AMT_INST_MIN_REGULARITY_MIN                                            28.0
# CC_NAME_CONTRACT_STATUS_Refused_MEAN                                      28.0
# CC_AMT_DRAWINGS_ATM_CURRENT_SUM                                           28.0
# CC_AMT_DRAWINGS_POS_CURRENT_SUM                                           28.0
# CC_NAME_CONTRACT_STATUS_Refused_SUM                                       28.0
# CC_NAME_CONTRACT_STATUS_Refused_VAR                                       28.0
# CC_NAME_CONTRACT_STATUS_Active_VAR                                        28.0
# CC_NAME_CONTRACT_STATUS_Sent proposal_MAX                                 28.0
# CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN                                28.0
# CC_NAME_CONTRACT_STATUS_Sent proposal_SUM                                 28.0
# CC_NAME_CONTRACT_STATUS_Signed_MIN                                        28.0
# CC_AMT_DRAWINGS_CURRENT_MIN                                               28.0
# CC_AMT_DRAWINGS_CURRENT_MAX                                               28.0
# CC_NAME_CONTRACT_STATUS_Approved_MIN                                      28.0
# CC_AMT_DRAWINGS_CURRENT_SUM                                               28.0
# CC_AMT_DRAWINGS_OTHER_CURRENT_SUM                                         28.0
# CC_NAME_CONTRACT_STATUS_Sent proposal_VAR                                 28.0
# CC_AMT_DRAWINGS_CURRENT_VAR                                               28.0
# BURO_AMT_ANNUITY_MEAN                                                     25.0
# BURO_AMT_ANNUITY_MAX                                                      25.0
# CLOSED_MONTHS_BALANCE_SIZE_MEAN                                           25.0
# CLOSED_MONTHS_BALANCE_MIN_MIN                                             25.0
# CLOSED_MONTHS_BALANCE_MAX_MAX                                             25.0
# ACTIVE_MONTHS_BALANCE_MAX_MAX                                             24.0
# ACTIVE_MONTHS_BALANCE_SIZE_MEAN                                           24.0
# ACTIVE_MONTHS_BALANCE_MIN_MIN                                             24.0
# CLOSED_AMT_ANNUITY_MAX                                                    21.0
# CLOSED_AMT_ANNUITY_MEAN                                                   21.0
# CC_AMT_PAYMENT_CURRENT_MAX                                                20.0
# CC_AMT_DRAWINGS_POS_CURRENT_MAX                                           20.0
# CC_AMT_DRAWINGS_OTHER_CURRENT_MIN                                         20.0
# CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN                                        20.0
# CC_AMT_DRAWINGS_POS_CURRENT_MIN                                           20.0
# CC_CNT_DRAWINGS_POS_CURRENT_MEAN                                          20.0
# CC_AMT_DRAWINGS_POS_CURRENT_MEAN                                          20.0
# CC_AMT_DRAWINGS_ATM_CURRENT_MEAN                                          20.0
# CC_AMT_PAYMENT_CURRENT_MIN                                                20.0
# CC_AMT_DRAWINGS_ATM_CURRENT_MAX                                           20.0
# CC_AMT_PAYMENT_CURRENT_MEAN                                               20.0
# CC_AMT_DRAWINGS_ATM_CURRENT_MIN                                           20.0
# CC_CNT_DRAWINGS_ATM_CURRENT_MIN                                           20.0
# CC_CNT_DRAWINGS_ATM_CURRENT_MAX                                           20.0
# CC_CNT_DRAWINGS_ATM_CURRENT_MEAN                                          20.0
# CC_CNT_DRAWINGS_OTHER_CURRENT_MIN                                         20.0
# CC_CNT_DRAWINGS_OTHER_CURRENT_MAX                                         20.0
# CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN                                        20.0
# CC_CNT_DRAWINGS_POS_CURRENT_MIN                                           20.0
# CC_CNT_DRAWINGS_POS_CURRENT_MAX                                           20.0
# CC_AMT_DRAWINGS_OTHER_CURRENT_MAX                                         20.0
# ACTIVE_AMT_ANNUITY_MEAN                                                   19.0
# ACTIVE_AMT_ANNUITY_MAX                                                    19.0
# CC_AMT_DRAWINGS_ATM_CURRENT_VAR                                           19.0
# CC_CNT_DRAWINGS_POS_CURRENT_VAR                                           19.0
# CC_AMT_DRAWINGS_OTHER_CURRENT_VAR                                         19.0
# CC_AMT_DRAWINGS_POS_CURRENT_VAR                                           19.0
# CC_AMT_PAYMENT_CURRENT_VAR                                                19.0
# CC_CNT_DRAWINGS_ATM_CURRENT_VAR                                           19.0
# CC_CNT_DRAWINGS_OTHER_CURRENT_VAR                                         19.0
# REFUSED_APP_CREDIT_PERC_VAR                                               16.0
# REFUSED_AMT_DOWN_PAYMENT_MEAN                                             15.0
# REFUSED_RATE_DOWN_PAYMENT_MEAN                                            15.0
# REFUSED_RATE_DOWN_PAYMENT_MAX                                             15.0
# REFUSED_RATE_DOWN_PAYMENT_MIN                                             15.0
# REFUSED_AMT_DOWN_PAYMENT_MIN                                              15.0
# REFUSED_AMT_DOWN_PAYMENT_MAX                                              15.0
# dtype: float64

# %%
sample_df.describe()
# Out:
#                index     SK_ID_CURR       TARGET  CODE_GENDER  FLAG_OWN_CAR  \
# count    4315.000000    4315.000000  4315.000000  4315.000000   4315.000000
# mean   153739.630591  278159.461182     0.080649     0.657937      0.347856
# std     88750.713164  102765.147433     0.272327     0.474455      0.476345
# min        26.000000  100031.000000     0.000000     0.000000      0.000000
# 25%     77243.000000  189563.500000     0.000000     0.000000      0.000000
# 50%    152937.000000  277257.000000     0.000000     1.000000      0.000000
# 75%    231498.000000  368145.500000     0.000000     1.000000      1.000000
# max    307507.000000  456252.000000     1.000000     1.000000      1.000000
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL    AMT_CREDIT  \
# count      4315.000000   4315.000000      4.315000e+03  4.315000e+03
# mean          0.306837      0.427578      1.696162e+05  6.072550e+05
# std           0.461234      0.730823      1.073679e+05  4.159843e+05
# min           0.000000      0.000000      3.015000e+04  4.500000e+04
# 25%           0.000000      0.000000      1.125000e+05  2.700000e+05
# 50%           0.000000      0.000000      1.440000e+05  5.212800e+05
# 75%           1.000000      1.000000      2.025000e+05  8.136180e+05
# max           1.000000      9.000000      2.250000e+06  3.956274e+06
#
#          AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  \
# count    4315.000000     4.314000e+03                 4315.000000
# mean    27195.291657     5.453201e+05                    0.020566
# std     14905.288550     3.813192e+05                    0.013686
# min      2722.500000     4.500000e+04                    0.000533
# 25%     16265.250000     2.385000e+05                    0.010006
# 50%     24763.500000     4.500000e+05                    0.018850
# 75%     34461.000000     6.795000e+05                    0.026392
# max    197230.500000     3.825000e+06                    0.072508
#
#          DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  \
# count   4315.000000    3504.000000        4315.000000      4315.000000
# mean  -15995.439166   -2426.095605       -4923.816686     -3037.223175
# std     4378.941922    2433.747454        3481.224952      1492.654738
# min   -25130.000000  -16304.000000      -20981.000000     -6093.000000
# 25%   -19736.000000   -3205.500000       -7397.000000     -4305.000000
# 50%   -15606.000000   -1623.500000       -4481.000000     -3337.000000
# 75%   -12301.000000    -774.750000       -1978.000000     -1800.500000
# max    -7695.000000     -20.000000           0.000000        -3.000000
#
#        OWN_CAR_AGE  FLAG_MOBIL  FLAG_EMP_PHONE  FLAG_WORK_PHONE  \
# count  1501.000000      4315.0     4315.000000      4315.000000
# mean     11.946036         1.0        0.812051         0.195365
# std      11.720314         0.0        0.390717         0.396527
# min       0.000000         1.0        0.000000         0.000000
# 25%       4.000000         1.0        1.000000         0.000000
# 50%       9.000000         1.0        1.000000         0.000000
# 75%      16.000000         1.0        1.000000         0.000000
# max      65.000000         1.0        1.000000         1.000000
#
#        FLAG_CONT_MOBILE   FLAG_PHONE   FLAG_EMAIL  CNT_FAM_MEMBERS  \
# count       4315.000000  4315.000000  4315.000000      4315.000000
# mean           0.996987     0.267439     0.054229         2.164542
# std            0.054812     0.442675     0.226496         0.918715
# min            0.000000     0.000000     0.000000         1.000000
# 25%            1.000000     0.000000     0.000000         2.000000
# 50%            1.000000     0.000000     0.000000         2.000000
# 75%            1.000000     1.000000     0.000000         3.000000
# max            1.000000     1.000000     1.000000        11.000000
#
#        REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# count           4315.000000                  4315.000000
# mean               2.067671                     2.048667
# std                0.505931                     0.498440
# min                1.000000                     1.000000
# 25%                2.000000                     2.000000
# 50%                2.000000                     2.000000
# 75%                2.000000                     2.000000
# max                3.000000                     3.000000
#
#        HOUR_APPR_PROCESS_START  REG_REGION_NOT_LIVE_REGION  \
# count              4315.000000                 4315.000000
# mean                 11.945539                    0.015759
# std                   3.248415                    0.124556
# min                   0.000000                    0.000000
# 25%                  10.000000                    0.000000
# 50%                  12.000000                    0.000000
# 75%                  14.000000                    0.000000
# max                  22.000000                    1.000000
#
#        REG_REGION_NOT_WORK_REGION  LIVE_REGION_NOT_WORK_REGION  \
# count                 4315.000000                  4315.000000
# mean                     0.048667                     0.037312
# std                      0.215197                     0.189546
# min                      0.000000                     0.000000
# 25%                      0.000000                     0.000000
# 50%                      0.000000                     0.000000
# 75%                      0.000000                     0.000000
# max                      1.000000                     1.000000
#
#        REG_CITY_NOT_LIVE_CITY  REG_CITY_NOT_WORK_CITY  \
# count             4315.000000             4315.000000
# mean                 0.078563                0.223407
# std                  0.269087                0.416577
# min                  0.000000                0.000000
# 25%                  0.000000                0.000000
# 50%                  0.000000                0.000000
# 75%                  0.000000                0.000000
# max                  1.000000                1.000000
#
#        LIVE_CITY_NOT_WORK_CITY  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# count              4315.000000   1869.000000   4305.000000   3459.000000
# mean                  0.171958      0.501545      0.509991      0.509795
# std                   0.377388      0.215413      0.191565      0.197376
# min                   0.000000      0.032145      0.000030      0.000527
# 25%                   0.000000      0.327661      0.383992      0.365617
# 50%                   0.000000      0.503300      0.560173      0.535276
# 75%                   0.000000      0.682442      0.659544      0.670652
# max                   1.000000      0.924984      0.855000      0.879506
#
#        APARTMENTS_AVG  BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  \
# count     2106.000000       1783.000000                  2187.000000
# mean         0.113399          0.086523                     0.977126
# std          0.103739          0.078447                     0.064891
# min          0.000000          0.000000                     0.000000
# 25%          0.055700          0.043400                     0.977100
# 50%          0.086600          0.075000                     0.981600
# 75%          0.146400          0.111100                     0.986600
# max          1.000000          1.000000                     1.000000
#
#        YEARS_BUILD_AVG  COMMONAREA_AVG  ELEVATORS_AVG  ENTRANCES_AVG  \
# count       1417.00000     1261.000000    1991.000000    2112.000000
# mean           0.74874        0.044324       0.076804       0.149366
# std            0.11210        0.076480       0.129274       0.097754
# min            0.00000        0.000000       0.000000       0.000000
# 25%            0.68720        0.008000       0.000000       0.069000
# 50%            0.75520        0.020300       0.000000       0.137900
# 75%            0.81640        0.051600       0.120000       0.206900
# max            1.00000        1.000000       0.880000       1.000000
#
#        FLOORSMAX_AVG  FLOORSMIN_AVG  LANDAREA_AVG  LIVINGAPARTMENTS_AVG  \
# count    2144.000000    1351.000000   1748.000000           1342.000000
# mean        0.223585       0.236450      0.064563              0.100222
# std         0.144962       0.163141      0.070666              0.088777
# min         0.000000       0.000000      0.000000              0.000000
# 25%         0.166700       0.125000      0.019275              0.050400
# 50%         0.166700       0.208300      0.046900              0.075600
# 75%         0.333300       0.375000      0.085050              0.121000
# max         1.000000       1.000000      0.726600              0.915300
#
#        LIVINGAREA_AVG  NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  \
# count     2134.000000              1292.000000        1914.000000
# mean         0.103776                 0.006361           0.028751
# std          0.103623                 0.021723           0.076262
# min          0.000000                 0.000000           0.000000
# 25%          0.044100                 0.000000           0.000000
# 50%          0.075150                 0.000000           0.003300
# 75%          0.124775                 0.004200           0.025975
# max          1.000000                 0.478800           1.000000
#
#        APARTMENTS_MODE  BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  \
# count      2106.000000        1783.000000                   2187.000000
# mean          0.110216           0.085700                      0.976748
# std           0.104345           0.078937                      0.066744
# min           0.000000           0.000000                      0.000000
# 25%           0.050400           0.040050                      0.976700
# 50%           0.084000           0.074100                      0.981600
# 75%           0.136325           0.111700                      0.986600
# max           1.000000           1.000000                      1.000000
#
#        YEARS_BUILD_MODE  COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  \
# count       1417.000000      1261.000000     1991.000000     2112.000000
# mean           0.755691         0.042231        0.072126        0.144882
# std            0.109533         0.074255        0.127522        0.099344
# min            0.000000         0.000000        0.000000        0.000000
# 25%            0.699400         0.007600        0.000000        0.069000
# 50%            0.758300         0.017700        0.000000        0.137900
# 75%            0.823600         0.049800        0.120800        0.206900
# max            1.000000         1.000000        0.886200        1.000000
#
#        FLOORSMAX_MODE  FLOORSMIN_MODE  LANDAREA_MODE  LIVINGAPARTMENTS_MODE  \
# count     2144.000000     1351.000000    1748.000000            1342.000000
# mean         0.219750        0.232755       0.063190               0.105172
# std          0.145075        0.164081       0.071966               0.095695
# min          0.000000        0.000000       0.000000               0.000000
# 25%          0.166700        0.083300       0.016975               0.055100
# 50%          0.166700        0.208300       0.044900               0.077100
# 75%          0.333300        0.375000       0.082950               0.131300
# max          1.000000        1.000000       0.743200               1.000000
#
#        LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  NONLIVINGAREA_MODE  \
# count      2134.000000               1292.000000         1914.000000
# mean          0.102329                  0.005943            0.026548
# std           0.105138                  0.021746            0.071383
# min           0.000000                  0.000000            0.000000
# 25%           0.041725                  0.000000            0.000000
# 50%           0.073100                  0.000000            0.000900
# 75%           0.121600                  0.003900            0.022400
# max           1.000000                  0.482500            1.000000
#
#        APARTMENTS_MEDI  BASEMENTAREA_MEDI  YEARS_BEGINEXPLUATATION_MEDI  \
# count      2106.000000        1783.000000                   2187.000000
# mean          0.113915           0.086058                      0.976988
# std           0.105377           0.078413                      0.066764
# min           0.000000           0.000000                      0.000000
# 25%           0.055200           0.042750                      0.976700
# 50%           0.084300           0.074900                      0.981600
# 75%           0.145700           0.110400                      0.986600
# max           1.000000           1.000000                      1.000000
#
#        YEARS_BUILD_MEDI  COMMONAREA_MEDI  ELEVATORS_MEDI  ENTRANCES_MEDI  \
# count       1417.000000      1261.000000     1991.000000     2112.000000
# mean           0.752133         0.044441        0.075831        0.148898
# std            0.110583         0.077175        0.129711        0.098140
# min            0.000000         0.000000        0.000000        0.000000
# 25%            0.691400         0.008000        0.000000        0.069000
# 50%            0.758500         0.020000        0.000000        0.137900
# 75%            0.818900         0.051600        0.120000        0.206900
# max            1.000000         1.000000        0.880000        1.000000
#
#        FLOORSMAX_MEDI  FLOORSMIN_MEDI  LANDAREA_MEDI  LIVINGAPARTMENTS_MEDI  \
# count     2144.000000     1351.000000    1748.000000            1342.000000
# mean         0.222811        0.236225       0.065543               0.101462
# std          0.145422        0.163872       0.072282               0.090300
# min          0.000000        0.000000       0.000000               0.000000
# 25%          0.166700        0.125000       0.019500               0.051300
# 50%          0.166700        0.208300       0.047700               0.076100
# 75%          0.333300        0.375000       0.086025               0.123100
# max          1.000000        1.000000       0.739200               0.931200
#
#        LIVINGAREA_MEDI  NONLIVINGAPARTMENTS_MEDI  NONLIVINGAREA_MEDI  \
# count      2134.000000               1292.000000         1914.000000
# mean          0.105168                  0.006236            0.028390
# std           0.105971                  0.021777            0.076681
# min           0.000000                  0.000000            0.000000
# 25%           0.044550                  0.000000            0.000000
# 50%           0.075500                  0.000000            0.002700
# 75%           0.125375                  0.003900            0.024700
# max           1.000000                  0.481400            1.000000
#
#        TOTALAREA_MODE  OBS_30_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE  \
# count     2211.000000               4302.000000               4302.000000
# mean         0.100587                  1.447699                  0.140632
# std          0.102898                  2.401839                  0.424740
# min          0.000000                  0.000000                  0.000000
# 25%          0.040150                  0.000000                  0.000000
# 50%          0.068700                  0.000000                  0.000000
# 75%          0.123900                  2.000000                  0.000000
# max          0.962900                 22.000000                  4.000000
#
#        OBS_60_CNT_SOCIAL_CIRCLE  DEF_60_CNT_SOCIAL_CIRCLE  \
# count               4302.000000               4302.000000
# mean                   1.432589                  0.102046
# std                    2.386018                  0.360256
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    2.000000                  0.000000
# max                   22.000000                  4.000000
#
#        DAYS_LAST_PHONE_CHANGE  FLAG_DOCUMENT_2  FLAG_DOCUMENT_3  \
# count             4315.000000           4315.0      4315.000000
# mean              -970.286443              0.0         0.719583
# std                827.828337              0.0         0.449255
# min              -4292.000000              0.0         0.000000
# 25%              -1583.000000              0.0         0.000000
# 50%               -767.000000              0.0         1.000000
# 75%               -275.000000              0.0         1.000000
# max                  0.000000              0.0         1.000000
#
#        FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  FLAG_DOCUMENT_6  FLAG_DOCUMENT_7  \
# count           4315.0      4315.000000      4315.000000      4315.000000
# mean               0.0         0.012051         0.085284         0.000232
# std                0.0         0.109126         0.279336         0.015223
# min                0.0         0.000000         0.000000         0.000000
# 25%                0.0         0.000000         0.000000         0.000000
# 50%                0.0         0.000000         0.000000         0.000000
# 75%                0.0         0.000000         0.000000         0.000000
# max                0.0         1.000000         1.000000         1.000000
#
#        FLAG_DOCUMENT_8  FLAG_DOCUMENT_9  FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  \
# count      4315.000000      4315.000000            4315.0       4315.000000
# mean          0.077636         0.004867               0.0          0.003940
# std           0.267629         0.069600               0.0          0.062651
# min           0.000000         0.000000               0.0          0.000000
# 25%           0.000000         0.000000               0.0          0.000000
# 50%           0.000000         0.000000               0.0          0.000000
# 75%           0.000000         0.000000               0.0          0.000000
# max           1.000000         1.000000               0.0          1.000000
#
#        FLAG_DOCUMENT_12  FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  FLAG_DOCUMENT_15  \
# count            4315.0       4315.000000       4315.000000       4315.000000
# mean                0.0          0.003940          0.004403          0.000927
# std                 0.0          0.062651          0.066218          0.030436
# min                 0.0          0.000000          0.000000          0.000000
# 25%                 0.0          0.000000          0.000000          0.000000
# 50%                 0.0          0.000000          0.000000          0.000000
# 75%                 0.0          0.000000          0.000000          0.000000
# max                 0.0          1.000000          1.000000          1.000000
#
#        FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  \
# count       4315.000000       4315.000000       4315.000000       4315.000000
# mean           0.009038          0.000232          0.007879          0.000463
# std            0.094650          0.015223          0.088426          0.021527
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000          0.000000
# 75%            0.000000          0.000000          0.000000          0.000000
# max            1.000000          1.000000          1.000000          1.000000
#
#        FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  AMT_REQ_CREDIT_BUREAU_HOUR  \
# count       4315.000000            4315.0                 3721.000000
# mean           0.001159               0.0                    0.007525
# std            0.034025               0.0                    0.089487
# min            0.000000               0.0                    0.000000
# 25%            0.000000               0.0                    0.000000
# 50%            0.000000               0.0                    0.000000
# 75%            0.000000               0.0                    0.000000
# max            1.000000               0.0                    2.000000
#
#        AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# count                3721.000000                 3721.000000
# mean                    0.004837                    0.032518
# std                     0.080176                    0.181885
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     0.000000                    0.000000
# 75%                     0.000000                    0.000000
# max                     3.000000                    2.000000
#
#        AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# count                3721.000000                3721.000000
# mean                    0.251545                   0.260951
# std                     0.805651                   0.594241
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   0.000000
# max                    13.000000                   4.000000
#
#        AMT_REQ_CREDIT_BUREAU_YEAR  DAYS_EMPLOYED_PERC  INCOME_CREDIT_PERC  \
# count                 3721.000000         3504.000000         4315.000000
# mean                     1.872077            0.160756            0.395274
# std                      1.860679            0.138824            0.331566
# min                      0.000000            0.001204            0.031784
# 25%                      0.000000            0.055361            0.189906
# 50%                      1.000000            0.119690            0.303767
# 75%                      3.000000            0.224773            0.490909
# max                      9.000000            0.691345            4.500000
#
#        INCOME_PER_PERSON  ANNUITY_INCOME_PERC  PAYMENT_RATE  \
# count       4.315000e+03          4315.000000   4315.000000
# mean        9.312645e+04             0.180501      0.053230
# std         7.742634e+04             0.092667      0.022336
# min         9.000000e+03             0.011111      0.023829
# 25%         4.725000e+04             0.115384      0.036161
# 50%         7.500000e+04             0.164769      0.050000
# 75%         1.125000e+05             0.228061      0.061425
# max         2.250000e+06             0.919851      0.124428
#
#        BURO_DAYS_CREDIT_MIN  BURO_DAYS_CREDIT_MAX  BURO_DAYS_CREDIT_MEAN  \
# count           3689.000000           3689.000000            3689.000000
# mean           -1777.719978           -482.564652           -1085.406753
# std              859.931022            522.992875             556.315233
# min            -2922.000000          -2921.000000           -2921.000000
# 25%            -2583.000000           -608.000000           -1435.500000
# 50%            -1890.000000           -308.000000           -1054.500000
# 75%            -1057.000000           -143.000000            -683.333333
# max               -7.000000             -4.000000              -7.000000
#
#        BURO_DAYS_CREDIT_VAR  BURO_DAYS_CREDIT_ENDDATE_MIN  \
# count          3.229000e+03                   3663.000000
# mean           4.895054e+05                  -1096.160797
# std            4.575691e+05                   2198.777708
# min            0.000000e+00                 -41822.000000
# 25%            1.280180e+05                  -2138.000000
# 50%            3.864172e+05                  -1289.000000
# 75%            7.237697e+05                   -487.500000
# max            4.173160e+06                  31194.000000
#
#        BURO_DAYS_CREDIT_ENDDATE_MAX  BURO_DAYS_CREDIT_ENDDATE_MEAN  \
# count                   3663.000000                    3663.000000
# mean                    4252.466284                     548.048977
# std                     9102.897307                    2946.586831
# min                    -2759.000000                   -7419.166667
# 25%                      146.000000                    -718.500000
# 50%                      915.000000                    -150.571429
# 75%                     1658.000000                     575.483333
# max                    31195.000000                   31194.000000
#
#        BURO_DAYS_CREDIT_UPDATE_MEAN  BURO_CREDIT_DAY_OVERDUE_MAX  \
# count                   3689.000000                  3689.000000
# mean                    -554.382664                     4.515316
# std                      455.490476                    87.070557
# min                   -10758.500000                     0.000000
# 25%                     -781.000000                     0.000000
# 50%                     -487.857143                     0.000000
# 75%                     -225.000000                     0.000000
# max                        0.000000                  2667.000000
#
#        BURO_CREDIT_DAY_OVERDUE_MEAN  BURO_AMT_CREDIT_MAX_OVERDUE_MEAN  \
# count                   3689.000000                      2.593000e+03
# mean                       1.272305                      4.620398e+03
# std                       36.751454                      5.526011e+04
# min                        0.000000                      0.000000e+00
# 25%                        0.000000                      0.000000e+00
# 50%                        0.000000                      0.000000e+00
# 75%                        0.000000                      2.368721e+03
# max                     2048.000000                      2.327828e+06
#
#        BURO_AMT_CREDIT_SUM_MAX  BURO_AMT_CREDIT_SUM_MEAN  \
# count             3.689000e+03              3.689000e+03
# mean              1.088433e+06              4.338548e+05
# std               6.740420e+06              3.328991e+06
# min               0.000000e+00              0.000000e+00
# 25%               1.800000e+05              1.034190e+05
# 50%               4.500000e+05              1.965000e+05
# 75%               1.048500e+06              3.937500e+05
# max               3.960000e+08              1.980723e+08
#
#        BURO_AMT_CREDIT_SUM_SUM  BURO_AMT_CREDIT_SUM_DEBT_MAX  \
# count             3.689000e+03                  3.589000e+03
# mean              2.098155e+06                  5.124807e+05
# std               7.392624e+06                  1.219189e+06
# min               0.000000e+00                 -2.137500e+01
# 25%               3.613725e+05                  0.000000e+00
# 50%               1.003500e+06                  1.473830e+05
# 75%               2.285927e+06                  4.956120e+05
# max               3.961447e+08                  2.430000e+07
#
#        BURO_AMT_CREDIT_SUM_DEBT_MEAN  BURO_AMT_CREDIT_SUM_DEBT_SUM  \
# count                   3.589000e+03                  3.689000e+03
# mean                    1.539183e+05                  6.310647e+05
# std                     4.694830e+05                  1.399250e+06
# min                    -2.530642e+04                 -1.763728e+05
# 25%                     0.000000e+00                  0.000000e+00
# 50%                     4.418399e+04                  1.707170e+05
# 75%                     1.426905e+05                  6.732810e+05
# max                     1.382538e+07                  2.434790e+07
#
#        BURO_AMT_CREDIT_SUM_OVERDUE_MEAN  BURO_AMT_CREDIT_SUM_LIMIT_MEAN  \
# count                       3689.000000                    3.388000e+03
# mean                          19.690162                    6.118769e+03
# std                          819.859987                    2.938208e+04
# min                            0.000000                   -6.372792e+03
# 25%                            0.000000                    0.000000e+00
# 50%                            0.000000                    0.000000e+00
# 75%                            0.000000                    0.000000e+00
# max                        48087.495000                    1.003500e+06
#
#        BURO_AMT_CREDIT_SUM_LIMIT_SUM  BURO_AMT_ANNUITY_MAX  \
# count                   3.689000e+03          1.089000e+03
# mean                    2.484018e+04          2.588526e+04
# std                     1.009109e+05          9.649482e+04
# min                    -3.186396e+04          0.000000e+00
# 25%                     0.000000e+00          0.000000e+00
# 50%                     0.000000e+00          1.218114e+04
# 75%                     0.000000e+00          2.771550e+04
# max                     2.007000e+06          2.852001e+06
#
#        BURO_AMT_ANNUITY_MEAN  BURO_CNT_CREDIT_PROLONG_SUM  \
# count            1089.000000                  3689.000000
# mean            12276.463557                     0.039577
# std             25277.761996                     0.244363
# min                 0.000000                     0.000000
# 25%                 0.000000                     0.000000
# 50%              6275.565000                     0.000000
# 75%             15243.923077                     0.000000
# max            589298.400000                     5.000000
#
#        BURO_MONTHS_BALANCE_MIN_MIN  BURO_MONTHS_BALANCE_MAX_MAX  \
# count                  1262.000000                  1262.000000
# mean                    -56.919176                    -1.048336
# std                      28.061388                     6.555688
# min                     -96.000000                   -75.000000
# 25%                     -84.000000                     0.000000
# 50%                     -59.000000                     0.000000
# 75%                     -34.000000                     0.000000
# max                       0.000000                     0.000000
#
#        BURO_MONTHS_BALANCE_SIZE_MEAN  BURO_MONTHS_BALANCE_SIZE_SUM  \
# count                    1262.000000                   3689.000000
# mean                       27.257699                     54.892654
# std                        16.643766                    119.317027
# min                         1.000000                      0.000000
# 25%                        15.000000                      0.000000
# 50%                        24.133333                      0.000000
# 75%                        36.575000                     51.000000
# max                        96.000000                   1300.000000
#
#        BURO_CREDIT_ACTIVE_Active_MEAN  BURO_CREDIT_ACTIVE_Bad debt_MEAN  \
# count                     3689.000000                       3689.000000
# mean                         0.415681                          0.000090
# std                          0.306945                          0.005488
# min                          0.000000                          0.000000
# 25%                          0.200000                          0.000000
# 50%                          0.375000                          0.000000
# 75%                          0.600000                          0.000000
# max                          1.000000                          0.333333
#
#        BURO_CREDIT_ACTIVE_Closed_MEAN  BURO_CREDIT_ACTIVE_Sold_MEAN  \
# count                     3689.000000                   3689.000000
# mean                         0.579103                      0.005126
# std                          0.307185                      0.050935
# min                          0.000000                      0.000000
# 25%                          0.400000                      0.000000
# 50%                          0.600000                      0.000000
# 75%                          0.800000                      0.000000
# max                          1.000000                      1.000000
#
#        BURO_CREDIT_ACTIVE_nan_MEAN  BURO_CREDIT_CURRENCY_currency 1_MEAN  \
# count                       3689.0                           3689.000000
# mean                           0.0                              0.999754
# std                            0.0                              0.005774
# min                            0.0                              0.800000
# 25%                            0.0                              1.000000
# 50%                            0.0                              1.000000
# 75%                            0.0                              1.000000
# max                            0.0                              1.000000
#
#        BURO_CREDIT_CURRENCY_currency 2_MEAN  \
# count                           3689.000000
# mean                               0.000231
# std                                0.005709
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                0.200000
#
#        BURO_CREDIT_CURRENCY_currency 3_MEAN  \
# count                           3689.000000
# mean                               0.000014
# std                                0.000867
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                0.052632
#
#        BURO_CREDIT_CURRENCY_currency 4_MEAN  BURO_CREDIT_CURRENCY_nan_MEAN  \
# count                                3689.0                         3689.0
# mean                                    0.0                            0.0
# std                                     0.0                            0.0
# min                                     0.0                            0.0
# 25%                                     0.0                            0.0
# 50%                                     0.0                            0.0
# 75%                                     0.0                            0.0
# max                                     0.0                            0.0
#
#        BURO_CREDIT_TYPE_Another type of loan_MEAN  \
# count                                 3689.000000
# mean                                     0.000609
# std                                      0.010898
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      0.333333
#
#        BURO_CREDIT_TYPE_Car loan_MEAN  \
# count                     3689.000000
# mean                         0.020289
# std                          0.095555
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                          1.000000
#
#        BURO_CREDIT_TYPE_Cash loan (non-earmarked)_MEAN  \
# count                                           3689.0
# mean                                               0.0
# std                                                0.0
# min                                                0.0
# 25%                                                0.0
# 50%                                                0.0
# 75%                                                0.0
# max                                                0.0
#
#        BURO_CREDIT_TYPE_Consumer credit_MEAN  \
# count                            3689.000000
# mean                                0.723165
# std                                 0.273479
# min                                 0.000000
# 25%                                 0.583333
# 50%                                 0.750000
# 75%                                 1.000000
# max                                 1.000000
#
#        BURO_CREDIT_TYPE_Credit card_MEAN  \
# count                        3689.000000
# mean                            0.235370
# std                             0.252101
# min                             0.000000
# 25%                             0.000000
# 50%                             0.200000
# 75%                             0.333333
# max                             1.000000
#
#        BURO_CREDIT_TYPE_Interbank credit_MEAN  \
# count                                  3689.0
# mean                                      0.0
# std                                       0.0
# min                                       0.0
# 25%                                       0.0
# 50%                                       0.0
# 75%                                       0.0
# max                                       0.0
#
#        BURO_CREDIT_TYPE_Loan for business development_MEAN  \
# count                                        3689.000000
# mean                                            0.001211
# std                                             0.021888
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BURO_CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN  \
# count                                        3689.000000
# mean                                            0.000018
# std                                             0.001098
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             0.066667
#
#        BURO_CREDIT_TYPE_Loan for the purchase of equipment_MEAN  \
# count                                             3689.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        BURO_CREDIT_TYPE_Loan for working capital replenishment_MEAN  \
# count                                        3689.000000
# mean                                            0.000304
# std                                             0.010282
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             0.500000
#
#        BURO_CREDIT_TYPE_Microloan_MEAN  \
# count                      3689.000000
# mean                          0.003412
# std                           0.038305
# min                           0.000000
# 25%                           0.000000
# 50%                           0.000000
# 75%                           0.000000
# max                           1.000000
#
#        BURO_CREDIT_TYPE_Mobile operator loan_MEAN  \
# count                                      3689.0
# mean                                          0.0
# std                                           0.0
# min                                           0.0
# 25%                                           0.0
# 50%                                           0.0
# 75%                                           0.0
# max                                           0.0
#
#        BURO_CREDIT_TYPE_Mortgage_MEAN  BURO_CREDIT_TYPE_Real estate loan_MEAN  \
# count                     3689.000000                             3689.000000
# mean                         0.015509                                0.000027
# std                          0.084968                                0.001646
# min                          0.000000                                0.000000
# 25%                          0.000000                                0.000000
# 50%                          0.000000                                0.000000
# 75%                          0.000000                                0.000000
# max                          1.000000                                0.100000
#
#        BURO_CREDIT_TYPE_Unknown type of loan_MEAN  BURO_CREDIT_TYPE_nan_MEAN  \
# count                                 3689.000000                     3689.0
# mean                                     0.000086                        0.0
# std                                      0.003272                        0.0
# min                                      0.000000                        0.0
# 25%                                      0.000000                        0.0
# 50%                                      0.000000                        0.0
# 75%                                      0.000000                        0.0
# max                                      0.166667                        0.0
#
#        BURO_STATUS_0_MEAN_MEAN  BURO_STATUS_1_MEAN_MEAN  \
# count              1262.000000              1262.000000
# mean                  0.454196                 0.014103
# std                   0.256751                 0.037028
# min                   0.000000                 0.000000
# 25%                   0.255176                 0.000000
# 50%                   0.430306                 0.000000
# 75%                   0.629167                 0.009468
# max                   1.000000                 0.341430
#
#        BURO_STATUS_2_MEAN_MEAN  BURO_STATUS_3_MEAN_MEAN  \
# count              1262.000000              1262.000000
# mean                  0.000904                 0.000513
# std                   0.005197                 0.003793
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   0.076923                 0.076923
#
#        BURO_STATUS_4_MEAN_MEAN  BURO_STATUS_5_MEAN_MEAN  \
# count              1262.000000              1262.000000
# mean                  0.000385                 0.002412
# std                   0.003138                 0.022461
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   0.052083                 0.366667
#
#        BURO_STATUS_C_MEAN_MEAN  BURO_STATUS_X_MEAN_MEAN  \
# count              1262.000000              1262.000000
# mean                  0.336654                 0.190833
# std                   0.263398                 0.229792
# min                   0.000000                 0.000000
# 25%                   0.109812                 0.012495
# 50%                   0.328147                 0.102089
# 75%                   0.529513                 0.281976
# max                   1.000000                 1.000000
#
#        BURO_STATUS_nan_MEAN_MEAN  ACTIVE_DAYS_CREDIT_MIN  \
# count                     1262.0             3053.000000
# mean                         0.0             -950.638716
# std                          0.0              721.517104
# min                          0.0            -2922.000000
# 25%                          0.0            -1333.000000
# 50%                          0.0             -797.000000
# 75%                          0.0             -370.000000
# max                          0.0               -5.000000
#
#        ACTIVE_DAYS_CREDIT_MAX  ACTIVE_DAYS_CREDIT_MEAN  \
# count             3053.000000              3053.000000
# mean              -415.532918              -656.022474
# std                459.949660               489.370593
# min              -2914.000000             -2914.000000
# 25%               -508.000000              -891.500000
# 50%               -266.000000              -549.500000
# 75%               -124.000000              -301.500000
# max                 -4.000000                -5.000000
#
#        ACTIVE_DAYS_CREDIT_VAR  ACTIVE_DAYS_CREDIT_ENDDATE_MIN  \
# count            2.072000e+03                     2931.000000
# mean             3.047574e+05                      956.749574
# std              5.132480e+05                     4483.114570
# min              0.000000e+00                    -2738.000000
# 25%              2.222438e+04                      -20.000000
# 50%              1.118645e+05                      252.000000
# 75%              3.392548e+05                      743.500000
# max              3.998792e+06                    31194.000000
#
#        ACTIVE_DAYS_CREDIT_ENDDATE_MAX  ACTIVE_DAYS_CREDIT_ENDDATE_MEAN  \
# count                     2931.000000                      2931.000000
# mean                      4726.435005                      2411.876274
# std                       9301.127996                      5328.317786
# min                      -2730.000000                     -2730.000000
# 25%                        518.500000                       274.250000
# 50%                       1064.000000                       710.000000
# 75%                       1715.000000                      1445.000000
# max                      31194.000000                     31194.000000
#
#        ACTIVE_DAYS_CREDIT_UPDATE_MEAN  ACTIVE_CREDIT_DAY_OVERDUE_MAX  \
# count                     3053.000000                    3053.000000
# mean                      -134.908514                       4.784474
# std                        253.987818                      88.237794
# min                      -2757.000000                       0.000000
# 25%                       -129.166667                       0.000000
# 50%                        -30.500000                       0.000000
# 75%                        -16.750000                       0.000000
# max                          0.000000                    2667.000000
#
#        ACTIVE_CREDIT_DAY_OVERDUE_MEAN  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN  \
# count                     3053.000000                         1653.000000
# mean                         2.146083                         2816.652926
# std                         46.355199                        14839.618160
# min                          0.000000                            0.000000
# 25%                          0.000000                            0.000000
# 50%                          0.000000                            0.000000
# 75%                          0.000000                          481.419000
# max                       2048.000000                       491095.260000
#
#        ACTIVE_AMT_CREDIT_SUM_MAX  ACTIVE_AMT_CREDIT_SUM_MEAN  \
# count               3.053000e+03                3.053000e+03
# mean                9.452363e+05                5.523378e+05
# std                 1.615007e+06                9.791858e+05
# min                 0.000000e+00                0.000000e+00
# 25%                 1.800000e+05                1.350000e+05
# 50%                 4.500000e+05                2.766262e+05
# 75%                 9.900000e+05                5.692500e+05
# max                 2.430000e+07                1.568250e+07
#
#        ACTIVE_AMT_CREDIT_SUM_SUM  ACTIVE_AMT_CREDIT_SUM_DEBT_MAX  \
# ...
#
#        CC_CNT_DRAWINGS_OTHER_CURRENT_SUM  CC_CNT_DRAWINGS_OTHER_CURRENT_VAR  \
# count                        1222.000000                         840.000000
# mean                            0.120295                           0.007714
# std                             0.558837                           0.051950
# min                             0.000000                           0.000000
# 25%                             0.000000                           0.000000
# 50%                             0.000000                           0.000000
# 75%                             0.000000                           0.000000
# max                             6.000000                           1.041667
#
#        CC_CNT_DRAWINGS_POS_CURRENT_MIN  CC_CNT_DRAWINGS_POS_CURRENT_MAX  \
# count                       848.000000                       848.000000
# mean                          0.145047                         6.071934
# std                           0.929104                        11.214587
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.000000                         1.000000
# 75%                           0.000000                         7.000000
# max                          14.000000                        78.000000
#
#        CC_CNT_DRAWINGS_POS_CURRENT_MEAN  CC_CNT_DRAWINGS_POS_CURRENT_SUM  \
# count                        848.000000                      1222.000000
# mean                           1.655546                        14.886252
# std                            3.804970                        39.452697
# min                            0.000000                         0.000000
# 25%                            0.000000                         0.000000
# 50%                            0.028571                         0.000000
# 75%                            1.151974                         6.000000
# max                           32.142857                       344.000000
#
#        CC_CNT_DRAWINGS_POS_CURRENT_VAR  CC_CNT_INSTALMENT_MATURE_CUM_MIN  \
# count                       840.000000                       1222.000000
# mean                         17.325778                          0.882979
# std                          67.069345                          2.497872
# min                           0.000000                          0.000000
# 25%                           0.000000                          0.000000
# 50%                           0.028571                          0.000000
# 75%                           3.577372                          1.000000
# max                         847.500000                         20.000000
#
#        CC_CNT_INSTALMENT_MATURE_CUM_MAX  CC_CNT_INSTALMENT_MATURE_CUM_MEAN  \
# count                       1222.000000                        1222.000000
# mean                          16.245499                          10.167350
# std                           22.119665                          13.756094
# min                            0.000000                           0.000000
# 25%                            0.000000                           0.000000
# 50%                            7.000000                           3.600000
# 75%                           22.750000                          15.000000
# max                          106.000000                          59.333333
#
#        CC_CNT_INSTALMENT_MATURE_CUM_SUM  CC_CNT_INSTALMENT_MATURE_CUM_VAR  \
# count                       1222.000000                       1216.000000
# mean                         722.265957                         67.552321
# std                         1260.690565                        148.658353
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                           45.000000                          6.000000
# 75%                          758.750000                         39.166290
# max                         5696.000000                        776.000000
#
#        CC_SK_DPD_MIN  CC_SK_DPD_MAX  CC_SK_DPD_MEAN  CC_SK_DPD_SUM  \
# count         1222.0    1222.000000     1222.000000    1222.000000
# mean             0.0      17.114566        4.274831     353.191489
# std              0.0     143.830913       43.721520    3715.519347
# min              0.0       0.000000        0.000000       0.000000
# 25%              0.0       0.000000        0.000000       0.000000
# 50%              0.0       0.000000        0.000000       0.000000
# 75%              0.0       0.000000        0.000000       0.000000
# max              0.0    1917.000000      695.674419   59828.000000
#
#        CC_SK_DPD_VAR  CC_SK_DPD_DEF_MIN  CC_SK_DPD_DEF_MAX  \
# count    1216.000000             1222.0        1222.000000
# mean     2276.180916                0.0           0.615385
# std     24940.714472                0.0           4.085414
# min         0.000000                0.0           0.000000
# 25%         0.000000                0.0           0.000000
# 50%         0.000000                0.0           0.000000
# 75%         0.000000                0.0           0.000000
# max    412756.292750                0.0          79.000000
#
#        CC_SK_DPD_DEF_MEAN  CC_SK_DPD_DEF_SUM  CC_SK_DPD_DEF_VAR  \
# count         1222.000000        1222.000000        1216.000000
# mean             0.046406           2.137480           0.716286
# std              0.397906          16.441615           9.708011
# min              0.000000           0.000000           0.000000
# 25%              0.000000           0.000000           0.000000
# 50%              0.000000           0.000000           0.000000
# 75%              0.000000           0.000000           0.000000
# max              9.000000         439.000000         254.379106
#
#        CC_NAME_CONTRACT_STATUS_Active_MEAN  \
# count                          1222.000000
# mean                              0.964398
# std                               0.109069
# min                               0.142857
# 25%                               1.000000
# 50%                               1.000000
# 75%                               1.000000
# max                               1.000000
#
#        CC_NAME_CONTRACT_STATUS_Active_SUM  CC_NAME_CONTRACT_STATUS_Active_VAR  \
# count                         1222.000000                         1216.000000
# mean                            34.756137                            0.024283
# std                             32.436687                            0.064152
# min                              1.000000                            0.000000
# 25%                              9.000000                            0.000000
# 50%                             19.000000                            0.000000
# 75%                             67.000000                            0.000000
# max                            121.000000                            0.500000
#
#        CC_NAME_CONTRACT_STATUS_Approved_MEAN  \
# count                                 1222.0
# mean                                     0.0
# std                                      0.0
# min                                      0.0
# 25%                                      0.0
# 50%                                      0.0
# 75%                                      0.0
# max                                      0.0
#
#        CC_NAME_CONTRACT_STATUS_Approved_SUM  \
# count                                1222.0
# mean                                    0.0
# std                                     0.0
# min                                     0.0
# 25%                                     0.0
# 50%                                     0.0
# 75%                                     0.0
# max                                     0.0
#
#        CC_NAME_CONTRACT_STATUS_Approved_VAR  \
# count                                1216.0
# mean                                    0.0
# std                                     0.0
# min                                     0.0
# 25%                                     0.0
# 50%                                     0.0
# 75%                                     0.0
# max                                     0.0
#
#        CC_NAME_CONTRACT_STATUS_Completed_MEAN  \
# count                             1222.000000
# mean                                 0.031342
# std                                  0.105106
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  0.857143
#
#        CC_NAME_CONTRACT_STATUS_Completed_SUM  \
# count                            1222.000000
# mean                                1.229951
# std                                 4.675233
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                35.000000
#
#        CC_NAME_CONTRACT_STATUS_Completed_VAR  \
# count                            1216.000000
# mean                                0.020870
# std                                 0.061681
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 0.500000
#
#        CC_NAME_CONTRACT_STATUS_Demand_MEAN  \
# count                               1222.0
# mean                                   0.0
# std                                    0.0
# min                                    0.0
# 25%                                    0.0
# 50%                                    0.0
# 75%                                    0.0
# max                                    0.0
#
#        CC_NAME_CONTRACT_STATUS_Demand_SUM  CC_NAME_CONTRACT_STATUS_Demand_VAR  \
# count                              1222.0                              1216.0
# mean                                  0.0                                 0.0
# std                                   0.0                                 0.0
# min                                   0.0                                 0.0
# 25%                                   0.0                                 0.0
# 50%                                   0.0                                 0.0
# 75%                                   0.0                                 0.0
# max                                   0.0                                 0.0
#
#        CC_NAME_CONTRACT_STATUS_Refused_MEAN  \
# count                                1222.0
# mean                                    0.0
# std                                     0.0
# min                                     0.0
# 25%                                     0.0
# 50%                                     0.0
# 75%                                     0.0
# max                                     0.0
#
#        CC_NAME_CONTRACT_STATUS_Refused_SUM  \
# count                               1222.0
# mean                                   0.0
# std                                    0.0
# min                                    0.0
# 25%                                    0.0
# 50%                                    0.0
# 75%                                    0.0
# max                                    0.0
#
#        CC_NAME_CONTRACT_STATUS_Refused_VAR  \
# count                               1216.0
# mean                                   0.0
# std                                    0.0
# min                                    0.0
# 25%                                    0.0
# 50%                                    0.0
# 75%                                    0.0
# max                                    0.0
#
#        CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN  \
# count                                 1222.000000
# mean                                     0.000037
# std                                      0.000651
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      0.011905
#
#        CC_NAME_CONTRACT_STATUS_Sent proposal_SUM  \
# count                                1222.000000
# mean                                    0.003273
# std                                     0.057143
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        CC_NAME_CONTRACT_STATUS_Sent proposal_VAR  \
# count                                1216.000000
# mean                                    0.000037
# std                                     0.000653
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     0.011905
#
#        CC_NAME_CONTRACT_STATUS_Signed_MEAN  \
# count                          1222.000000
# mean                              0.004224
# std                               0.031593
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               0.583333
#
#        CC_NAME_CONTRACT_STATUS_Signed_SUM  CC_NAME_CONTRACT_STATUS_Signed_VAR  \
# count                         1222.000000                         1216.000000
# mean                             0.185761                            0.003497
# std                              2.270927                            0.021019
# min                              0.000000                            0.000000
# 25%                              0.000000                            0.000000
# 50%                              0.000000                            0.000000
# 75%                              0.000000                            0.000000
# max                             56.000000                            0.252532
#
#        CC_NAME_CONTRACT_STATUS_nan_MEAN  CC_NAME_CONTRACT_STATUS_nan_SUM  \
# count                            1222.0                           1222.0
# mean                                0.0                              0.0
# std                                 0.0                              0.0
# min                                 0.0                              0.0
# 25%                                 0.0                              0.0
# 50%                                 0.0                              0.0
# 75%                                 0.0                              0.0
# max                                 0.0                              0.0
#
#        CC_NAME_CONTRACT_STATUS_nan_VAR     CC_COUNT       NB_NAN
# count                           1216.0  1222.000000  4315.000000
# mean                               0.0    36.175123   208.181460
# std                                0.0    33.666288   103.975213
# min                                0.0     1.000000     0.000000
# 25%                                0.0     9.000000   151.000000
# 50%                                0.0    20.000000   212.000000
# 75%                                0.0    73.750000   244.000000
# max                                0.0   129.000000   604.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sélectionner les premières 5 colonnes pour l'exemple
selected_columns = sample_df.columns[2:12]

# Tracer des histogrammes pour ces colonnes
for col in selected_columns:
    plt.figure(figsize=(12, 6))
    sns.histplot(data=sample_df, x=col, kde=True)
    plt.title('Distribution de ' + col)
    plt.show()

# %%
#Export sample_df to csv
sample_df.to_csv("sample_df.csv", index=False)
